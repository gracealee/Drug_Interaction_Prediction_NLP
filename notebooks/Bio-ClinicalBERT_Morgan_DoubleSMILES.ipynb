# %% [markdown]
# # Bio-BERT Transformer Trainer

# %% [markdown]
# ## Set Up

# %%
# !pip install transformers datasets accelerate evaluate gensim==4.2.0 numpy==1.22.4 rdkit==2023.3.1

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# cd drive/MyDrive/w210_Capstone/
# %cd ..
# Out:
# /home/ubuntu/capstone-project

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.backends.cudnn as cudnn
import torch.optim as optim

from transformers import AutoTokenizer, AutoModel, Trainer, TrainingArguments, AutoConfig
from transformers import AdamW, get_cosine_schedule_with_warmup
from transformers import BertConfig, BertModel
from datasets import load_metric, load_dataset

import gensim
import re
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pprint
import os
import shutil
import time
import datetime

from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_curve, average_precision_score, auc

# from logging import warning
import warnings
warnings.filterwarnings('ignore')

# %%
if torch.cuda.is_available():
    device = "cuda"
    print('Number of GPU(s) available:', torch.cuda.device_count())
    print('GPU device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available')
    device = "cpu"
# Out:
# Number of GPU(s) available: 1
# GPU device name: NVIDIA A10G

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
RANDOM_SEED = 40
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed_all(RANDOM_SEED)

# %% [markdown]
# ## Bio-BERT with Trainer & Hugging Face

# %% [markdown]
# ### Build DataSet

# %%
## Define hyperparameters
BATCH_SIZE = 32
EPOCHS = 4
# LEARNING_RATE = 1e-3
LEARNING_RATE = 0.01
# LEARNING_RATE = 0.0963
WEIGHT_DECAY = 1e-4
# WEIGHT_DECAY = 0.01
WORKERS = int(os.cpu_count())

# %%
# Import data
train_file = 'data/binary_ddi/ddi_train_balanced_150k.csv'
dev_file = 'data/binary_ddi/ddi_val_binary.csv'
test_file = 'data/binary_ddi/ddi_test_binary.csv'

dataset = load_dataset('csv',
                       sep="\t",
                       data_files={'train': train_file, 'validation': dev_file,'test': test_file})
# Out:
# Found cached dataset csv (/home/ubuntu/.cache/huggingface/datasets/csv/default-7c7fda65b4fd85b3/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['d1', 'd2', 'd1_name', 'd2_name', 'interaction', 'interaction_type', 'severity', 'smiles1', 'smiles2'],
#         num_rows: 300000
#     })
#     validation: Dataset({
#         features: ['d1', 'd2', 'd1_name', 'd2_name', 'interaction', 'interaction_type', 'severity', 'smiles1', 'smiles2'],
#         num_rows: 238072
#     })
#     test: Dataset({
#         features: ['d1', 'd2', 'd1_name', 'd2_name', 'interaction', 'interaction_type', 'severity', 'smiles1', 'smiles2'],
#         num_rows: 186753
#     })
# })

# %%
df_train = pd.read_csv(train_file, sep='\t')
df_dev = pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')
print(f'''mean length of smiles1: {df_train['smiles1'].map(len).mean()}''')
print(f'''min length of smiles1: {df_train['smiles1'].map(len).min()}''')
print(f'''max length of smiles1: {df_train['smiles1'].map(len).max()}''')
print(f'''mean length of smiles2: {df_train['smiles2'].map(len).mean()}''')
print(f'''min length of smiles2: {df_train['smiles2'].map(len).min()}''')
print(f'''max length of smiles2: {df_train['smiles2'].map(len).max()}''')
print('Value Counts of Labels in Train Set:')
df_train.interaction_type.value_counts()
# Out:
# mean length of smiles1: 62.479706666666665
# min length of smiles1: 2
# max length of smiles1: 748
# mean length of smiles2: 62.77145
# min length of smiles2: 3
# max length of smiles2: 748
# Value Counts of Labels in Train Set:
# interaction_type
# 1    150000
# 0    150000
# Name: count, dtype: int64

# %%
## Load the pre-trained BioBERT tokenizer
# model_checkpoint = "dmis-lab/biobert-base-cased-v1.1"
model_checkpoint = "emilyalsentzer/Bio_ClinicalBERT"

# Tokenize & Pre-process Data
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
from transformers import PretrainedConfig

class BioClinicalBertConfig(PretrainedConfig):
    model_type = "bert"

    def __init__(
        self,
        hidden_size1: int = 68, 
        hidden_size2: int = 54, 
        hidden_size3: int = 40, 
        hidden3_dropout: float = 0.1, 
        unfreeze: bool = False,
        layer_norm_eps: float = 1e-12,
        pad_token_id: int = 0,
        position_embedding_type: str = "absolute",
        use_cache: bool = True,
        **kwargs,
    ):
        self.hidden_size1 = hidden_size1
        self.hidden_size2 = hidden_size2
        self.hidden_size3 = hidden_size3
        self.hidden3_dropout = hidden3_dropout
        self.unfreeze = unfreeze
        self.layer_norm_eps = layer_norm_eps
        self.pad_token_id = pad_token_id
        self.position_embedding_type = position_embedding_type
        self.use_cache = use_cache
        super().__init__(**kwargs)

config = BioClinicalBertConfig.from_pretrained(
    model_checkpoint,
    label2id={"NEGATIVE": 0, "POSITIVE": 1},
    id2label={0: "NEGATIVE", 1: "POSITIVE"},
    unfreeze=False,
    
)

# %%
print(config)
# Out:
# BioClinicalBertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }

# %%
# Create Combined SMILES column, seperated by [SEP] token between SMILES1 & SMILES2
def preprocess_data(examples):
    source_inputs = []
    for sm1, sm2 in zip(examples['smiles1'], examples['smiles2']):
        # Ensure feeding both smile 1 & smiles 2 into input by truncating if the smiles are too loong
        source_input = "[CLS]" + sm1[:250] + "[SEP]" + sm2[:250] + "[SEP]"
        source_inputs.append(source_input)
    model_inputs = tokenizer(source_inputs,
                             max_length=512,
                             padding="max_length",
                             truncation=True,
                             return_token_type_ids=False,
                             return_tensors='pt'
                             )

    model_inputs["labels"] = examples['interaction_type']

    return model_inputs

# %%
encoded_train_ds = dataset['train'].map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_val_ds_full = dataset['validation'].map(preprocess_data, batched=True, remove_columns=dataset['validation'].column_names)
encoded_val_ds = encoded_val_ds_full.select(indices=range(30000))  # Subset to smaller valset for faster training
encoded_test_ds = dataset['test'].map(preprocess_data, batched=True, remove_columns=dataset['test'].column_names)

encoded_val_ds
# Out:
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/csv/default-7c7fda65b4fd85b3/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d/cache-302195fe960a0721.arrow
# Map:   0%|          | 0/238072 [00:00<?, ? examples/s]
# Loading cached processed dataset at /home/ubuntu/.cache/huggingface/datasets/csv/default-7c7fda65b4fd85b3/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d/cache-88c4a77060bf653b.arrow
# Dataset({
#     features: ['input_ids', 'attention_mask', 'labels'],
#     num_rows: 30000
# })

# %%
encoded_val_ds[0]['labels']
# Out:
# 1

# %%
len(encoded_train_ds)/BATCH_SIZE
# Out:
# 2343.75

# %% [markdown]
# ### Build Model, Set up Trainer

# %%
from transformers import BertPreTrainedModel, BertModel

class BioClinicalBertClassification(BertPreTrainedModel):
    config_class = BioClinicalBertConfig
    
    def __init__(self, config, num_labels=2):
        super(BioClinicalBertClassification, self).__init__(config)
        self.bert_model = BertModel(config=config)
        self.num_labels = num_labels

        # Unfreeze the last BERT transformer layer
        if config.unfreeze == "last layer":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if config.unfreeze == "all layers":
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = True
        else:
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = False

        self.bert_hidden_size = self.bert_model.config.hidden_size
        self.hidden_layer = nn.Linear(self.bert_hidden_size, config.hidden_size1)
        self.hidden_layer2 = nn.Linear(config.hidden_size1, config.hidden_size2)
        self.hidden_layer3 = nn.Linear(config.hidden_size2, config.hidden_size3)

        self.drop_out = nn.Dropout(config.hidden3_dropout)

        if self.num_labels >= 2:
            self.classification = nn.Linear(config.hidden_size3, self.num_labels)
        else:
            self.classification = nn.Linear(config.hidden_size3, 1)
            
        self.GeLU = nn.GELU()
        self.Sigmoid = nn.Sigmoid()

    def forward(self, input_ids=None, attention_mask=None, labels=None):
        bert_output = self.bert_model(input_ids=input_ids,
                                      attention_mask=attention_mask)
        
        # pooler_token = bert_output[1]
        pooler_token = bert_output[0][:,0]

        hidden_ouput = self.GeLU(self.hidden_layer(pooler_token))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer2(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer3(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)      

        if self.num_labels >= 2:
            logits = self.classification(hidden_ouput)

        else:           
            logits = self.Sigmoid(self.classification(hidden_ouput))
            logits = logits.flatten()
        
        if self.num_labels == 1 and labels is not None:
            loss_fct = nn.BCELoss()
            loss = loss_fct(logits, labels.float())
            return {"loss": loss, "logits": logits}
        
        if self.num_labels >= 2 and labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
            return {"loss": loss, "logits": logits}

        return {"logits": logits}

# %%
BioClinicalBertConfig.register_for_auto_class()
BioClinicalBertClassification.register_for_auto_class("AutoModelForSequenceClassification")

# %%
# Load Metric
metric = load_metric('glue', 'sst2')
metric
# Out:
# Metric(name: "glue", features: {'predictions': Value(dtype='int64', id=None), 'references': Value(dtype='int64', id=None)}, usage: """
# Compute GLUE evaluation metric associated to each GLUE dataset.
# Args:
#     predictions: list of predictions to score.
#         Each translation should be tokenized into a list of tokens.
#     references: list of lists of references for each translation.
#         Each reference should be tokenized into a list of tokens.
# Returns: depending on the GLUE subset, one or several of:
#     "accuracy": Accuracy
#     "f1": F1 score
#     "pearson": Pearson Correlation
#     "spearmanr": Spearman Correlation
#     "matthews_correlation": Matthew Correlation
# Examples:
#
#     >>> glue_metric = datasets.load_metric('glue', 'sst2')  # 'sst2' or any of ["mnli", "mnli_mismatched", "mnli_matched", "qnli", "rte", "wnli", "hans"]
#     >>> references = [0, 1]
#     >>> predictions = [0, 1]
#     >>> results = glue_metric.compute(predictions=predictions, references=references)
#     >>> print(results)
#     {'accuracy': 1.0}
#
#     >>> glue_metric = datasets.load_metric('glue', 'mrpc')  # 'mrpc' or 'qqp'
#     >>> references = [0, 1]
#     >>> predictions = [0, 1]
#     >>> results = glue_metric.compute(predictions=predictions, references=references)
#     >>> print(results)
#     {'accuracy': 1.0, 'f1': 1.0}
#
#     >>> glue_metric = datasets.load_metric('glue', 'stsb')
#     >>> references = [0., 1., 2., 3., 4., 5.]
#     >>> predictions = [0., 1., 2., 3., 4., 5.]
#     >>> results = glue_metric.compute(predictions=predictions, references=references)
#     >>> print({"pearson": round(results["pearson"], 2), "spearmanr": round(results["spearmanr"], 2)})
#     {'pearson': 1.0, 'spearmanr': 1.0}
#
#     >>> glue_metric = datasets.load_metric('glue', 'cola')
#     >>> references = [0, 1]
#     >>> predictions = [0, 1]
#     >>> results = glue_metric.compute(predictions=predictions, references=references)
#     >>> print(results)
#     {'matthews_correlation': 1.0}
# """, stored examples: 0)

# %%
# Test metric calculation
fake_preds = np.random.randint(0, 2, size=(64,))
fake_labels = np.random.randint(0, 2, size=(64,))
metric.compute(predictions=fake_preds, references=fake_labels)
# Out:
# {'accuracy': 0.53125}

# %%
def compute_metrics(eval_pred, num_labels=2):
    predictions, labels = eval_pred
        
    if num_labels >= 2:
        # probability
        # softmax = np.exp(predictions) / np.sum(np.exp(predictions), axis=1, keepdims=True)
        # scores = softmax[:, 1]
        predictions = np.argmax(predictions, axis=1)
    else:
        predictions =(np.array(predictions) >= 0.5).astype(float)
        # scores = np.array(predictions)

    # Accuracy
    result = metric.compute(predictions=predictions, references=labels)

    # Add F2 Score
    result["f2"] = metrics.fbeta_score(labels, predictions, average="binary", pos_label=1, beta=2)

    # Add Recall
    result["recall"] = metrics.recall_score(labels, predictions, average="binary", pos_label=1)

    # Add Precision
    result["precision"] = metrics.precision_score(labels, predictions, average="binary", pos_label=1)

    # Matthew Correlation
    result["mcc"] = metrics.matthews_corrcoef(labels, predictions)

    # Area Under Precision, Recall Curve
    # precisions, recalls, thresholds = precision_recall_curve(labels, scores)
    # result["AUPRC"] = auc(precisions, recalls)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
# Clear out cuda before training
torch.cuda.empty_cache()

# %%
# Model Initilization
model = BioClinicalBertClassification(config)

# # Pretrain model weights
# pretrained_model = AutoModel.from_pretrained(model_checkpoint)
# # Load pre-train weights to BioBert model
# model.bert_model.load_state_dict(pretrained_model.state_dict())

# Load training weights checkpoint, for continue training
# pretrained_weights = torch.load('models/BioBERTFrozen.pth')
pretrained_weights = torch.load('models/Bio_ClinicalBERT_DDI_2heads2.pth')
model.load_state_dict(pretrained_weights )



# from transformers import AutoModelForSequenceClassification
# model = AutoModelForSequenceClassification.from_pretrained(
#     model_checkpoint, config=config
# )

# Print out models params for checking
params = list(model.named_parameters())
for p in params[-20:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

# Optimizer & Schedular
# optimizer = AdamW(model.parameters(), lr=LEARNING_RATE, 
#                   weight_decay=WEIGHT_DECAY)
# scheduler = get_cosine_schedule_with_warmup(optimizer,
#                                             num_warmup_steps=10,
#                                             num_training_steps=30000)

# Optimizer
optimizer = optim.Adadelta(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Create learning rate scheduler.
T_max = round(EPOCHS*len(encoded_train_ds)/BATCH_SIZE)
print('Number of steps:', T_max)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)
# Out:
# bert_model.encoder.layer.11.attention.output.dense.weight   (768, 768)
# bert_model.encoder.layer.11.attention.output.dense.bias       (768,)
# bert_model.encoder.layer.11.attention.output.LayerNorm.weight       (768,)
# bert_model.encoder.layer.11.attention.output.LayerNorm.bias       (768,)
# bert_model.encoder.layer.11.intermediate.dense.weight    (3072, 768)
# bert_model.encoder.layer.11.intermediate.dense.bias          (3072,)
# bert_model.encoder.layer.11.output.dense.weight          (768, 3072)
# bert_model.encoder.layer.11.output.dense.bias                 (768,)
# bert_model.encoder.layer.11.output.LayerNorm.weight           (768,)
# bert_model.encoder.layer.11.output.LayerNorm.bias             (768,)
# bert_model.pooler.dense.weight                            (768, 768)
# bert_model.pooler.dense.bias                                  (768,)
# hidden_layer.weight                                        (68, 768)
# hidden_layer.bias                                              (68,)
# hidden_layer2.weight                                        (54, 68)
# hidden_layer2.bias                                             (54,)
# hidden_layer3.weight                                        (40, 54)
# hidden_layer3.bias                                             (40,)
# classification.weight                                        (2, 40)
# classification.bias                                             (2,)
# Number of steps: 37500

# %% [markdown]
# ### Training with Trainer

# %%
# Training Arguments
model_dir = "Bio_ClinicalBERT_DDI_finetuned"

args = TrainingArguments(
    output_dir=model_dir,
    overwrite_output_dir=True,
    do_train=True,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    # evaluation_strategy="steps",
    # eval_steps=1000,
    # logging_strategy="steps",
    # logging_steps=1000,
    learning_rate=LEARNING_RATE,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    weight_decay=WEIGHT_DECAY,
    num_train_epochs=EPOCHS,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    remove_unused_columns=True,
    push_to_hub=True,
)

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=encoded_train_ds,
    eval_dataset=encoded_val_ds,
    tokenizer=tokenizer,
    optimizers=(optimizer, scheduler),
    compute_metrics=compute_metrics,
)
# Out:
# /home/ubuntu/capstone-project/Bio_ClinicalBERT_DDI_finetuned is already a clone of https://huggingface.co/ltmai/Bio_ClinicalBERT_DDI_finetuned. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
# Starting metrics from last checkpoint training
# EVALUATION BEFORE TRAINING
trainer.evaluate()
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='469' max='469' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [469/469 04:32]
#     </div>
# {'eval_loss': 0.683655321598053,
#  'eval_accuracy': 0.5625,
#  'eval_f2': 0.8649,
#  'eval_recall': 0.9991,
#  'eval_precision': 0.5626,
#  'eval_mcc': -0.0005,
#  'eval_runtime': 274.3033,
#  'eval_samples_per_second': 109.368,
#  'eval_steps_per_second': 1.71}

# %%
# TRANING
trainer.train()
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='37500' max='37500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37500/37500 3:42:04, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F2</th>
#       <th>Recall</th>
#       <th>Precision</th>
#       <th>Mcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.678500</td>
#       <td>0.685292</td>
#       <td>0.555000</td>
#       <td>0.717400</td>
#       <td>0.762900</td>
#       <td>0.579400</td>
#       <td>0.057200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.676800</td>
#       <td>0.686711</td>
#       <td>0.551900</td>
#       <td>0.688000</td>
#       <td>0.720800</td>
#       <td>0.582200</td>
#       <td>0.059800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.677700</td>
#       <td>0.687498</td>
#       <td>0.550100</td>
#       <td>0.670300</td>
#       <td>0.696100</td>
#       <td>0.584000</td>
#       <td>0.061600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.679000</td>
#       <td>0.687751</td>
#       <td>0.548200</td>
#       <td>0.658300</td>
#       <td>0.679800</td>
#       <td>0.584700</td>
#       <td>0.061200</td>
#     </tr>
#   </tbody>
# </table><p>
# We can't save the code defining BioClinicalBertClassification(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (hidden_layer): Linear(in_features=768, out_features=68, bias=True)
#   (hidden_layer2): Linear(in_features=68, out_features=54, bias=True)
#   (hidden_layer3): Linear(in_features=54, out_features=40, bias=True)
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (classification): Linear(in_features=40, out_features=2, bias=True)
#   (GeLU): GELU(approximate='none')
#   (Sigmoid): Sigmoid()
# ) in Bio_ClinicalBERT_DDI_finetuned/checkpoint-9375 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertConfig {
#   "architectures": [
#     "BioClinicalBertClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#  in Bio_ClinicalBERT_DDI_finetuned/checkpoint-9375 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertClassification(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (hidden_layer): Linear(in_features=768, out_features=68, bias=True)
#   (hidden_layer2): Linear(in_features=68, out_features=54, bias=True)
#   (hidden_layer3): Linear(in_features=54, out_features=40, bias=True)
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (classification): Linear(in_features=40, out_features=2, bias=True)
#   (GeLU): GELU(approximate='none')
#   (Sigmoid): Sigmoid()
# ) in Bio_ClinicalBERT_DDI_finetuned/checkpoint-18750 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertConfig {
#   "architectures": [
#     "BioClinicalBertClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#  in Bio_ClinicalBERT_DDI_finetuned/checkpoint-18750 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertClassification(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (hidden_layer): Linear(in_features=768, out_features=68, bias=True)
#   (hidden_layer2): Linear(in_features=68, out_features=54, bias=True)
#   (hidden_layer3): Linear(in_features=54, out_features=40, bias=True)
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (classification): Linear(in_features=40, out_features=2, bias=True)
#   (GeLU): GELU(approximate='none')
#   (Sigmoid): Sigmoid()
# ) in Bio_ClinicalBERT_DDI_finetuned/checkpoint-28125 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertConfig {
#   "architectures": [
#     "BioClinicalBertClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#  in Bio_ClinicalBERT_DDI_finetuned/checkpoint-28125 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertClassification(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (hidden_layer): Linear(in_features=768, out_features=68, bias=True)
#   (hidden_layer2): Linear(in_features=68, out_features=54, bias=True)
#   (hidden_layer3): Linear(in_features=54, out_features=40, bias=True)
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (classification): Linear(in_features=40, out_features=2, bias=True)
#   (GeLU): GELU(approximate='none')
#   (Sigmoid): Sigmoid()
# ) in Bio_ClinicalBERT_DDI_finetuned/checkpoint-37500 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertConfig {
#   "architectures": [
#     "BioClinicalBertClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#  in Bio_ClinicalBERT_DDI_finetuned/checkpoint-37500 as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# TrainOutput(global_step=37500, training_loss=0.6782601220703125, metrics={'train_runtime': 13325.0567, 'train_samples_per_second': 90.056, 'train_steps_per_second': 2.814, 'total_flos': 3.159425138688e+17, 'train_loss': 0.6782601220703125, 'epoch': 4.0})

# %% [markdown]
# ### Evaluation

# %%
# EVALUATION AFTER TRAINING
trainer.evaluate(encoded_test_ds)
# Out:
#     <div>
#
#       <progress value='5837' max='5837' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5837/5837 28:22]
#     </div>
# {'eval_loss': 0.6686776280403137,
#  'eval_accuracy': 0.592,
#  'eval_f2': 0.7169,
#  'eval_recall': 0.7257,
#  'eval_precision': 0.6836,
#  'eval_mcc': 0.0495,
#  'eval_runtime': 1703.9991,
#  'eval_samples_per_second': 109.597,
#  'eval_steps_per_second': 3.425,
#  'epoch': 4.0}

# %%
trainer.push_to_hub()
#model.push_to_hub()
# Out:
# We can't save the code defining BioClinicalBertClassification(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (hidden_layer): Linear(in_features=768, out_features=68, bias=True)
#   (hidden_layer2): Linear(in_features=68, out_features=54, bias=True)
#   (hidden_layer3): Linear(in_features=54, out_features=40, bias=True)
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (classification): Linear(in_features=40, out_features=2, bias=True)
#   (GeLU): GELU(approximate='none')
#   (Sigmoid): Sigmoid()
# ) in Bio_ClinicalBERT_DDI_finetuned as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# We can't save the code defining BioClinicalBertConfig {
#   "architectures": [
#     "BioClinicalBertClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden3_dropout": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "hidden_size1": 68,
#   "hidden_size2": 54,
#   "hidden_size3": 40,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "unfreeze": false,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#  in Bio_ClinicalBERT_DDI_finetuned as it's been defined in __main__. You should put this code in a separate module so we can include it in the saved folder and make it easier to share via the Hub.
# To https://huggingface.co/ltmai/Bio_ClinicalBERT_DDI_finetuned
#    5c3c426..18c5dee  main -> main
#
# To https://huggingface.co/ltmai/Bio_ClinicalBERT_DDI_finetuned
#    18c5dee..de11cf9  main -> main
# 'https://huggingface.co/ltmai/Bio_ClinicalBERT_DDI_finetuned/commit/18c5deeab17f9dcb4f1e422f1f1f76a077e69617'

# %%
# save training weights
# trainer.save_pretrain('Bio_ClinicalBERT_DDI_finetuned')
torch.save(model.state_dict(), 'models/Bio_ClinicalBERT_DDI_2heads3.pth')

# %% [markdown]
# ## SMILES Morgan768 & Action + Target BioClinicalBERT
#
# ### Build Model

# %%
# Define hyperparameters
BATCH_SIZE = 16
EPOCHS = 30
LEARNING_RATE = 0.001
# MOMENTUM = 0.9
WEIGHT_DECAY = 0.01
WORKERS = int(os.cpu_count())

# %%
# Clear out cuda before training
torch.cuda.empty_cache()

# %%
# BERT Model
class MorganBioBertClassification(nn.Module):
    def __init__(self,output_dim=1,
                 hidden_size=68, hidden_size2=54, hidden_size3=40,
                 dropout=0.1, unfreeze=False):
        super(MorganBioBertClassification, self).__init__()
        self.bert_model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

        # Unfreeze the last BERT transformer layer
        if unfreeze == "last layer":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "last two":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name or 'bert_model.encoder.layer.10' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "all layers":
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = True
        else:
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = False

        self.bert_hidden_size = self.bert_model.config.hidden_size
        self.hidden_size = hidden_size
        self.hidden_size2 = hidden_size2
        self.hidden_size3 = hidden_size3
        self.hidden_layer = nn.Linear(self.bert_hidden_size, self.hidden_size)
        self.hidden_layer2 = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3 = nn.Linear(self.hidden_size2, self.hidden_size3)

        # Morgan Embedding First hidden layer
        self.hidden_layer_morgan = nn.Linear(1536, self.hidden_size)
        self.hidden_layer2_morgan = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3_morgan = nn.Linear(self.hidden_size2, self.hidden_size3)

        self.drop_out = nn.Dropout(dropout)

        self.classification = nn.Linear(self.hidden_size3, output_dim)

        self.GeLU = nn.GELU()
        self.Sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask, morgan_embedding):
        # Output for target data
        bert_output = self.bert_model(input_ids=input_ids,
                                      attention_mask=attention_mask)

        pooler_token = bert_output[1]

        hidden_ouput = self.GeLU(self.hidden_layer(pooler_token))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer2(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer3(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)

        # Output for SMILES Morgan Embedding
        hidden_morgan_output = self.GeLU(self.hidden_layer_morgan(morgan_embedding))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer2_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer3_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)

        # Concatenate hidden_output and morgan_output
        concat_output = torch.cat((hidden_morgan_output, hidden_ouput), 1)

        # logits = self.classification(x)
        output = self.Sigmoid(self.classification(concat_output))
        output = output.flatten()

        # return logits
        return output

# %%
# Initialize model
model = MorganBioBertClassification()
model = model.to(device)

#load the pre-trained Bio-ClinicalBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')

# Print out models params for checking
params = list(model.named_parameters())
for p in params[-30:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# bert_model.encoder.layer.11.output.dense.weight          (768, 3072)
# bert_model.encoder.layer.11.output.dense.bias                 (768,)
# bert_model.encoder.layer.11.output.LayerNorm.weight           (768,)
# bert_model.encoder.layer.11.output.LayerNorm.bias             (768,)
# bert_model.pooler.dense.weight                            (768, 768)
# bert_model.pooler.dense.bias                                  (768,)
# hidden_layer.weight                                        (68, 768)
# hidden_layer.bias                                              (68,)
# hidden_layer2.weight                                        (54, 68)
# hidden_layer2.bias                                             (54,)
# hidden_layer3.weight                                        (40, 54)
# hidden_layer3.bias                                             (40,)
# hidden_layer_morgan.weight                                (68, 1536)
# hidden_layer_morgan.bias                                       (68,)
# hidden_layer2_morgan.weight                                 (54, 68)
# hidden_layer2_morgan.bias                                      (54,)
# hidden_layer3_morgan.weight                                 (40, 54)
# hidden_layer3_morgan.bias                                      (40,)
# classification.weight                                        (1, 80)
# classification.bias                                             (1,)

# %% [markdown]
# ### Build DataLoader

# %%
# Import data
train_file = 'data/binary_ddi/ddi_train_balanced_with_target_150k.csv'
dev_file = 'data/binary_ddi/ddi_val_binary_with_target.csv'
test_file = 'data/binary_ddi/ddi_test_binary_with_target.csv'
action_file = 'data/scraping_action_pathways.csv'

df_train = pd.read_csv(train_file, sep='\t')
# df_train = df_train[["d1", "d2", "interaction_type", "smiles1", "smiles2", "d1_target", "d2_target"]]
df_val= pd.read_csv(dev_file, sep='\t')
# df_val = df_val[["d1", "d2", "interaction_type", "smiles1", "smiles2", "d1_target", "d2_target"]]
df_test = pd.read_csv(test_file, sep='\t')
# df_test = df_test[["d1", "d2", "interaction_type", "smiles1", "smiles2", "d1_target", "d2_target"]]
df_action  =  pd.read_csv(action_file,  sep='\t')

print(f'''mean length of smiles1: {df_train['smiles1'].map(len).mean()}''')
print(f'''min length of smiles1: {df_train['smiles1'].map(len).min()}''')
print(f'''max length of smiles1: {df_train['smiles1'].map(len).max()}''')
print(f'''mean length of smiles2: {df_train['smiles2'].map(len).mean()}''')
print(f'''min length of smiles2: {df_train['smiles2'].map(len).min()}''')
print(f'''max length of smiles2: {df_train['smiles2'].map(len).max()}''')
print(f'''mean length of target1: {df_train['d1_target'].map(len).mean()}''')
print(f'''min length of target1: {df_train['d1_target'].map(len).min()}''')
print(f'''max length of target1: {df_train['d1_target'].map(len).max()}''')
print('Value Counts of Labels in Train Set:')
df_train.interaction_type.value_counts()
df_train.head(2)
# Out:
# mean length of smiles1: 62.47947666666666
# min length of smiles1: 2
# max length of smiles1: 748
# mean length of smiles2: 62.731
# min length of smiles2: 2
# max length of smiles2: 748
# mean length of target1: 249.94
# min length of target1: 13
# max length of target1: 24879
# Value Counts of Labels in Train Set:
#         d1       d2      d1_name        d2_name  \
# 0  DB01501  DB00356    Difenoxin  Chlorzoxazone
# 1  DB00208  DB00242  Ticlopidine     Cladribine
#
#                                          interaction  interaction_type  \
# 0  The risk or severity of adverse effects can be...                 1
# 1  The risk or severity of bleeding can be increa...                 1
#
#   severity                                            smiles1  \
# 0     high  OC(=O)C1(CCN(CCC(C#N)(C2=CC=CC=C2)C2=CC=CC=C2)...
# 1     high                    ClC1=CC=CC=C1CN1CCC2=C(C1)C=CS2
#
#                                              smiles2  \
# 0                           ClC1=CC2=C(OC(=O)N2)C=C1
# 1  NC1=C2N=CN([C@H]3C[C@H](O)[C@@H](CO)O3)C2=NC(C...
#
#                                            d1_target  \
# 0                                      Not Available
# 1  Category: A, Protein: P2Y purinoceptor 12, Act...
#
#                                            d1_action  \
# 0  Difenoxin acts as an antidiarrheal by activati...
# 1  The active metabolite of ticlopidine prevents ...
#
#                                            d2_target  \
# 0                                      Not Available
# 1  Category: A, Protein: Ribonucleoside-diphospha...
#
#                                            d2_action
# 0  Chlorzoxazone inhibits degranulation of mast c...
# 1  Cladribine is structurally related to fludarab...

# %%
import string
def get_drug_id(url):
    words = url.split('=')
    # w = words[0].translate(str.maketrans('', '', string.punctuation))
    w = words[-1].strip()
    return w
df_action['drug_id'] = df_action['url'].apply(get_drug_id)
df_action.head()
# Out:
#                                                  url  \
# 0  http://smpdb.ca/view/SMP0000277?highlight[comp...
# 1  http://smpdb.ca/view/SMP0000429?highlight[comp...
# 2  http://smpdb.ca/view/SMP0000429?highlight[comp...
# 3  http://smpdb.ca/view/SMP0000428?highlight[comp...
# 4  http://smpdb.ca/view/SMP0000729?highlight[comp...
#
#                                       action_pathway  drug_id
# 0  Bivalirudin, trade name angiomax, is a direct ...  DB00006
# 1  Disulfiram is a drug used in the treatment of ...  DB00118
# 2  Disulfiram is a drug used in the treatment of ...  DB00126
# 3  Mercaptopurine is a purine antimetabolite prod...  DB00130
# 4  Chloramphenicol, trade names Pentamycetin and ...  DB00134

# %%
## Data Clean Up
import re

def clean_up_text(x):
  """Remove line breaks, special characters, punctuations within each post"""
  # Remove special characters and punctuations
  x = str(x)
  if not x or x == "nan":
      x = "Pathway not available"
  SPECIAL_CHARS_PATTERN = re.compile(r"(\*)|(\=\=)|(\~)|(\=)|(\.\.\.)|(\;)|(\:)|(\!)|(\?)|(\,)|(\")|(\|)|(\()|(\))|(\[)|(\])|(\%)|(\$)|(\>)|(\<)|(\{)|(\})")
  x = SPECIAL_CHARS_PATTERN.sub("", x)

  # Remove different types of line breaks and white spaces
  x = re.sub(r"\n|\r|\r\n|<br\s*/?>", " ", x)
  
  # Remove extra white spaces
  x = re.sub(r"\s+", " ", x.strip())

  return x

def trim_to_125_words(text):
    words = text.split()
    return " ".join(words[:125])

def trim_to_250_words(text):
    words = text.split()
    return " ".join(words[:250])
    
def extract_action_pathway(df, df_action=df_action):
    # Drug 1 action pathway
    df = pd.merge(df, df_action, left_on='d1', right_on='drug_id', how='left')
    df = df.rename(columns={"action_pathway": "d1_pathway"})
    # Add action pathway to target
    df["d1_target"] = df["d1_target"].apply(clean_up_text)
    df["d1_target"] = df["d1_target"].apply(trim_to_125_words) #Trim down target to include pathway infor if available
    df["d1_pathway"] = df["d1_pathway"].apply(clean_up_text)
    df["d1_action"] = df["d1_action"].apply(clean_up_text)
    df["d1_target_action"] = "Target " + df["d1_target"] + " " + df["d1_pathway"] + " " + df["d1_action"]
    df["d1_target_action"] = df["d1_target_action"].apply(trim_to_250_words) #Trim down to include drug 2

    # Drug 2 action pathway
    df = pd.merge(df, df_action, left_on='d2', right_on ='drug_id', how='left')
    df = df.rename(columns={"action_pathway": "d2_pathway"})
        # Add action pathway to target
    df["d2_target"] = df["d2_target"].apply(clean_up_text)
    df["d2_target"] = df["d2_target"].apply(trim_to_125_words) #Trim down target to include pathway infor if available
    df["d2_pathway"] = df["d2_pathway"].apply(clean_up_text)
    df["d2_action"] = df["d2_action"].apply(clean_up_text)
    df["d2_target_action"] = "Target " + df["d2_target"] + ". " + df["d2_pathway"] + " " + df["d2_action"]
    df["d2_target_action"] = df["d2_target_action"].apply(trim_to_250_words) 
    
    df = df[["d1", "d2", "interaction_type", "smiles1", "smiles2", "d1_target_action", "d2_target_action"]]
    return df

df_train = extract_action_pathway(df_train)
df_val = extract_action_pathway(df_val)
df_test = extract_action_pathway(df_test)
df_train.head(2)
# Out:
#         d1       d2  interaction_type  \
# 0  DB01501  DB00356                 1
# 1  DB00208  DB00242                 1
#
#                                              smiles1  \
# 0  OC(=O)C1(CCN(CCC(C#N)(C2=CC=CC=C2)C2=CC=CC=C2)...
# 1                    ClC1=CC=CC=C1CN1CCC2=C(C1)C=CS2
#
#                                              smiles2  \
# 0                           ClC1=CC2=C(OC(=O)N2)C=C1
# 1  NC1=C2N=CN([C@H]3C[C@H](O)[C@@H](CO)O3)C2=NC(C...
#
#                                     d1_target_action  \
# 0  Target Not Available Pathway not available Dif...
# 1  Target Category A Protein P2Y purinoceptor 12 ...
#
#                                     d2_target_action
# 0  Target Not Available. Pathway not available Ch...
# 1  Target Category A Protein Ribonucleoside-dipho...

# %%
from sklearn.utils import resample

# Choose a smaller subset of val data for faster training
df_val_small = resample(df_val,
                        replace=False,     # sample without replacement
                        n_samples=30000,
                        # random_state=1
                       ) 
print(df_val_small.shape)
df_val_small.head(2)
# Out:
# (30000, 7)
#              d1       d2  interaction_type  \
# 100113  DB01628  DB13406                 1
# 70844   DB09091  DB13868                 1
#
#                                                   smiles1  \
# 100113  CC1=NC=C(C=C1)C1=C(C=C(Cl)C=N1)C1=CC=C(C=C1)S(...
# 70844   [H][C@@]12CC[C@](O)(C(=O)CS)[C@@]1(C)C[C@H](O)...
#
#                                    smiles2  \
# 100113  CCCCNC(=O)NS(=O)(=O)C1=CC=C(N)C=C1
# 70844    NC1=C2N=CN(CCOCP(O)(O)=O)C2=NC=N1
#
#                                          d1_target_action  \
# 100113  Target Category A Protein Prostaglandin G/H sy...
# 70844   Target Category A Protein Glucocorticoid recep...
#
#                                          d2_target_action
# 100113  Target Not Available. Pathway not available No...
# 70844   Target Category A Protein DNA polymerase/rever...

# %%
# Import Drug2Vec Embedding - Morgan Fingerprints, Cosine Similarity
# drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_300clusters_morgan_cosine.txt", binary=False)
# Import Drug2Vec Embedding - Morgan Fingerprints, Tanimoto Similarity, 768 clusters
drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_768clusters_maccs_tanimoto.txt", binary=False)

print('Number of drugs available:', len(drug2vec_model.index_to_key))
print('Example - top 10 keys:', drug2vec_model.index_to_key[:10])
print('Embedding dimension:', len(drug2vec_model[drug2vec_model.index_to_key[0]]))
# Out:
# Number of drugs available: 2563
# Example - top 10 keys: ['DB00006', 'DB00007', 'DB00014', 'DB00027', 'DB00035', 'DB00067', 'DB00080', 'DB00091', 'DB00115', 'DB00118']
# Embedding dimension: 768

# %%
def build_data_loader(df, shuffle=True, verbose=False):
    # Extract Morgan Fingerprint Embedding
    # Remove the 4 SMILES causing error, only include SMILES in drug2vec.txt
    valid_smiles = drug2vec_model.index_to_key
    df = df[df['d1'].isin(valid_smiles) & df['d2'].isin(valid_smiles)]

    # Extract embedding
    df['d1_embedding'] = df['d1'].apply(lambda x: drug2vec_model[x])
    df['d2_embedding'] = df['d2'].apply(lambda x: drug2vec_model[x])

    # Drop all records that could not extract embedding (SMILES errors)
    df = df.dropna(subset=['d1_embedding', 'd2_embedding'], how='any')
    d1_embed = np.array(df['d1_embedding'].tolist())
    d2_embed = np.array(df['d2_embedding'].tolist())
    X_smiles = np.hstack((d1_embed, d2_embed))
    morgan_embedding = torch.from_numpy(X_smiles)
    if verbose:
        print('Drug1 Embedding Dimension:',d1_embed.shape)
        print('Drug2 Embedding Dimension:',d2_embed.shape)
        print('Drug 1 Concatenate with Drug 2 Embedding Dimension:', X_smiles.shape)
        print('Torch tensor Embedding Dimension:', morgan_embedding.shape)

    # Combine Target2 and Target2 Together, using [SEP] token to distingush between drug1 & drug2
    # df["d1_target"] = df["d1_target"].str.replace('|', '.').str.replace(':','')
    # df["d1_target"] = df["d1_target"].apply(trim_to_250_words)
    # df["d2_target"] = df["d2_target"].str.replace('|', '.').str.replace(':','')
    # df["d2_target"] = df["d2_target"].apply(trim_to_250_words)
    df["target_features"] = "Drug1: " + df["d1_target_action"] + " [SEP] " + "Drug2: " + df["d2_target_action"] + " [SEP]"

    X_target = df["target_features"]
    y = df["interaction_type"]

    # Tokenize Target
    _encodings = tokenizer(
        list(X_target.values),
        max_length=512,
        truncation=True,
        pad_to_max_length=True,
        return_token_type_ids=False,
        return_tensors='pt'
    )

    _ids = _encodings.input_ids
    _mask = _encodings.attention_mask
    _labels = torch.tensor(y.values)
    if verbose:
        print('Torch tensor target_ids Dimension:', _ids.shape)
        print('Torch tensor labels Dimension:', _labels.shape)

    _dataset = TensorDataset(_ids, _mask, _labels, morgan_embedding)
    _loader = DataLoader(_dataset, batch_size=BATCH_SIZE, shuffle=shuffle, num_workers=WORKERS)

    return _loader
    # return X_smiles, X_target, y

# %%
# Val Data Loader
print('Validation Data Loader:')
val_loader = build_data_loader(df_val_small, shuffle=False, verbose=True)
# Out:
# Validation Data Loader:
# Drug1 Embedding Dimension: (29959, 768)
# Drug2 Embedding Dimension: (29959, 768)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (29959, 1536)
# Torch tensor Embedding Dimension: torch.Size([29959, 1536])
# Torch tensor target_ids Dimension: torch.Size([29959, 512])
# Torch tensor labels Dimension: torch.Size([29959])

# %%
# Test Data Loader
print('Testing Data Loader:')
test_loader = build_data_loader(df_test, shuffle=False, verbose=True)
# Out:
# Testing Data Loader:
# Drug1 Embedding Dimension: (216063, 768)
# Drug2 Embedding Dimension: (216063, 768)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (216063, 1536)
# Torch tensor Embedding Dimension: torch.Size([216063, 1536])
# Torch tensor target_ids Dimension: torch.Size([216063, 512])
# Torch tensor labels Dimension: torch.Size([216063])

# %%
# Train Data Loader
print('Training Data Loader:')
train_loader = build_data_loader(df_train, verbose=True)
# Out:
# Training Data Loader:
# Drug1 Embedding Dimension: (299076, 768)
# Drug2 Embedding Dimension: (299076, 768)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (299076, 1536)
# Torch tensor Embedding Dimension: torch.Size([299076, 1536])
# Torch tensor target_ids Dimension: torch.Size([299076, 512])
# Torch tensor labels Dimension: torch.Size([299076])

# %%
print('Train batches:', len(train_loader))
print('Val subset batches:', len(val_loader))
# print('Val Full batches:', len(val_loader_full))
print('Test batches:', len(test_loader))
# Out:
# Train batches: 18693
# Val subset batches: 1873
# Test batches: 13504

# %% [markdown]
# ### Training

# %%
# Initiate loss to Binary Cross Entropy
from transformers import get_linear_schedule_with_warmup

criterion = nn.BCELoss()  # 1 head
# criterion = nn.CrossEntropyLoss().to(device)  # 2 heads

# Optimizer
optimizer = optim.Adadelta(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Create learning rate scheduler.
T_max = EPOCHS*len(train_loader)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min = 1e-5)
# scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*T_max, num_training_steps=T_max)

# %%
def format_time(seconds):
    return str(datetime.timedelta(seconds=int(round(seconds))))

# %%
## Define train function
def train(train_loader, model, criterion, optimizer, verbose=True):  
    # reset total loss for each epoch
    total_loss = 0

    # switch model to train mode
    model.train()

    # start time
    t0 = time.time()

    for step, data in enumerate(train_loader): 
        # send the data to cuda device
        ids = data[0].to(device, dtype = torch.long)
        mask = data[1].to(device, dtype = torch.long)
        target = data[2].float().to(device)   # 1 head
        # target = data[2].to(device, dtype = torch.long)   # 2 heads
        morgan_embedding = data[3].to(device)
    
        # compute output
        output = model(input_ids=ids, 
                       attention_mask=mask,
                       morgan_embedding=morgan_embedding
                      )

        # compute loss 
        # loss = criterion(output.view(-1, 2), target.view(-1))
        loss = criterion(output, target)

        # Accumulate the training loss over all of the batches 
        total_loss += loss.item()

        # zero out gradients in the optimizer each step
        optimizer.zero_grad()

        # Report progress every 200 batches
        if step % 2000 == 0 and not step == 0 and verbose==True:
            print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                 step, 
                 len(train_loader),
                 loss.item(),
                 format_time(time.time() - t0))) 
        
        # compute gradient and do SGD
        # backprop!
        loss.backward()
        
        # update the weights!
        optimizer.step()

        # update learning rate
        scheduler.step()

    avg_train_loss = total_loss / len(train_loader) 
    elapsed_time = time.time() - t0
    if verbose:
      print ("\nAvg Training Loss {:0.4f}, Completed in {:} \n".format(
          avg_train_loss,
          format_time(elapsed_time)
            ))
    
    # return model, avg_train_loss, elapsed_time
    return avg_train_loss, elapsed_time

# %%
## Define validate function
def validate(val_loader, model, criterion, verbose=True):
    # Initialize
    targets=[]
    outputs=[]
    t0 = time.time()
    total_val_loss = 0

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        for step, data in enumerate(val_loader):
            
            # send the data to cuda device
            ids = data[0].to(device, dtype = torch.long)
            mask = data[1].to(device, dtype = torch.long)
            target = data[2].float().to(device) # 1 head
            # target = data[2].to(device, dtype = torch.long)  # 2 heads
            morgan_embedding = data[3].to(device)
    
            # compute output
            output = model(input_ids=ids, 
                           attention_mask=mask,
                           morgan_embedding=morgan_embedding
                          )

            # compute loss
            loss = criterion(output, target)
            # loss = criterion(output.view(-1, 2), target.view(-1))

            # Accumulate the validation loss over all of the batches to calculate average loss
            total_val_loss += loss.item()

            targets.extend(target.cpu().detach().numpy().tolist())
            outputs.extend(output.cpu().detach().numpy().tolist())

            if step % 2000 == 0 and not step == 0 and verbose==True:
                print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                    step, 
                    len(val_loader),
                    loss.item(),
                    format_time(time.time() - t0)))        

    avg_val_loss = total_val_loss / len(val_loader)
    elapsed_time = time.time() - t0
    if verbose:
      print ("\nAvg Validation Loss {:0.4f}, Completed in {:}".format(
          avg_val_loss,
          format_time(elapsed_time)
            ))
    
    return outputs, targets, avg_val_loss, elapsed_time

# %%
# calculate the F1 score, auc, accuracy of our predictions vs labels
def compute_metrics(outputs, targets, prefix="Training"):
    y_pred = (np.array(outputs) >= 0.5).astype(float)  # 1 head
    y_score = np.array(outputs)  # 1 head
    # y_pred = np.argmax(outputs, axis=1)
    # softmax = np.exp(outputs) / np.sum(np.exp(outputs), axis=1, keepdims=True)
    # y_score = softmax[:, 1]
    y_true = np.array(targets)

    f2 =  metrics.fbeta_score(y_true, y_pred, average="binary", pos_label=1, beta=2)
    print(f"{prefix} F2-score: {round(f2,4)}")

    mcc = metrics.matthews_corrcoef(y_true, y_pred)
    print(f"{prefix} Matthew Correlation Coefficient: {round(mcc,4)}")

    recall_macro = metrics.recall_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Recall: {round(recall_macro,4)}")

    precision_macro = metrics.precision_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Precision: {round(precision_macro,4)}")

    accuracy_macro = metrics.accuracy_score(y_true, y_pred)
    print(f"{prefix} Accuracy: {round(accuracy_macro,4)}")
    
    return y_true, y_score, y_pred

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "TRUE"

# %%
# Store the average loss after each epoch so we can plot them.
train_loss_values = []
val_loss_values = []

for epoch in range(EPOCHS):
    print ('######  Epoch {}/{} ######'.format(epoch+1, EPOCHS))
    print ('-----  Training -----')
    train_loss, train_time = train(train_loader, model, criterion, optimizer)
    train_loss_values.append(train_loss)

    print ('-----  Validation -----')
    val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
    val_loss_values.append(val_loss)
    y_val_true, y_val_score, y_val_pred = compute_metrics(val_outputs, val_targets, prefix="Validation")
# Out:
# ######  Epoch 1/5 ######
# -----  Training -----
# Batch 2,000  of  18,693.  Loss 0.6320  Elapsed: 0:05:21.
# Batch 4,000  of  18,693.  Loss 0.7045  Elapsed: 0:10:34.
# Batch 6,000  of  18,693.  Loss 0.6316  Elapsed: 0:15:46.
# Batch 8,000  of  18,693.  Loss 0.6775  Elapsed: 0:20:58.
# Batch 10,000  of  18,693.  Loss 0.6116  Elapsed: 0:26:11.
# Batch 12,000  of  18,693.  Loss 0.6475  Elapsed: 0:31:23.
# Batch 14,000  of  18,693.  Loss 0.7384  Elapsed: 0:36:36.
# Batch 16,000  of  18,693.  Loss 0.7518  Elapsed: 0:41:49.
# Batch 18,000  of  18,693.  Loss 0.6613  Elapsed: 0:47:01.
#
# Avg Training Loss 0.6729, Completed in 0:49:00
#
# -----  Validation -----
#
# Avg Validation Loss 0.6807, Completed in 0:04:44
# Validation F2-score: 0.7179
# Validation Matthew Correlation Coefficient: 0.065
# Validation Recall: 0.7513
# Validation Precision: 0.6095
# Validation Accuracy: 0.5693
# ######  Epoch 2/5 ######
# -----  Training -----
# Batch 2,000  of  18,693.  Loss 0.6819  Elapsed: 0:05:22.
# Batch 4,000  of  18,693.  Loss 0.6470  Elapsed: 0:10:34.
# Batch 6,000  of  18,693.  Loss 0.6720  Elapsed: 0:15:47.
# Batch 8,000  of  18,693.  Loss 0.7338  Elapsed: 0:21:00.
# Batch 10,000  of  18,693.  Loss 0.5963  Elapsed: 0:26:14.
# Batch 12,000  of  18,693.  Loss 0.7653  Elapsed: 0:31:27.
# Batch 14,000  of  18,693.  Loss 0.7159  Elapsed: 0:36:39.
# Batch 16,000  of  18,693.  Loss 0.7512  Elapsed: 0:41:52.
# Batch 18,000  of  18,693.  Loss 0.6778  Elapsed: 0:47:04.
#
# Avg Training Loss 0.6565, Completed in 0:49:03
#
# -----  Validation -----
#
# Avg Validation Loss 0.7660, Completed in 0:04:43
# Validation F2-score: 0.2928
# Validation Matthew Correlation Coefficient: 0.1652
# Validation Recall: 0.254
# Validation Precision: 0.7529
# Validation Accuracy: 0.5108
# ######  Epoch 3/5 ######
# -----  Training -----
# Batch 2,000  of  18,693.  Loss 0.6597  Elapsed: 0:05:22.
# Batch 4,000  of  18,693.  Loss 0.5607  Elapsed: 0:10:35.
# Batch 6,000  of  18,693.  Loss 0.7498  Elapsed: 0:15:48.
# Batch 8,000  of  18,693.  Loss 0.5436  Elapsed: 0:21:01.
# Batch 10,000  of  18,693.  Loss 0.4606  Elapsed: 0:26:15.
# Batch 12,000  of  18,693.  Loss 0.6275  Elapsed: 0:31:27.
# Batch 14,000  of  18,693.  Loss 0.7099  Elapsed: 0:36:40.
# Batch 16,000  of  18,693.  Loss 0.6030  Elapsed: 0:41:54.
# Batch 18,000  of  18,693.  Loss 0.7517  Elapsed: 0:47:09.
#
# Avg Training Loss 0.6472, Completed in 0:49:08
#
# -----  Validation -----
#
# Avg Validation Loss 0.6619, Completed in 0:04:45
# Validation F2-score: 0.6846
# Validation Matthew Correlation Coefficient: 0.1656
# Validation Recall: 0.693
# Validation Precision: 0.6528
# Validation Accuracy: 0.6015
# ######  Epoch 4/5 ######
# -----  Training -----
# Batch 2,000  of  18,693.  Loss 0.7041  Elapsed: 0:05:24.
# Batch 4,000  of  18,693.  Loss 0.7326  Elapsed: 0:10:38.
# Batch 6,000  of  18,693.  Loss 0.8964  Elapsed: 0:15:53.
# Batch 8,000  of  18,693.  Loss 0.6763  Elapsed: 0:21:07.
# Batch 10,000  of  18,693.  Loss 0.6358  Elapsed: 0:26:22.
# Batch 12,000  of  18,693.  Loss 0.5766  Elapsed: 0:31:37.
# Batch 14,000  of  18,693.  Loss 0.6488  Elapsed: 0:36:52.
# Batch 16,000  of  18,693.  Loss 0.6391  Elapsed: 0:42:07.
# Batch 18,000  of  18,693.  Loss 0.5856  Elapsed: 0:47:22.
#
# Avg Training Loss 0.6399, Completed in 0:49:22
#
# -----  Validation -----
#
# Avg Validation Loss 0.6541, Completed in 0:04:45
# Validation F2-score: 0.6352
# Validation Matthew Correlation Coefficient: 0.2137
# Validation Recall: 0.6233
# Validation Precision: 0.688
# Validation Accuracy: 0.611
# ######  Epoch 5/5 ######
# -----  Training -----
# Batch 2,000  of  18,693.  Loss 0.6238  Elapsed: 0:05:24.
# Batch 4,000  of  18,693.  Loss 0.5899  Elapsed: 0:10:39.
# Batch 6,000  of  18,693.  Loss 0.7418  Elapsed: 0:15:53.
# Batch 8,000  of  18,693.  Loss 0.5394  Elapsed: 0:21:08.
# Batch 10,000  of  18,693.  Loss 0.6373  Elapsed: 0:26:22.
# Batch 12,000  of  18,693.  Loss 0.4950  Elapsed: 0:31:38.
# Batch 14,000  of  18,693.  Loss 0.6755  Elapsed: 0:36:53.
# Batch 16,000  of  18,693.  Loss 0.5545  Elapsed: 0:42:08.
# Batch 18,000  of  18,693.  Loss 0.5615  Elapsed: 0:47:23.
#
# Avg Training Loss 0.6357, Completed in 0:49:23
#
# -----  Validation -----
#
# Avg Validation Loss 0.6525, Completed in 0:04:46
# Validation F2-score: 0.6602
# Validation Matthew Correlation Coefficient: 0.2061
# Validation Recall: 0.6559
# Validation Precision: 0.6778
# Validation Accuracy: 0.6131

# %%
### Plot Training & Validation Loss
data = {'Epoch': range(1, 6), 'Training Loss': train_loss_values, 'Validation Loss': val_loss_values}
df = pd.DataFrame(data)

fig, ax = plt.subplots(figsize=(10, 6))
sns.set_style('whitegrid')
sns.set(font_scale=1.5)

# Plot train & val loss
sns.lineplot(data=df, x="Epoch", y="Training Loss", label="Training Loss", marker='o')
sns.lineplot(data=df, x="Epoch", y="Validation Loss", label="Validation Loss", marker='o')

# set the axis labels and title
ax.set(xlabel='Epoch', ylabel='Loss')
ax.set_title('Training and Validation Loss', fontsize=18)
ax.set_ylim(0)

# set the legend and adjust its position
plt.legend(fontsize=14)

# set the ticks fontsize
ax.tick_params(axis='both', which='major', labelsize=14)

# %%
torch.save(model.state_dict(), 'models/BioClinicalBertMorgan768Clusters.pth')

# %% [markdown]
# ### Evaluation

# %%
# Predicting with Test Set
print('\nEvaluation metrics for Test Set:')
test_outputs, test_targets, test_loss, test_time = validate(test_loader, model, criterion, verbose=True)
print()
y_test_true, y_test_score, y_test_pred = compute_metrics(test_outputs, test_targets, prefix="Testing")
# Out:
# Evaluation metrics for Test Set:
# Batch 2,000  of  13,504.  Loss 0.5495  Elapsed: 0:04:54.
# Batch 4,000  of  13,504.  Loss 0.6929  Elapsed: 0:09:40.
# Batch 6,000  of  13,504.  Loss 0.4974  Elapsed: 0:14:25.
# Batch 8,000  of  13,504.  Loss 0.6313  Elapsed: 0:19:11.
# Batch 10,000  of  13,504.  Loss 0.7052  Elapsed: 0:23:56.
# Batch 12,000  of  13,504.  Loss 0.7650  Elapsed: 0:28:42.
#
# Avg Validation Loss 0.6323, Completed in 0:32:27
#
# Testing F2-score: 0.7065
# Testing Matthew Correlation Coefficient: 0.2276
# Testing Recall: 0.7045
# Testing Precision: 0.7148
# Testing Accuracy: 0.6375

# %%
# Extract AUPRC & AP
def plot_AUPRC(y_true, y_score, title='Area Under Precision Recall Curve'):
    sns.set_style('white')
    plt.figure(figsize=(8,8))

    # Compute precision-recall pairs
    precision, recall, thresholds = precision_recall_curve(y_true, y_score)
    # Compute AUPRC
    auprc = auc(recall, precision)
    plt.plot(recall, precision, color="#663399", lw=2, alpha=0.9,
             label=f'AUPRC = {round(auprc, 3)})'
             )
    plt.xlabel('Recall', fontsize=14)
    plt.ylabel('Precision', fontsize=14)
    plt.ylim(bottom=0)
    plt.title(title, fontsize=16)
    plt.legend()
    plt.show()

plot_AUPRC(y_test_true, y_test_score)

# %%
target_names = ['class ' + str(x) for x in range(2)]
val_classification_report = classification_report(y_test_true, y_test_pred, target_names=target_names)
print("Validation Set - Classification Report:")
print(val_classification_report)
# Out:
# Validation Set - Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.51      0.52      0.52     80235
#      class 1       0.71      0.70      0.71    135828
#
#     accuracy                           0.64    216063
#    macro avg       0.61      0.61      0.61    216063
# weighted avg       0.64      0.64      0.64    216063

# %%
conf_matrix = confusion_matrix(y_test_true, y_test_pred)
conf_matrix = conf_matrix/conf_matrix.sum(axis=1, keepdims=True) * 100 #Convert to percentage
conf_matrix
# Out:
# array([[52.42101327, 47.57898673],
#        [29.5528168 , 70.4471832 ]])

# %%
def plot_conf_matrix_high(conf_matrix):
    """Plot confusion matrix"""
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(
        conf_matrix, annot=True,
        cmap=sns.cubehelix_palette(as_cmap=True),
        xticklabels= ['Negative', 'Positive'],
        yticklabels= ['Negative', 'Positive'],
        # fmt=',.0f'
        fmt='.1f'
    )
    ax.set_xlabel("Predicted Label", fontsize=16)
    ax.set_ylabel("True Label", fontsize=16)
    ax.set_title("Normalized Confusion Matrix (%)", fontsize=18)
    plt.show()

plot_conf_matrix_high(conf_matrix)

# %% [markdown]
# ## Double SMILES Morgan300 & BioClinicalBERT

# %% [markdown]
# ### Build Model

# %%
# Define hyperparameters
BATCH_SIZE = 24
EPOCHS = 30
LEARNING_RATE = 0.001
# MOMENTUM = 0.9
WEIGHT_DECAY = 0.01
WORKERS = int(os.cpu_count())

# %%
# BERT Model
class MorganBioBertClassification(nn.Module):
    def __init__(self,output_dim=1,
                 hidden_size=68, hidden_size2=54, hidden_size3=40,
                 dropout=0.1, unfreeze=False):
        super(MorganBioBertClassification, self).__init__()
        self.bert_model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

        # Unfreeze the last BERT transformer layer
        if unfreeze == "last layer":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "last two":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name or 'bert_model.encoder.layer.10' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "all layers":
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = True
        else:
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = False

        self.bert_hidden_size = self.bert_model.config.hidden_size
        self.hidden_size = hidden_size
        self.hidden_size2 = hidden_size2
        self.hidden_size3 = hidden_size3
        self.hidden_layer = nn.Linear(self.bert_hidden_size, self.hidden_size)
        self.hidden_layer2 = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3 = nn.Linear(self.hidden_size2, self.hidden_size3)

        # Morgan Embedding First hidden layer
        self.hidden_layer_morgan = nn.Linear(600, self.hidden_size)
        self.hidden_layer2_morgan = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3_morgan = nn.Linear(self.hidden_size2, self.hidden_size3)

        # One hidden Layer after combining both branches
        self.hidden_layer_combine = nn.Linear(2*self.hidden_size3, 16)

        self.drop_out = nn.Dropout(dropout)

        self.classification = nn.Linear(16, output_dim)

        self.GeLU = nn.GELU()
        self.Sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask, morgan_embedding):
        # Output for target data
        bert_output = self.bert_model(input_ids=input_ids,
                                      attention_mask=attention_mask)

        pooler_token = bert_output[1]

        hidden_ouput = self.GeLU(self.hidden_layer(pooler_token))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer2(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer3(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)

        # Output for SMILES Morgan Embedding
        hidden_morgan_output = self.GeLU(self.hidden_layer_morgan(morgan_embedding))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer2_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer3_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)

        # Concatenate hidden_output and morgan_output
        concat_output = torch.cat((hidden_morgan_output, hidden_ouput), 1)
        hidden_concat_output = self.GeLU(self.hidden_layer_combine(concat_output))
        hidden_concat_output = self.drop_out(hidden_concat_output)

        # logits = self.classification(x)
        output = self.Sigmoid(self.classification(hidden_concat_output))
        output = output.flatten()

        # return logits
        return output

# %%
# Initialize model
model = MorganBioBertClassification()
model = model.to(device)

#load the pre-trained Bio-ClinicalBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')

# Print out models params for checking
params = list(model.named_parameters())
for p in params[-30:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# bert_model.encoder.layer.11.attention.self.value.weight   (768, 768)
# bert_model.encoder.layer.11.attention.self.value.bias         (768,)
# bert_model.encoder.layer.11.attention.output.dense.weight   (768, 768)
# bert_model.encoder.layer.11.attention.output.dense.bias       (768,)
# bert_model.encoder.layer.11.attention.output.LayerNorm.weight       (768,)
# bert_model.encoder.layer.11.attention.output.LayerNorm.bias       (768,)
# bert_model.encoder.layer.11.intermediate.dense.weight    (3072, 768)
# bert_model.encoder.layer.11.intermediate.dense.bias          (3072,)
# bert_model.encoder.layer.11.output.dense.weight          (768, 3072)
# bert_model.encoder.layer.11.output.dense.bias                 (768,)
# bert_model.encoder.layer.11.output.LayerNorm.weight           (768,)
# bert_model.encoder.layer.11.output.LayerNorm.bias             (768,)
# bert_model.pooler.dense.weight                            (768, 768)
# bert_model.pooler.dense.bias                                  (768,)
# hidden_layer.weight                                        (68, 768)
# hidden_layer.bias                                              (68,)
# hidden_layer2.weight                                        (54, 68)
# hidden_layer2.bias                                             (54,)
# hidden_layer3.weight                                        (40, 54)
# hidden_layer3.bias                                             (40,)
# hidden_layer_morgan.weight                                 (68, 600)
# hidden_layer_morgan.bias                                       (68,)
# hidden_layer2_morgan.weight                                 (54, 68)
# hidden_layer2_morgan.bias                                      (54,)
# hidden_layer3_morgan.weight                                 (40, 54)
# hidden_layer3_morgan.bias                                      (40,)
# hidden_layer_combine.weight                                 (16, 80)
# hidden_layer_combine.bias                                      (16,)
# classification.weight                                        (1, 16)
# classification.bias                                             (1,)

# %% [markdown]
# ### Build DataLoader

# %%
# Import data
train_file = 'data/binary_ddi/ddi_train_balanced_150k.csv'
dev_file = 'data/binary_ddi/ddi_val_binary.csv'
test_file = 'data/binary_ddi/ddi_test_binary.csv'

df_train = pd.read_csv(train_file, sep='\t')
df_val= pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

print(f'''mean length of smiles1: {df_train['smiles1'].map(len).mean()}''')
print(f'''min length of smiles1: {df_train['smiles1'].map(len).min()}''')
print(f'''max length of smiles1: {df_train['smiles1'].map(len).max()}''')
print(f'''mean length of smiles2: {df_train['smiles2'].map(len).mean()}''')
print(f'''min length of smiles2: {df_train['smiles2'].map(len).min()}''')
print(f'''max length of smiles2: {df_train['smiles2'].map(len).max()}''')
print('Value Counts of Labels in Train Set:')
df_train.interaction_type.value_counts()
df_train.head(2)
# Out:
# mean length of smiles1: 62.479706666666665
# min length of smiles1: 2
# max length of smiles1: 748
# mean length of smiles2: 62.77145
# min length of smiles2: 3
# max length of smiles2: 748
# Value Counts of Labels in Train Set:
#         d1       d2                d1_name      d2_name  \
# 0  DB01156  DB00552              Bupropion  Pentostatin
# 1  DB09414  DB00542  Dipotassium phosphate   Benazepril
#
#                                          interaction  interaction_type  \
# 0  #Drug1 may decrease the excretion rate of #Dru...                 1
# 1  The risk or severity of hyperkalemia can be in...                 1
#
#   severity                            smiles1  \
# 0  unknown  CC(NC(C)(C)C)C(=O)C1=CC(Cl)=CC=C1
# 1     high         [K+].[K+].OP([O-])([O-])=O
#
#                                              smiles2
# 0    OC[C@H]1O[C@H](C[C@@H]1O)N1C=NC2=C1N=CNC[C@H]2O
# 1  [H][C@@]1(CCC2=CC=CC=C2N(CC(O)=O)C1=O)N[C@@H](...

# %%
from sklearn.utils import resample

# Choose a smaller subset of val data for faster training
df_val_small = resample(df_val,
                        replace=False,     # sample without replacement
                        n_samples=30000,
                        # random_state=1
                        )
print(df_val_small.shape)
df_val_small.head(2)
# Out:
# (30000, 9)
#              d1       d2                d1_name       d2_name  \
# 148095  DB08950  DB01614              Indoramin  Acepromazine
# 19472   DB01013  DB09289  Clobetasol propionate    Tianeptine
#
#                                               interaction  interaction_type  \
# 148095  #Drug2 may increase the orthostatic hypotensiv...                 1
# 19472   The metabolism of #Drug2 can be increased when...                 1
#
#        severity                                            smiles1  \
# 148095  unknown     O=C(NC1CCN(CCC2=CNC3=C2C=CC=C3)CC1)C1=CC=CC=C1
# 19472   unknown  [H][C@@]12C[C@H](C)[C@](OC(=O)CC)(C(=O)CCl)[C@...
#
#                                                   smiles2
# 148095         CN(C)CCCN1C2=CC=CC=C2SC2=C1C=C(C=C2)C(C)=O
# 19472   CN1C2=CC=CC=C2C(NCCCCCCC(O)=O)C2=C(C=C(Cl)C=C2...

# %%
# Import Drug2Vec Embedding - Morgan Fingerprints, Cosine Similarity
# drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_300clusters_morgan_cosine.txt", binary=False)
# Import Drug2Vec Embedding - Morgan Fingerprints, Tanimoto Similarity, 300 clusters
drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_300clusters_morgan_tanimoto.txt", binary=False)

print('Number of drugs available:', len(drug2vec_model.index_to_key))
print('Example - top 10 keys:', drug2vec_model.index_to_key[:10])
print('Embedding dimension:', len(drug2vec_model[drug2vec_model.index_to_key[0]]))
# Out:
# Number of drugs available: 2563
# Example - top 10 keys: ['DB00006', 'DB00007', 'DB00014', 'DB00027', 'DB00035', 'DB00067', 'DB00080', 'DB00091', 'DB00115', 'DB00118']
# Embedding dimension: 300

# %%
def build_data_loader(df, shuffle=True, verbose=False):
    # Extract Morgan Fingerprint Embedding
    # Remove the 4 SMILES causing error, only include SMILES in drug2vec.txt
    valid_smiles = drug2vec_model.index_to_key
    df = df[df['d1'].isin(valid_smiles) & df['d2'].isin(valid_smiles)]

    # Extract embedding
    df['d1_embedding'] = df['d1'].apply(lambda x: drug2vec_model[x])
    df['d2_embedding'] = df['d2'].apply(lambda x: drug2vec_model[x])

    # Drop all records that could not extract embedding (SMILES errors)
    df = df.dropna(subset=['d1_embedding', 'd2_embedding'], how='any')
    d1_embed = np.array(df['d1_embedding'].tolist())
    d2_embed = np.array(df['d2_embedding'].tolist())
    X_smiles = np.hstack((d1_embed, d2_embed))
    morgan_embedding = torch.from_numpy(X_smiles)
    if verbose:
        print('Drug1 Embedding Dimension:',d1_embed.shape)
        print('Drug2 Embedding Dimension:',d2_embed.shape)
        print('Drug 1 Concatenate with Drug 2 Embedding Dimension:', X_smiles.shape)
        print('Torch tensor Embedding Dimension:', morgan_embedding.shape)

    # Combine SMILES1 & SMILE2 Together, using [SEP] token to distingush between drug1 & drug2
    df["features"] = df["smiles1"].str[:254] + " [SEP] " + df["smiles2"].str[:254]
    X = df["features"]
    y = df["interaction_type"]

    # Combine Target2 and Target2 Together, using [SEP] token to distingush between drug1 & drug2
    # df["target_features"] = "Drug1: " + df["d1_target_action"] + " [SEP] " + "Drug2: " + df["d2_target_action"] + " [SEP]"
    # X_target = df["target_features"]

    # Tokenize Target
    _encodings = tokenizer(
        list(X.values),
        max_length=512,
        truncation=True,
        pad_to_max_length=True,
        return_token_type_ids=False,
        return_tensors='pt'
    )

    _ids = _encodings.input_ids
    _mask = _encodings.attention_mask
    _labels = torch.tensor(y.values)
    if verbose:
        print('Torch tensor target_ids Dimension:', _ids.shape)
        print('Torch tensor labels Dimension:', _labels.shape)

    _dataset = TensorDataset(_ids, _mask, _labels, morgan_embedding)
    _loader = DataLoader(_dataset, batch_size=BATCH_SIZE, shuffle=shuffle, num_workers=WORKERS)

    return _loader

# %%
# Val Data Loader
print('Validation Data Loader:')
val_loader = build_data_loader(df_val_small, shuffle=False, verbose=True)
# Out:
# Validation Data Loader:
# Drug1 Embedding Dimension: (29961, 300)
# Drug2 Embedding Dimension: (29961, 300)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (29961, 600)
# Torch tensor Embedding Dimension: torch.Size([29961, 600])
# Torch tensor target_ids Dimension: torch.Size([29961, 512])
# Torch tensor labels Dimension: torch.Size([29961])

# %%
# Train Data Loader
print('Testing Data Loader:')
test_loader = build_data_loader(df_test, verbose=True)
# Out:
# Testing Data Loader:
# Drug1 Embedding Dimension: (186487, 300)
# Drug2 Embedding Dimension: (186487, 300)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (186487, 600)
# Torch tensor Embedding Dimension: torch.Size([186487, 600])
# Torch tensor target_ids Dimension: torch.Size([186487, 512])
# Torch tensor labels Dimension: torch.Size([186487])

# %%
# Train Data Loader
print('Training Data Loader:')
train_loader = build_data_loader(df_train, verbose=True)
# Out:
# Training Data Loader:
# Drug1 Embedding Dimension: (299117, 300)
# Drug2 Embedding Dimension: (299117, 300)
# Drug 1 Concatenate with Drug 2 Embedding Dimension: (299117, 600)
# Torch tensor Embedding Dimension: torch.Size([299117, 600])
# Torch tensor target_ids Dimension: torch.Size([299117, 512])
# Torch tensor labels Dimension: torch.Size([299117])

# %%
print('Train batches:', len(train_loader))
print('Val subset batches:', len(val_loader))
print('Test batches:', len(test_loader))
# Out:
# Train batches: 12464
# Val subset batches: 1249
# Test batches: 7771

# %% [markdown]
# ### Training
# #### Learning Rate Finder

# %%
model = MorganBioBertClassification()
model = model.to(device)

# Initiate loss to Binary Cross Entropy
criterion = nn.BCELoss()

# Optimizer
# optimizer = optim.Adadelta(model.parameters(), lr=1e-7, weight_decay=1e-2)
optimizer = optim.AdamW(model.parameters(), lr=1e-7, weight_decay=1e-2)
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Function to adjust the Learning Rate manually for Finding a good learning rate
# Increase LR from 1e-7 to 10 in exponential manner
n_step_lr = 100
learning_rates = np.logspace(-7, 0, n_step_lr)

def adjust_learning_rate(optimizer, step):
    """This function is for testing different learning rate in an epoch to find the best LR range"""
    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rates[step]

learning_rates
# Out:
# array([1.00000000e-07, 1.17681195e-07, 1.38488637e-07, 1.62975083e-07,
#        1.91791026e-07, 2.25701972e-07, 2.65608778e-07, 3.12571585e-07,
#        3.67837977e-07, 4.32876128e-07, 5.09413801e-07, 5.99484250e-07,
#        7.05480231e-07, 8.30217568e-07, 9.77009957e-07, 1.14975700e-06,
#        1.35304777e-06, 1.59228279e-06, 1.87381742e-06, 2.20513074e-06,
#        2.59502421e-06, 3.05385551e-06, 3.59381366e-06, 4.22924287e-06,
#        4.97702356e-06, 5.85702082e-06, 6.89261210e-06, 8.11130831e-06,
#        9.54548457e-06, 1.12332403e-05, 1.32194115e-05, 1.55567614e-05,
#        1.83073828e-05, 2.15443469e-05, 2.53536449e-05, 2.98364724e-05,
#        3.51119173e-05, 4.13201240e-05, 4.86260158e-05, 5.72236766e-05,
#        6.73415066e-05, 7.92482898e-05, 9.32603347e-05, 1.09749877e-04,
#        1.29154967e-04, 1.51991108e-04, 1.78864953e-04, 2.10490414e-04,
#        2.47707636e-04, 2.91505306e-04, 3.43046929e-04, 4.03701726e-04,
#        4.75081016e-04, 5.59081018e-04, 6.57933225e-04, 7.74263683e-04,
#        9.11162756e-04, 1.07226722e-03, 1.26185688e-03, 1.48496826e-03,
#        1.74752840e-03, 2.05651231e-03, 2.42012826e-03, 2.84803587e-03,
#        3.35160265e-03, 3.94420606e-03, 4.64158883e-03, 5.46227722e-03,
#        6.42807312e-03, 7.56463328e-03, 8.90215085e-03, 1.04761575e-02,
#        1.23284674e-02, 1.45082878e-02, 1.70735265e-02, 2.00923300e-02,
#        2.36448941e-02, 2.78255940e-02, 3.27454916e-02, 3.85352859e-02,
#        4.53487851e-02, 5.33669923e-02, 6.28029144e-02, 7.39072203e-02,
#        8.69749003e-02, 1.02353102e-01, 1.20450354e-01, 1.41747416e-01,
#        1.66810054e-01, 1.96304065e-01, 2.31012970e-01, 2.71858824e-01,
#        3.19926714e-01, 3.76493581e-01, 4.43062146e-01, 5.21400829e-01,
#        6.13590727e-01, 7.22080902e-01, 8.49753436e-01, 1.00000000e+00])

# %%
def format_time(seconds):
    return str(datetime.timedelta(seconds=int(round(seconds))))

# %%
import math

## Define Learning Rate Finding fuction
def train_LRFinder(train_loader, model, criterion, optimizer, verbose=True):
    # reset total loss for each epoch
    total_loss = 0

    # LR Finding initialization
    losses = []
    lrs = []
    loss_100iters = 0


    # switch model to train mode
    model.train()

    # start time
    t0 = time.time()

    for step, data in enumerate(train_loader):
        # zero out gradients in the optimizer each step
        optimizer.zero_grad()

        # send the data to cuda device
        ids = data[0].to(device, dtype = torch.long)
        mask = data[1].to(device, dtype = torch.long)
        target = data[2].float().to(device)
        morgan_embedding = data[3].to(device)
    
        # compute output
        output = model(input_ids=ids, 
                       attention_mask=mask,
                       morgan_embedding=morgan_embedding
                      )

        # compute loss
        loss = criterion(output, target)

        # Accumulate the training loss over all of the batches
        total_loss += loss.item()
        loss_100iters += loss.item()

        # compute gradient
        # backprop!
        loss.backward()

        # update the weights!
        optimizer.step()

        # Report progress
        update_lr_step = int(math.ceil(len(train_loader)/n_step_lr))  #step = 125
        if step % update_lr_step == 0 and not step == 0 and verbose==True:
            n_iter_lr = int(step//update_lr_step)
            # Average loss for the current LR
            loss_100iters = loss_100iters / update_lr_step
            lr = learning_rates[n_iter_lr]

            print('Batch {:>5,}  of  {:>5,}.   Step Loss {:0.4f}   Avg Loss {:0.4f}   Learning Rate {:}    Elapsed: {:}.'.format(
                step,
                len(train_loader),
                loss.item(),
                loss_100iters,
                lr,
                format_time(time.time() - t0)))

            # Add loss & lr to list for ploting later
            losses.append(loss_100iters)
            lrs.append(lr)

            # update learning rate
            # scheduler.step()
            adjust_learning_rate(optimizer, n_iter_lr)

            # Reset loss for next lr
            loss_100iters = 0

    # Last iteration
    resid = len(train_loader) - 125*(n_step_lr-1)
    loss_100iters = loss_100iters / resid
    # Add loss & lr to list for ploting later
    losses.append(loss_100iters)
    lrs.append(learning_rates[-1])

    avg_train_loss = total_loss / len(train_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Training Loss {:0.4f}, Completed in {:} \n".format(
            avg_train_loss,
            format_time(elapsed_time)
        ))

    # return model, avg_train_loss, elapsed_time
    return losses, lrs

# %%
len(train_loader) - 125*(n_step_lr-1)
# Out:
# 89

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "TRUE"

# %%
print ('-----  Learning Rate Finder -----')
losses, lrs = train_LRFinder(train_loader, model, criterion, optimizer)
print('Losses Dim:', len(losses))
print('LR Dim:', len(lrs))
# Out:
# -----  Learning Rate Finder -----
# Batch   125  of  12,464.   Step Loss 0.6962   Avg Loss 0.6990   Learning Rate 1.1768119524349991e-07    Elapsed: 0:00:31.
# Batch   250  of  12,464.   Step Loss 0.6949   Avg Loss 0.6935   Learning Rate 1.3848863713938718e-07    Elapsed: 0:00:59.
# Batch   375  of  12,464.   Step Loss 0.6983   Avg Loss 0.6940   Learning Rate 1.6297508346206436e-07    Elapsed: 0:01:28.
# Batch   500  of  12,464.   Step Loss 0.6959   Avg Loss 0.6936   Learning Rate 1.9179102616724887e-07    Elapsed: 0:01:56.
# Batch   625  of  12,464.   Step Loss 0.6966   Avg Loss 0.6937   Learning Rate 2.2570197196339216e-07    Elapsed: 0:02:25.
# Batch   750  of  12,464.   Step Loss 0.6983   Avg Loss 0.6940   Learning Rate 2.656087782946684e-07    Elapsed: 0:02:53.
# Batch   875  of  12,464.   Step Loss 0.6884   Avg Loss 0.6931   Learning Rate 3.125715849688235e-07    Elapsed: 0:03:22.
# Batch 1,000  of  12,464.   Step Loss 0.6973   Avg Loss 0.6934   Learning Rate 3.678379771828634e-07    Elapsed: 0:03:50.
# Batch 1,125  of  12,464.   Step Loss 0.6935   Avg Loss 0.6935   Learning Rate 4.3287612810830616e-07    Elapsed: 0:04:19.
# Batch 1,250  of  12,464.   Step Loss 0.6955   Avg Loss 0.6935   Learning Rate 5.094138014816375e-07    Elapsed: 0:04:47.
# Batch 1,375  of  12,464.   Step Loss 0.6902   Avg Loss 0.6932   Learning Rate 5.994842503189409e-07    Elapsed: 0:05:15.
# Batch 1,500  of  12,464.   Step Loss 0.6996   Avg Loss 0.6941   Learning Rate 7.054802310718645e-07    Elapsed: 0:05:44.
# Batch 1,625  of  12,464.   Step Loss 0.7013   Avg Loss 0.6934   Learning Rate 8.302175681319736e-07    Elapsed: 0:06:12.
# Batch 1,750  of  12,464.   Step Loss 0.6919   Avg Loss 0.6935   Learning Rate 9.770099572992247e-07    Elapsed: 0:06:41.
# Batch 1,875  of  12,464.   Step Loss 0.6956   Avg Loss 0.6937   Learning Rate 1.1497569953977357e-06    Elapsed: 0:07:09.
# Batch 2,000  of  12,464.   Step Loss 0.6949   Avg Loss 0.6932   Learning Rate 1.3530477745798075e-06    Elapsed: 0:07:38.
# Batch 2,125  of  12,464.   Step Loss 0.6933   Avg Loss 0.6931   Learning Rate 1.592282793341094e-06    Elapsed: 0:08:06.
# Batch 2,250  of  12,464.   Step Loss 0.6935   Avg Loss 0.6930   Learning Rate 1.873817422860383e-06    Elapsed: 0:08:35.
# Batch 2,375  of  12,464.   Step Loss 0.6864   Avg Loss 0.6930   Learning Rate 2.2051307399030456e-06    Elapsed: 0:09:03.
# Batch 2,500  of  12,464.   Step Loss 0.6943   Avg Loss 0.6938   Learning Rate 2.5950242113997373e-06    Elapsed: 0:09:32.
# Batch 2,625  of  12,464.   Step Loss 0.6961   Avg Loss 0.6931   Learning Rate 3.0538555088334123e-06    Elapsed: 0:10:00.
# Batch 2,750  of  12,464.   Step Loss 0.6910   Avg Loss 0.6931   Learning Rate 3.5938136638046257e-06    Elapsed: 0:10:29.
# Batch 2,875  of  12,464.   Step Loss 0.6976   Avg Loss 0.6936   Learning Rate 4.229242874389499e-06    Elapsed: 0:10:57.
# Batch 3,000  of  12,464.   Step Loss 0.6969   Avg Loss 0.6936   Learning Rate 4.977023564332114e-06    Elapsed: 0:11:25.
# Batch 3,125  of  12,464.   Step Loss 0.6967   Avg Loss 0.6935   Learning Rate 5.857020818056661e-06    Elapsed: 0:11:54.
# Batch 3,250  of  12,464.   Step Loss 0.6914   Avg Loss 0.6934   Learning Rate 6.892612104349695e-06    Elapsed: 0:12:22.
# Batch 3,375  of  12,464.   Step Loss 0.6903   Avg Loss 0.6933   Learning Rate 8.111308307896873e-06    Elapsed: 0:12:51.
# Batch 3,500  of  12,464.   Step Loss 0.6940   Avg Loss 0.6929   Learning Rate 9.545484566618328e-06    Elapsed: 0:13:19.
# Batch 3,625  of  12,464.   Step Loss 0.6901   Avg Loss 0.6932   Learning Rate 1.1233240329780266e-05    Elapsed: 0:13:48.
# Batch 3,750  of  12,464.   Step Loss 0.6956   Avg Loss 0.6932   Learning Rate 1.3219411484660286e-05    Elapsed: 0:14:16.
# Batch 3,875  of  12,464.   Step Loss 0.6908   Avg Loss 0.6930   Learning Rate 1.5556761439304724e-05    Elapsed: 0:14:45.
# Batch 4,000  of  12,464.   Step Loss 0.6968   Avg Loss 0.6930   Learning Rate 1.8307382802953696e-05    Elapsed: 0:15:13.
# Batch 4,125  of  12,464.   Step Loss 0.6946   Avg Loss 0.6931   Learning Rate 2.1544346900318823e-05    Elapsed: 0:15:42.
# Batch 4,250  of  12,464.   Step Loss 0.6939   Avg Loss 0.6927   Learning Rate 2.5353644939701114e-05    Elapsed: 0:16:10.
# Batch 4,375  of  12,464.   Step Loss 0.6918   Avg Loss 0.6925   Learning Rate 2.9836472402833343e-05    Elapsed: 0:16:38.
# Batch 4,500  of  12,464.   Step Loss 0.6913   Avg Loss 0.6925   Learning Rate 3.511191734215127e-05    Elapsed: 0:17:07.
# Batch 4,625  of  12,464.   Step Loss 0.6936   Avg Loss 0.6924   Learning Rate 4.1320124001153344e-05    Elapsed: 0:17:35.
# Batch 4,750  of  12,464.   Step Loss 0.6832   Avg Loss 0.6914   Learning Rate 4.8626015800653536e-05    Elapsed: 0:18:04.
# Batch 4,875  of  12,464.   Step Loss 0.6946   Avg Loss 0.6907   Learning Rate 5.72236765935022e-05    Elapsed: 0:18:32.
# Batch 5,000  of  12,464.   Step Loss 0.6765   Avg Loss 0.6889   Learning Rate 6.734150657750829e-05    Elapsed: 0:19:01.
# Batch 5,125  of  12,464.   Step Loss 0.6796   Avg Loss 0.6881   Learning Rate 7.92482898353917e-05    Elapsed: 0:19:29.
# Batch 5,250  of  12,464.   Step Loss 0.6921   Avg Loss 0.6870   Learning Rate 9.326033468832199e-05    Elapsed: 0:19:58.
# Batch 5,375  of  12,464.   Step Loss 0.6651   Avg Loss 0.6844   Learning Rate 0.00010974987654930556    Elapsed: 0:20:26.
# Batch 5,500  of  12,464.   Step Loss 0.6504   Avg Loss 0.6795   Learning Rate 0.0001291549665014884    Elapsed: 0:20:54.
# Batch 5,625  of  12,464.   Step Loss 0.6674   Avg Loss 0.6798   Learning Rate 0.0001519911082952933    Elapsed: 0:21:23.
# Batch 5,750  of  12,464.   Step Loss 0.6777   Avg Loss 0.6784   Learning Rate 0.0001788649529057435    Elapsed: 0:21:51.
# Batch 5,875  of  12,464.   Step Loss 0.7004   Avg Loss 0.6789   Learning Rate 0.00021049041445120198    Elapsed: 0:22:20.
# Batch 6,000  of  12,464.   Step Loss 0.5852   Avg Loss 0.6719   Learning Rate 0.0002477076355991709    Elapsed: 0:22:48.
# Batch 6,125  of  12,464.   Step Loss 0.6527   Avg Loss 0.6777   Learning Rate 0.0002915053062825176    Elapsed: 0:23:17.
# Batch 6,250  of  12,464.   Step Loss 0.6315   Avg Loss 0.6747   Learning Rate 0.0003430469286314916    Elapsed: 0:23:45.
# Batch 6,375  of  12,464.   Step Loss 0.5947   Avg Loss 0.6786   Learning Rate 0.0004037017258596554    Elapsed: 0:24:14.
# Batch 6,500  of  12,464.   Step Loss 0.6670   Avg Loss 0.6740   Learning Rate 0.00047508101621027935    Elapsed: 0:24:42.
# Batch 6,625  of  12,464.   Step Loss 0.6744   Avg Loss 0.6683   Learning Rate 0.0005590810182512223    Elapsed: 0:25:10.
# Batch 6,750  of  12,464.   Step Loss 0.6673   Avg Loss 0.6737   Learning Rate 0.0006579332246575676    Elapsed: 0:25:39.
# Batch 6,875  of  12,464.   Step Loss 0.6539   Avg Loss 0.6842   Learning Rate 0.000774263682681127    Elapsed: 0:26:07.
# Batch 7,000  of  12,464.   Step Loss 0.6722   Avg Loss 0.6723   Learning Rate 0.0009111627561154887    Elapsed: 0:26:36.
# Batch 7,125  of  12,464.   Step Loss 0.6438   Avg Loss 0.6758   Learning Rate 0.0010722672220103231    Elapsed: 0:27:04.
# Batch 7,250  of  12,464.   Step Loss 0.6667   Avg Loss 0.6841   Learning Rate 0.0012618568830660211    Elapsed: 0:27:33.
# Batch 7,375  of  12,464.   Step Loss 0.8331   Avg Loss 0.6745   Learning Rate 0.0014849682622544635    Elapsed: 0:28:01.
# Batch 7,500  of  12,464.   Step Loss 0.6840   Avg Loss 0.6832   Learning Rate 0.001747528400007683    Elapsed: 0:28:30.
# Batch 7,625  of  12,464.   Step Loss 0.7073   Avg Loss 0.6830   Learning Rate 0.0020565123083486517    Elapsed: 0:28:58.
# Batch 7,750  of  12,464.   Step Loss 0.6728   Avg Loss 0.6793   Learning Rate 0.0024201282647943836    Elapsed: 0:29:26.
# Batch 7,875  of  12,464.   Step Loss 0.6228   Avg Loss 0.6796   Learning Rate 0.002848035868435799    Elapsed: 0:29:55.
# Batch 8,000  of  12,464.   Step Loss 0.6970   Avg Loss 0.6763   Learning Rate 0.003351602650938841    Elapsed: 0:30:23.
# Batch 8,125  of  12,464.   Step Loss 0.6760   Avg Loss 0.6813   Learning Rate 0.003944206059437656    Elapsed: 0:30:52.
# Batch 8,250  of  12,464.   Step Loss 0.7265   Avg Loss 0.6873   Learning Rate 0.004641588833612773    Elapsed: 0:31:20.
# Batch 8,375  of  12,464.   Step Loss 0.6919   Avg Loss 0.6873   Learning Rate 0.005462277217684337    Elapsed: 0:31:49.
# Batch 8,500  of  12,464.   Step Loss 0.6884   Avg Loss 0.6948   Learning Rate 0.006428073117284319    Elapsed: 0:32:17.
# Batch 8,625  of  12,464.   Step Loss 0.6924   Avg Loss 0.6925   Learning Rate 0.007564633275546291    Elapsed: 0:32:46.
# Batch 8,750  of  12,464.   Step Loss 0.7005   Avg Loss 0.6932   Learning Rate 0.008902150854450374    Elapsed: 0:33:14.
# Batch 8,875  of  12,464.   Step Loss 0.6953   Avg Loss 0.6958   Learning Rate 0.010476157527896641    Elapsed: 0:33:42.
# Batch 9,000  of  12,464.   Step Loss 0.6858   Avg Loss 0.6933   Learning Rate 0.012328467394420659    Elapsed: 0:34:11.
# Batch 9,125  of  12,464.   Step Loss 0.6892   Avg Loss 0.6948   Learning Rate 0.014508287784959401    Elapsed: 0:34:39.
# Batch 9,250  of  12,464.   Step Loss 0.6862   Avg Loss 0.6948   Learning Rate 0.017073526474706887    Elapsed: 0:35:08.
# Batch 9,375  of  12,464.   Step Loss 0.6917   Avg Loss 0.6951   Learning Rate 0.02009233002565046    Elapsed: 0:35:36.
# Batch 9,500  of  12,464.   Step Loss 0.6946   Avg Loss 0.6937   Learning Rate 0.023644894126454073    Elapsed: 0:36:05.
# Batch 9,750  of  12,464.   Step Loss 0.6915   Avg Loss 0.6940   Learning Rate 0.03274549162877725    Elapsed: 0:37:02.
# Batch 9,875  of  12,464.   Step Loss 0.6898   Avg Loss 0.6944   Learning Rate 0.03853528593710527    Elapsed: 0:37:30.
# Batch 10,000  of  12,464.   Step Loss 4.8358   Avg Loss 3.1680   Learning Rate 0.04534878508128582    Elapsed: 0:37:58.
# Batch 10,125  of  12,464.   Step Loss 8.9687   Avg Loss 5.9554   Learning Rate 0.053366992312063016    Elapsed: 0:38:27.
# Batch 10,250  of  12,464.   Step Loss 4.7983   Avg Loss 5.4574   Learning Rate 0.06280291441834246    Elapsed: 0:38:55.
# Batch 10,375  of  12,464.   Step Loss 13.0732   Avg Loss 5.8876   Learning Rate 0.07390722033525775    Elapsed: 0:39:24.
# Batch 10,500  of  12,464.   Step Loss 0.6897   Avg Loss 5.0620   Learning Rate 0.08697490026177834    Elapsed: 0:39:52.
# Batch 10,625  of  12,464.   Step Loss 4.8354   Avg Loss 6.0888   Learning Rate 0.10235310218990247    Elapsed: 0:40:21.
# Batch 10,750  of  12,464.   Step Loss 0.6941   Avg Loss 1.8117   Learning Rate 0.12045035402587811    Elapsed: 0:40:49.
# Batch 10,875  of  12,464.   Step Loss 0.7153   Avg Loss 0.7282   Learning Rate 0.14174741629268048    Elapsed: 0:41:17.
# Batch 11,000  of  12,464.   Step Loss 0.6904   Avg Loss 0.6952   Learning Rate 0.1668100537200059    Elapsed: 0:41:46.
# Batch 11,125  of  12,464.   Step Loss 0.6765   Avg Loss 0.7305   Learning Rate 0.19630406500402683    Elapsed: 0:42:14.
# Batch 11,250  of  12,464.   Step Loss 45.8354   Avg Loss 25.8452   Learning Rate 0.2310129700083158    Elapsed: 0:42:43.
# Batch 11,375  of  12,464.   Step Loss 45.8333   Avg Loss 49.5338   Learning Rate 0.271858824273294    Elapsed: 0:43:11.
# Batch 11,500  of  12,464.   Step Loss 58.3333   Avg Loss 48.2033   Learning Rate 0.31992671377973847    Elapsed: 0:43:40.
# Batch 11,625  of  12,464.   Step Loss 62.5000   Avg Loss 49.4667   Learning Rate 0.3764935806792464    Elapsed: 0:44:08.
# Batch 11,750  of  12,464.   Step Loss 37.5000   Avg Loss 49.1098   Learning Rate 0.44306214575838776    Elapsed: 0:44:37.
# Batch 11,875  of  12,464.   Step Loss 45.8333   Avg Loss 49.3106   Learning Rate 0.5214008287999684    Elapsed: 0:45:05.
# Batch 12,000  of  12,464.   Step Loss 29.1667   Avg Loss 50.8374   Learning Rate 0.6135907273413164    Elapsed: 0:45:34.
# Batch 12,125  of  12,464.   Step Loss 50.0000   Avg Loss 50.2000   Learning Rate 0.7220809018385457    Elapsed: 0:46:02.
# Batch 12,250  of  12,464.   Step Loss 54.1667   Avg Loss 50.1760   Learning Rate 0.8497534359086438    Elapsed: 0:46:31.
# Batch 12,375  of  12,464.   Step Loss 29.1667   Avg Loss 48.5000   Learning Rate 1.0    Elapsed: 0:46:59.
#
# Avg Training Loss 5.9972, Completed in 0:47:22
#
# Losses Dim: 100
# LR Dim: 100

# %%
plt.title("Learning Rate Finder")
plt.ylabel("Loss")
plt.xlabel("Learning Rate (log scale)")
plt.plot(lrs[:80], losses[:80])
plt.xscale('log')

# %%
plt.title("Learning Rate Finder - Zoomed In")
plt.ylabel("Loss")
plt.xlabel("Learning Rate (log scale)")
plt.plot(lrs[:79], losses[:79])
plt.xscale('log')

# %% [markdown]
# #### Training with Best LR

# %%
# Define hyperparameters
BATCH_SIZE = 24
EPOCHS = 50
# LEARNING_RATE = 0.0006 #start epoch1
LEARNING_RATE = 0.0001 #start epoch60
WEIGHT_DECAY = 1e-2
WORKERS = int(os.cpu_count())

# %%
# from transformers import get_linear_schedule_with_warmup
# Initialize Model
model = MorganBioBertClassification(unfreeze=False)

# Continue training
model = model.to(device)
checkpoint = torch.load("models/checkpoint_ep59.pth.tar") # Load from epoch 59
model.load_state_dict(checkpoint['state_dict'])

# Initiate loss to Binary Cross Entropy
criterion = nn.BCELoss()

# Optimizer
# optimizer = optim.Adadelta(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Create learning rate scheduler.
T_max = EPOCHS*len(train_loader)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min = 1e-6)
# scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*T_max, num_training_steps=T_max)
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
## Define train function
def train(train_loader, model, criterion, optimizer, verbose=True):
    # reset total loss for each epoch
    total_loss = 0

    # switch model to train mode
    model.train()

    # start time
    t0 = time.time()

    for step, data in enumerate(train_loader):
        # zero out gradients in the optimizer each step
        optimizer.zero_grad()

        # send the data to cuda device
        ids = data[0].to(device, dtype = torch.long)
        mask = data[1].to(device, dtype = torch.long)
        target = data[2].float().to(device)   # 1 head
        # target = data[2].to(device, dtype = torch.long)   # 2 heads
        morgan_embedding = data[3].to(device)
    
        # compute output
        output = model(input_ids=ids, 
                       attention_mask=mask,
                       morgan_embedding=morgan_embedding
                      )

        # compute loss
        loss = criterion(output, target)

        # Accumulate the training loss over all of the batches
        total_loss += loss.item()

        # Report progress every 200 batches
        if step % 1000 == 0 and not step == 0 and verbose==True:
            print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                step,
                len(train_loader),
                loss.item(),
                format_time(time.time() - t0)))

        # compute gradient and do SGD
        # backprop!
        loss.backward()

        # update the weights!
        optimizer.step()

        # update learning rate with scheduler
        scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Training Loss {:0.4f}, Completed in {:} \n".format(
            avg_train_loss,
            format_time(elapsed_time)
        ))

    # return model, avg_train_loss, elapsed_time
    return avg_train_loss, elapsed_time

# %%
## Define validate function
def validate(val_loader, model, criterion, verbose=True):
    # Initialize
    targets=[]
    outputs=[]
    t0 = time.time()
    total_val_loss = 0

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        for step, data in enumerate(val_loader):

            # send the data to cuda device
            ids = data[0].to(device, dtype = torch.long)
            mask = data[1].to(device, dtype = torch.long)
            target = data[2].float().to(device)
            morgan_embedding = data[3].to(device)
        
            # compute output
            output = model(input_ids=ids, 
                           attention_mask=mask,
                           morgan_embedding=morgan_embedding
                          )

            # compute loss
            loss = criterion(output, target)

            # Accumulate the validation loss over all of the batches to calculate average loss
            total_val_loss += loss.item()

            targets.extend(target.cpu().detach().numpy().tolist())
            outputs.extend(output.cpu().detach().numpy().tolist())

            if step % 1000 == 0 and not step == 0 and verbose==True:
                print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                    step,
                    len(val_loader),
                    loss.item(),
                    format_time(time.time() - t0)))

    avg_val_loss = total_val_loss / len(val_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Validation Loss {:0.4f}, Completed in {:}".format(
            avg_val_loss,
            format_time(elapsed_time)
        ))

    return outputs, targets, avg_val_loss, elapsed_time

# %%
# calculate the F1 score, auc, accuracy of our predictions vs labels
def compute_metrics(outputs, targets, prefix="Training"):
    y_pred = (np.array(outputs) >= 0.5).astype(float)
    y_score = np.array(outputs)
    y_true = np.array(targets)

    f2 =  metrics.fbeta_score(y_true, y_pred, average="binary", pos_label=1, beta=2)
    print(f"{prefix} F2-score: {round(f2,4)}")

    mcc = metrics.matthews_corrcoef(y_true, y_pred)
    print(f"{prefix} Matthew Correlation Coefficient: {round(mcc,4)}")

    recall_macro = metrics.recall_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Recall: {round(recall_macro,4)}")

    precision_macro = metrics.precision_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Precision: {round(precision_macro,4)}")

    accuracy_macro = metrics.accuracy_score(y_true, y_pred)
    print(f"{prefix} Accuracy: {round(accuracy_macro,4)}")

    return y_true, y_score, y_pred, accuracy_macro

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "TRUE"

# %%
filename = "models/checkpoint.pth.tar"

def save_checkpoint(state, is_best, filename=filename):
    torch.save(state, filename)

    if is_best:
        shutil.copyfile(filename, 'models/model_best.pth.tar')

# %%
# ##### Test LR = 6.28e-4, Optim = AdamW
# # Store the average loss after each epoch so we can plot them.
# best_train_loss = 1e5
# train_loss_values = []
# val_loss_values = []
# learning_rates = []

# for epoch in range(EPOCHS):
#     print ('######  Epoch {}/{} ######'.format(epoch+1, EPOCHS))
#     print('Learning rate:', str(scheduler.get_last_lr()[0]))
#     print()
#     learning_rates.append(scheduler.get_last_lr())

#     print ('-----  Training -----')
#     train_loss, train_time = train(train_loader, model, criterion, optimizer)
#     train_loss_values.append(train_loss)

#     print ('-----  Validation -----')
#     val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
#     val_loss_values.append(val_loss)
#     y_val_true, y_val_score, y_val_pred = compute_metrics(val_outputs, val_targets, prefix="Validation")
#     print()

#     # Get the best loss
#     is_best = train_loss < best_train_loss
#     best_train_loss = min(train_loss, best_train_loss)

#     # Save Checkpoint
#     save_checkpoint(
#         {'epoch': epoch+1,
#          'state_dict': model.state_dict(),
#          'best_train_loss': best_train_loss,
#          'optimizer': optimizer.state_dict()
#          },
#         is_best
#     )

#     if best_train_loss < 0.2:
#         break
# Out:
# ######  Epoch 1/30 ######
# Learning rate: 0.0005903778297738204
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6212  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6589  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.5187  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.6188  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.5939  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.5730  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.6895  Elapsed: 0:26:35.
# Batch 8,000  of  12,464.  Loss 0.7123  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.5212  Elapsed: 0:34:10.
# Batch 10,000  of  12,464.  Loss 0.5191  Elapsed: 0:37:58.
# Batch 11,000  of  12,464.  Loss 0.7438  Elapsed: 0:41:45.
# Batch 12,000  of  12,464.  Loss 0.7242  Elapsed: 0:45:32.
#
# Avg Training Loss 0.6057, Completed in 0:47:20
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5665  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6702, Completed in 0:04:21
# Validation F2-score: 0.6756
# Validation Matthew Correlation Coefficient: 0.207
# Validation Recall: 0.6833
# Validation Precision: 0.6463
# Validation Accuracy: 0.6124
#
# ######  Epoch 2/30 ######
# Learning rate: 0.0005809096856935629
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5816  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.7849  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.6232  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.5780  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.5115  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.5222  Elapsed: 0:22:47.
# Batch 7,000  of  12,464.  Loss 0.5221  Elapsed: 0:26:34.
# Batch 8,000  of  12,464.  Loss 0.6185  Elapsed: 0:30:22.
# Batch 9,000  of  12,464.  Loss 0.7287  Elapsed: 0:34:09.
# Batch 10,000  of  12,464.  Loss 0.5877  Elapsed: 0:37:57.
# Batch 11,000  of  12,464.  Loss 0.5422  Elapsed: 0:41:44.
# Batch 12,000  of  12,464.  Loss 0.5733  Elapsed: 0:45:32.
#
# Avg Training Loss 0.5921, Completed in 0:47:20
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5293  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6504, Completed in 0:04:21
# Validation F2-score: 0.7584
# Validation Matthew Correlation Coefficient: 0.2374
# Validation Recall: 0.7958
# Validation Precision: 0.6385
# Validation Accuracy: 0.6325
#
# ######  Epoch 3/30 ######
# Learning rate: 0.0005683643841231732
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6111  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4703  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.5069  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.4017  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.6173  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.5839  Elapsed: 0:22:47.
# Batch 7,000  of  12,464.  Loss 0.5673  Elapsed: 0:26:34.
# Batch 8,000  of  12,464.  Loss 0.3743  Elapsed: 0:30:22.
# Batch 9,000  of  12,464.  Loss 0.8074  Elapsed: 0:34:09.
# Batch 10,000  of  12,464.  Loss 0.6110  Elapsed: 0:37:57.
# Batch 11,000  of  12,464.  Loss 0.6750  Elapsed: 0:41:44.
# Batch 12,000  of  12,464.  Loss 0.6058  Elapsed: 0:45:32.
#
# Avg Training Loss 0.5798, Completed in 0:47:20
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5507  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6661, Completed in 0:04:21
# Validation F2-score: 0.758
# Validation Matthew Correlation Coefficient: 0.2093
# Validation Recall: 0.7999
# Validation Precision: 0.6266
# Validation Accuracy: 0.6201
#
# ######  Epoch 4/30 ######
# Learning rate: 0.0005528793740119331
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4196  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5715  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.6482  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.7914  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.4225  Elapsed: 0:18:59.
# Batch 6,000  of  12,464.  Loss 0.5763  Elapsed: 0:22:46.
# Batch 7,000  of  12,464.  Loss 0.5371  Elapsed: 0:26:34.
# Batch 8,000  of  12,464.  Loss 0.6156  Elapsed: 0:30:21.
# Batch 9,000  of  12,464.  Loss 0.5864  Elapsed: 0:34:08.
# Batch 10,000  of  12,464.  Loss 0.7020  Elapsed: 0:37:55.
# Batch 11,000  of  12,464.  Loss 0.3491  Elapsed: 0:41:42.
# Batch 12,000  of  12,464.  Loss 0.5707  Elapsed: 0:45:30.
#
# Avg Training Loss 0.5677, Completed in 0:47:18
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5511  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6501, Completed in 0:04:21
# Validation F2-score: 0.6712
# Validation Matthew Correlation Coefficient: 0.2574
# Validation Recall: 0.6702
# Validation Precision: 0.6751
# Validation Accuracy: 0.6339
#
# ######  Epoch 5/30 ######
# Learning rate: 0.0005346243123710737
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6233  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5129  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.6198  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.4818  Elapsed: 0:15:11.
# Batch 5,000  of  12,464.  Loss 0.4869  Elapsed: 0:18:59.
# Batch 6,000  of  12,464.  Loss 0.6270  Elapsed: 0:22:46.
# Batch 7,000  of  12,464.  Loss 0.5112  Elapsed: 0:26:33.
# Batch 8,000  of  12,464.  Loss 0.5384  Elapsed: 0:30:20.
# Batch 9,000  of  12,464.  Loss 0.5956  Elapsed: 0:34:07.
# Batch 10,000  of  12,464.  Loss 0.6909  Elapsed: 0:37:55.
# Batch 11,000  of  12,464.  Loss 0.4371  Elapsed: 0:41:42.
# Batch 12,000  of  12,464.  Loss 0.5995  Elapsed: 0:45:29.
#
# Avg Training Loss 0.5597, Completed in 0:47:17
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5618  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6504, Completed in 0:04:21
# Validation F2-score: 0.6422
# Validation Matthew Correlation Coefficient: 0.2497
# Validation Recall: 0.6336
# Validation Precision: 0.6795
# Validation Accuracy: 0.6266
#
# ######  Epoch 6/30 ######
# Learning rate: 0.0005137992054760464
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5280  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5278  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.6023  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.5863  Elapsed: 0:15:11.
# Batch 5,000  of  12,464.  Loss 0.7050  Elapsed: 0:18:58.
# Batch 6,000  of  12,464.  Loss 0.6648  Elapsed: 0:22:46.
# Batch 7,000  of  12,464.  Loss 0.5434  Elapsed: 0:26:33.
# Batch 8,000  of  12,464.  Loss 0.4843  Elapsed: 0:30:20.
# Batch 9,000  of  12,464.  Loss 0.4528  Elapsed: 0:34:07.
# Batch 10,000  of  12,464.  Loss 0.5414  Elapsed: 0:37:55.
# Batch 11,000  of  12,464.  Loss 0.5404  Elapsed: 0:41:42.
# Batch 12,000  of  12,464.  Loss 0.5670  Elapsed: 0:45:29.
#
# Avg Training Loss 0.5514, Completed in 0:47:17
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5836  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6564, Completed in 0:04:20
# Validation F2-score: 0.706
# Validation Matthew Correlation Coefficient: 0.2468
# Validation Recall: 0.7189
# Validation Precision: 0.6587
# Validation Accuracy: 0.6331
#
# ######  Epoch 7/30 ######
# Learning rate: 0.000490632217555928
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6185  Elapsed: 0:03:49.
# Batch 2,000  of  12,464.  Loss 0.6571  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.5413  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.5844  Elapsed: 0:15:11.
# Batch 5,000  of  12,464.  Loss 0.5512  Elapsed: 0:18:58.
# Batch 6,000  of  12,464.  Loss 0.4777  Elapsed: 0:22:45.
# Batch 7,000  of  12,464.  Loss 0.7177  Elapsed: 0:26:32.
# Batch 8,000  of  12,464.  Loss 0.6760  Elapsed: 0:30:19.
# Batch 9,000  of  12,464.  Loss 0.5069  Elapsed: 0:34:07.
# Batch 10,000  of  12,464.  Loss 0.5907  Elapsed: 0:37:54.
# Batch 11,000  of  12,464.  Loss 0.5690  Elapsed: 0:41:41.
# Batch 12,000  of  12,464.  Loss 0.6223  Elapsed: 0:45:28.
#
# Avg Training Loss 0.5436, Completed in 0:47:16
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5305  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6840, Completed in 0:04:20
# Validation F2-score: 0.613
# Validation Matthew Correlation Coefficient: 0.2311
# Validation Recall: 0.599
# Validation Precision: 0.6767
# Validation Accuracy: 0.6143
#
# ######  Epoch 8/30 ######
# Learning rate: 0.0004653771709783697
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5326  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.7371  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.5657  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.5753  Elapsed: 0:15:11.
# Batch 5,000  of  12,464.  Loss 0.6178  Elapsed: 0:18:58.
# Batch 6,000  of  12,464.  Loss 0.4986  Elapsed: 0:22:45.
# Batch 7,000  of  12,464.  Loss 0.6646  Elapsed: 0:26:32.
# Batch 8,000  of  12,464.  Loss 0.5445  Elapsed: 0:30:20.
# Batch 9,000  of  12,464.  Loss 0.4408  Elapsed: 0:34:07.
# Batch 10,000  of  12,464.  Loss 0.8525  Elapsed: 0:37:54.
# Batch 11,000  of  12,464.  Loss 0.6928  Elapsed: 0:41:41.
# Batch 12,000  of  12,464.  Loss 0.5057  Elapsed: 0:45:28.
#
# Avg Training Loss 0.5362, Completed in 0:47:16
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5195  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6493, Completed in 0:04:21
# Validation F2-score: 0.7194
# Validation Matthew Correlation Coefficient: 0.2706
# Validation Recall: 0.7338
# Validation Precision: 0.6669
# Validation Accuracy: 0.6449
#
# ######  Epoch 9/30 ######
# Learning rate: 0.0004383107653186432
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6669  Elapsed: 0:03:50.
# Batch 3,000  of  12,464.  Loss 0.5381  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.5690  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.6946  Elapsed: 0:18:59.
# Batch 6,000  of  12,464.  Loss 0.5427  Elapsed: 0:22:46.
# Batch 7,000  of  12,464.  Loss 0.5013  Elapsed: 0:26:34.
# Batch 8,000  of  12,464.  Loss 0.4813  Elapsed: 0:30:21.
# Batch 9,000  of  12,464.  Loss 0.4512  Elapsed: 0:34:08.
# Batch 10,000  of  12,464.  Loss 0.4096  Elapsed: 0:37:56.
# Batch 11,000  of  12,464.  Loss 0.5220  Elapsed: 0:41:43.
# Batch 12,000  of  12,464.  Loss 0.5035  Elapsed: 0:45:30.
#
# Avg Training Loss 0.5306, Completed in 0:47:18
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5033  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6625, Completed in 0:04:21
# Validation F2-score: 0.65
# Validation Matthew Correlation Coefficient: 0.2685
# Validation Recall: 0.6411
# Validation Precision: 0.6886
# Validation Accuracy: 0.6359
#
# ######  Epoch 10/30 ######
# Learning rate: 0.0004097295457811535
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4999  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5900  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.4575  Elapsed: 0:11:24.
# Batch 4,000  of  12,464.  Loss 0.4186  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.7612  Elapsed: 0:18:59.
# Batch 6,000  of  12,464.  Loss 0.6185  Elapsed: 0:22:47.
# Batch 7,000  of  12,464.  Loss 0.5261  Elapsed: 0:26:34.
# Batch 8,000  of  12,464.  Loss 0.5229  Elapsed: 0:30:21.
# Batch 9,000  of  12,464.  Loss 0.3677  Elapsed: 0:34:09.
# Batch 10,000  of  12,464.  Loss 0.4264  Elapsed: 0:37:56.
# Batch 11,000  of  12,464.  Loss 0.6297  Elapsed: 0:41:44.
# Batch 12,000  of  12,464.  Loss 0.3634  Elapsed: 0:45:31.
#
# Avg Training Loss 0.5232, Completed in 0:47:19
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6207  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6389, Completed in 0:04:21
# Validation F2-score: 0.733
# Validation Matthew Correlation Coefficient: 0.2866
# Validation Recall: 0.7505
# Validation Precision: 0.6707
# Validation Accuracy: 0.6532
#
# ######  Epoch 11/30 ######
# Learning rate: 0.0003799466541881668
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4313  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3616  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.3316  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.3999  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.4389  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.5440  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.5890  Elapsed: 0:26:35.
# Batch 8,000  of  12,464.  Loss 0.4236  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.3982  Elapsed: 0:34:11.
# Batch 10,000  of  12,464.  Loss 0.3742  Elapsed: 0:37:58.
# Batch 11,000  of  12,464.  Loss 0.6525  Elapsed: 0:41:46.
# Batch 12,000  of  12,464.  Loss 0.7309  Elapsed: 0:45:34.
#
# Avg Training Loss 0.5190, Completed in 0:47:22
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6119  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6648, Completed in 0:04:21
# Validation F2-score: 0.6743
# Validation Matthew Correlation Coefficient: 0.2563
# Validation Recall: 0.6745
# Validation Precision: 0.6735
# Validation Accuracy: 0.6338
#
# ######  Epoch 12/30 ######
# Learning rate: 0.000349288398132448
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5950  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6851  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.6110  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3867  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4557  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5402  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4379  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.4464  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.4901  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.4614  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.5094  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.4672  Elapsed: 0:45:39.
#
# Avg Training Loss 0.5126, Completed in 0:47:28
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6551  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6476, Completed in 0:04:22
# Validation F2-score: 0.7462
# Validation Matthew Correlation Coefficient: 0.29
# Validation Recall: 0.7688
# Validation Precision: 0.6678
# Validation Accuracy: 0.6556
#
# ######  Epoch 13/30 ######
# Learning rate: 0.00031809067588299246
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5122  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3597  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.4753  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.4055  Elapsed: 0:15:16.
# Batch 5,000  of  12,464.  Loss 0.4758  Elapsed: 0:19:04.
# Batch 6,000  of  12,464.  Loss 0.6658  Elapsed: 0:22:53.
# Batch 7,000  of  12,464.  Loss 0.5219  Elapsed: 0:26:41.
# Batch 8,000  of  12,464.  Loss 0.5740  Elapsed: 0:30:29.
# Batch 9,000  of  12,464.  Loss 0.4011  Elapsed: 0:34:17.
# Batch 10,000  of  12,464.  Loss 0.4731  Elapsed: 0:38:05.
# Batch 11,000  of  12,464.  Loss 0.5478  Elapsed: 0:41:53.
# Batch 12,000  of  12,464.  Loss 0.3717  Elapsed: 0:45:41.
#
# Avg Training Loss 0.5088, Completed in 0:47:30
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5394  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6435, Completed in 0:04:21
# Validation F2-score: 0.7169
# Validation Matthew Correlation Coefficient: 0.3003
# Validation Recall: 0.7256
# Validation Precision: 0.6841
# Validation Accuracy: 0.658
#
# ######  Epoch 14/30 ######
# Learning rate: 0.0002866952962133078
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5206  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4479  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.4982  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.4264  Elapsed: 0:15:12.
# Batch 5,000  of  12,464.  Loss 0.6098  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.7698  Elapsed: 0:22:47.
# Batch 7,000  of  12,464.  Loss 0.6166  Elapsed: 0:26:35.
# Batch 8,000  of  12,464.  Loss 0.5291  Elapsed: 0:30:22.
# Batch 9,000  of  12,464.  Loss 0.5172  Elapsed: 0:34:10.
# Batch 10,000  of  12,464.  Loss 0.5447  Elapsed: 0:37:57.
# Batch 11,000  of  12,464.  Loss 0.3910  Elapsed: 0:41:45.
# Batch 12,000  of  12,464.  Loss 0.6029  Elapsed: 0:45:32.
#
# Avg Training Loss 0.5027, Completed in 0:47:20
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5651  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6517, Completed in 0:04:21
# Validation F2-score: 0.6843
# Validation Matthew Correlation Coefficient: 0.2909
# Validation Recall: 0.6828
# Validation Precision: 0.6905
# Validation Accuracy: 0.6502
#
# ######  Epoch 15/30 ######
# Learning rate: 0.00025544623347296334
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4416  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4236  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.6301  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5862  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4593  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5363  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.3760  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.5310  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.6976  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.4698  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.4701  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.5526  Elapsed: 0:45:39.
#
# Avg Training Loss 0.4983, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5806  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6619, Completed in 0:04:22
# Validation F2-score: 0.7652
# Validation Matthew Correlation Coefficient: 0.2952
# Validation Recall: 0.7957
# Validation Precision: 0.6633
# Validation Accuracy: 0.6587
#
# ######  Epoch 16/30 ######
# Learning rate: 0.00022468585893262654
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4117  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5057  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4500  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3353  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5459  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3357  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4135  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.5968  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4941  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5267  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.5152  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.6259  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4938, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6263  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6663, Completed in 0:04:21
# Validation F2-score: 0.7061
# Validation Matthew Correlation Coefficient: 0.2749
# Validation Recall: 0.7147
# Validation Precision: 0.6737
# Validation Accuracy: 0.6456
#
# ######  Epoch 17/30 ######
# Learning rate: 0.00019475118969278308
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6088  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5843  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5670  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5775  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5345  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5198  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4295  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.3987  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.3780  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.6076  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.3555  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.3650  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4896, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5926  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6462, Completed in 0:04:22
# Validation F2-score: 0.7212
# Validation Matthew Correlation Coefficient: 0.2966
# Validation Recall: 0.7321
# Validation Precision: 0.6805
# Validation Accuracy: 0.6567
#
# ######  Epoch 18/30 ######
# Learning rate: 0.00016597019625386067
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3221  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4173  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4468  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.4985  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.5449  Elapsed: 0:19:03.
# Batch 6,000  of  12,464.  Loss 0.3019  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.3777  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.4340  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.3110  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.4031  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.5063  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.4861  Elapsed: 0:45:39.
#
# Avg Training Loss 0.4855, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6055  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6409, Completed in 0:04:22
# Validation F2-score: 0.7044
# Validation Matthew Correlation Coefficient: 0.3155
# Validation Recall: 0.706
# Validation Precision: 0.6979
# Validation Accuracy: 0.6634
#
# ######  Epoch 19/30 ######
# Learning rate: 0.00013865820920278135
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3812  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5448  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4864  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3210  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4728  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3861  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4180  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.2331  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4515  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5563  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.7960  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.6705  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4817, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6328  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6597, Completed in 0:04:22
# Validation F2-score: 0.6797
# Validation Matthew Correlation Coefficient: 0.296
# Validation Recall: 0.6759
# Validation Precision: 0.6953
# Validation Accuracy: 0.6518
#
# ######  Epoch 20/30 ######
# Learning rate: 0.00011311446438508028
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3635  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3543  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3614  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.2994  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.6295  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4797  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.3348  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4166  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.5108  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.6848  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.6210  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.4668  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4785, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6622  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6552, Completed in 0:04:22
# Validation F2-score: 0.7652
# Validation Matthew Correlation Coefficient: 0.303
# Validation Recall: 0.7944
# Validation Precision: 0.6672
# Validation Accuracy: 0.6622
#
# ######  Epoch 21/30 ######
# Learning rate: 8.961882441435188e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4405  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6691  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5377  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3425  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5919  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.7398  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5580  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4696  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.4465  Elapsed: 0:34:13.
# Batch 10,000  of  12,464.  Loss 0.3485  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.4711  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.4079  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4756, Completed in 0:47:25
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6812  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6535, Completed in 0:04:21
# Validation F2-score: 0.7229
# Validation Matthew Correlation Coefficient: 0.3076
# Validation Recall: 0.7328
# Validation Precision: 0.686
# Validation Accuracy: 0.6618
#
# ######  Epoch 22/30 ######
# Learning rate: 6.842871243889412e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2895  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6238  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4702  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5123  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5396  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5077  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5086  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.5098  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4646  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.3379  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4852  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.4649  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4731, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6340  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6483, Completed in 0:04:21
# Validation F2-score: 0.7307
# Validation Matthew Correlation Coefficient: 0.3137
# Validation Recall: 0.7427
# Validation Precision: 0.6864
# Validation Accuracy: 0.6652
#
# ######  Epoch 23/30 ######
# Learning rate: 4.977629175982649e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4681  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3571  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3400  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5028  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.6056  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3649  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5539  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.5160  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.3776  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.4040  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4442  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.4041  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4703, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6802  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6455, Completed in 0:04:21
# Validation F2-score: 0.7342
# Validation Matthew Correlation Coefficient: 0.3102
# Validation Recall: 0.7482
# Validation Precision: 0.6831
# Validation Accuracy: 0.6639
#
# ######  Epoch 24/30 ######
# Learning rate: 3.3865922201378536e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4485  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4524  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4330  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3354  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3540  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3973  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.2945  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4306  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.5542  Elapsed: 0:34:13.
# Batch 10,000  of  12,464.  Loss 0.6075  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.5759  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.4709  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4692, Completed in 0:47:25
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6634  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6654, Completed in 0:04:21
# Validation F2-score: 0.7241
# Validation Matthew Correlation Coefficient: 0.3029
# Validation Recall: 0.7352
# Validation Precision: 0.6829
# Validation Accuracy: 0.6598
#
# ######  Epoch 25/30 ######
# Learning rate: 2.0871921101891518e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4204  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3929  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5631  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3944  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4219  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3064  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.2673  Elapsed: 0:26:37.
# Batch 8,000  of  12,464.  Loss 0.4858  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.3202  Elapsed: 0:34:13.
# Batch 11,000  of  12,464.  Loss 0.4395  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.4552  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4673, Completed in 0:47:25
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6857  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6600, Completed in 0:04:21
# Validation F2-score: 0.7282
# Validation Matthew Correlation Coefficient: 0.3097
# Validation Recall: 0.7398
# Validation Precision: 0.6852
# Validation Accuracy: 0.6632
#
# ######  Epoch 26/30 ######
# Learning rate: 1.093665345658086e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5199  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5098  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5430  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5216  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4847  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4263  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.3641  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4877  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4814  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.6606  Elapsed: 0:38:02.
# Batch 12,000  of  12,464.  Loss 0.5822  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4668, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6803  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6569, Completed in 0:04:21
# Validation F2-score: 0.7355
# Validation Matthew Correlation Coefficient: 0.3114
# Validation Recall: 0.7498
# Validation Precision: 0.6833
# Validation Accuracy: 0.6645
#
# ######  Epoch 27/30 ######
# Learning rate: 4.168972136857466e-06
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4766  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5047  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.3754  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.3047  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.5057  Elapsed: 0:19:01.
# Batch 6,000  of  12,464.  Loss 0.5031  Elapsed: 0:22:49.
# Batch 7,000  of  12,464.  Loss 0.4024  Elapsed: 0:26:37.
# Batch 8,000  of  12,464.  Loss 0.3495  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.5856  Elapsed: 0:34:13.
# Batch 10,000  of  12,464.  Loss 0.3055  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.6542  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.3242  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4656, Completed in 0:47:25
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6816  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6563, Completed in 0:04:21
# Validation F2-score: 0.7333
# Validation Matthew Correlation Coefficient: 0.3127
# Validation Recall: 0.7466
# Validation Precision: 0.6849
# Validation Accuracy: 0.6649
#
# ######  Epoch 28/30 ######
# Learning rate: 6.430252754882137e-07
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3628  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4371  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.6278  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.4030  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5700  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4531  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.3507  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4765  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4230  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.2124  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.5094  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.3023  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4659, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6766  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6555, Completed in 0:04:21
# Validation F2-score: 0.7282
# Validation Matthew Correlation Coefficient: 0.3131
# Validation Recall: 0.7393
# Validation Precision: 0.6871
# Validation Accuracy: 0.6647
#
# ######  Epoch 29/30 ######
# Learning rate: 3.9744388398249003e-07
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5089  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6439  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5053  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3707  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5065  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4642  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4843  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.2659  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4471  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.2542  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.5285  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.4738  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4655, Completed in 0:47:25
#
# -----  Validation -----

# %%
# ##### Test LR = 6.28e-4, Optim = AdamW. Continue Training
# # Store the average loss after each epoch so we can plot them.
# best_train_loss = 1e5
# train_loss_values2 = []
# val_loss_values2 = []
# learning_rates2 = []

# for epoch in range(EPOCHS):
#     print ('######  Epoch {}/{} ######'.format(epoch+30, EPOCHS+29))
#     print('Learning rate:', str(scheduler.get_last_lr()[0]))
#     print()
#     learning_rates2.append(scheduler.get_last_lr())

#     print ('-----  Training -----')
#     train_loss, train_time = train(train_loader, model, criterion, optimizer)
#     train_loss_values2.append(train_loss)

#     print ('-----  Validation -----')
#     val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
#     val_loss_values2.append(val_loss)
#     y_val_true, y_val_score, y_val_pred = compute_metrics(val_outputs, val_targets, prefix="Validation")
#     print()

#     # Get the best loss
#     is_best = train_loss < best_train_loss
#     best_train_loss = min(train_loss, best_train_loss)

#     # Save Checkpoint
#     save_checkpoint(
#         {'epoch': epoch+31,
#          'state_dict': model.state_dict(),
#          'best_train_loss': best_train_loss,
#          'optimizer': optimizer.state_dict()
#          },
#         is_best
#     )

#     if best_train_loss < 0.2:
#         break
# Out:
# ######  Epoch 30/59 ######
# Learning rate: 0.0006
#
# -----  Training -----
# Batch 2,000  of  12,464.  Loss 0.5366  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.4290  Elapsed: 0:11:28.
# Batch 4,000  of  12,464.  Loss 0.4909  Elapsed: 0:15:16.
# Batch 5,000  of  12,464.  Loss 0.6143  Elapsed: 0:19:05.
# Batch 6,000  of  12,464.  Loss 0.5990  Elapsed: 0:22:53.
# Batch 7,000  of  12,464.  Loss 0.4972  Elapsed: 0:26:42.
# Batch 8,000  of  12,464.  Loss 0.3647  Elapsed: 0:30:30.
# Batch 9,000  of  12,464.  Loss 0.4305  Elapsed: 0:34:18.
# Batch 10,000  of  12,464.  Loss 0.4659  Elapsed: 0:38:06.
# Batch 11,000  of  12,464.  Loss 0.3646  Elapsed: 0:41:54.
# Batch 12,000  of  12,464.  Loss 0.5258  Elapsed: 0:45:42.
#
# Avg Training Loss 0.5008, Completed in 0:47:31
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5697  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6421, Completed in 0:04:22
# Validation F2-score: 0.6266
# Validation Matthew Correlation Coefficient: 0.2975
# Validation Recall: 0.6076
# Validation Precision: 0.716
# Validation Accuracy: 0.6445
#
# ######  Epoch 31/59 ######
# Learning rate: 0.0005983839591336347
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3276  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4895  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5833  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5522  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5210  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5583  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.5141  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.7326  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.4116  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.3829  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.7053  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.3595  Elapsed: 0:45:39.
#
# Avg Training Loss 0.5006, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5861  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6502, Completed in 0:04:22
# Validation F2-score: 0.702
# Validation Matthew Correlation Coefficient: 0.2856
# Validation Recall: 0.7074
# Validation Precision: 0.6812
# Validation Accuracy: 0.6499
#
# ######  Epoch 32/59 ######
# Learning rate: 0.0005935535422164708
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4833  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5238  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5754  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5084  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5806  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3394  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.3225  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.5910  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.6150  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.3402  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4843  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.5081  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4969, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6074  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6519, Completed in 0:04:22
# Validation F2-score: 0.7202
# Validation Matthew Correlation Coefficient: 0.295
# Validation Recall: 0.7311
# Validation Precision: 0.6799
# Validation Accuracy: 0.6559
#
# ######  Epoch 33/59 ######
# Learning rate: 0.0005855616723070614
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4412  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4705  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5343  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5238  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3942  Elapsed: 0:19:03.
# Batch 6,000  of  12,464.  Loss 0.5071  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.3563  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.8070  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.3299  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.3528  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.5050  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.4874  Elapsed: 0:45:39.
#
# Avg Training Loss 0.4942, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5441  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6819, Completed in 0:04:22
# Validation F2-score: 0.8021
# Validation Matthew Correlation Coefficient: 0.3015
# Validation Recall: 0.8513
# Validation Precision: 0.6514
# Validation Accuracy: 0.6609
#
# ######  Epoch 34/59 ######
# Learning rate: 0.0005744959100045539
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3118  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5103  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3416  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5145  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4733  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3306  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.6243  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.5987  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.5056  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5484  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4049  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.4260  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4925, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6458  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6566, Completed in 0:04:22
# Validation F2-score: 0.7384
# Validation Matthew Correlation Coefficient: 0.2736
# Validation Recall: 0.7603
# Validation Precision: 0.6621
# Validation Accuracy: 0.6477
#
# ######  Epoch 35/59 ######
# Learning rate: 0.0005604774941163999
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5263  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3481  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5313  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3661  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4958  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3970  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5910  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.3407  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.5466  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.3234  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.3943  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.4442  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4885, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6566  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6475, Completed in 0:04:22
# Validation F2-score: 0.6709
# Validation Matthew Correlation Coefficient: 0.2955
# Validation Recall: 0.6644
# Validation Precision: 0.6982
# Validation Accuracy: 0.6505
#
# ######  Epoch 36/59 ######
# Learning rate: 0.0005436600133406005
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6623  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4350  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.4161  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.3979  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.5062  Elapsed: 0:19:04.
# Batch 6,000  of  12,464.  Loss 0.4830  Elapsed: 0:22:52.
# Batch 7,000  of  12,464.  Loss 0.4938  Elapsed: 0:26:40.
# Batch 8,000  of  12,464.  Loss 0.3716  Elapsed: 0:30:29.
# Batch 9,000  of  12,464.  Loss 0.5400  Elapsed: 0:34:17.
# Batch 10,000  of  12,464.  Loss 0.5437  Elapsed: 0:38:05.
# Batch 11,000  of  12,464.  Loss 0.3401  Elapsed: 0:41:54.
# Batch 12,000  of  12,464.  Loss 0.3698  Elapsed: 0:45:42.
#
# Avg Training Loss 0.4872, Completed in 0:47:30
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7420  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6656, Completed in 0:04:22
# Validation F2-score: 0.7494
# Validation Matthew Correlation Coefficient: 0.2786
# Validation Recall: 0.7755
# Validation Precision: 0.6608
# Validation Accuracy: 0.6505
#
# ######  Epoch 37/59 ######
# Learning rate: 0.0005242277235158256
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5204  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4121  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.4652  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.4816  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.4504  Elapsed: 0:19:03.
# Batch 6,000  of  12,464.  Loss 0.6294  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.5111  Elapsed: 0:26:40.
# Batch 8,000  of  12,464.  Loss 0.5105  Elapsed: 0:30:28.
# Batch 9,000  of  12,464.  Loss 0.4204  Elapsed: 0:34:16.
# Batch 10,000  of  12,464.  Loss 0.2588  Elapsed: 0:38:04.
# Batch 11,000  of  12,464.  Loss 0.4021  Elapsed: 0:41:52.
# Batch 12,000  of  12,464.  Loss 0.3744  Elapsed: 0:45:40.
#
# Avg Training Loss 0.4839, Completed in 0:47:29
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5734  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6541, Completed in 0:04:22
# Validation F2-score: 0.7478
# Validation Matthew Correlation Coefficient: 0.3167
# Validation Recall: 0.7665
# Validation Precision: 0.6813
# Validation Accuracy: 0.6677
#
# ######  Epoch 38/59 ######
# Learning rate: 0.000502393528875861
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5136  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4822  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4043  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.7428  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.5919  Elapsed: 0:19:03.
# Batch 6,000  of  12,464.  Loss 0.4102  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.6524  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.3656  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.6782  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.4606  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.4465  Elapsed: 0:41:52.
# Batch 12,000  of  12,464.  Loss 0.4298  Elapsed: 0:45:40.
#
# Avg Training Loss 0.4814, Completed in 0:47:28
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6510  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6564, Completed in 0:04:22
# Validation F2-score: 0.658
# Validation Matthew Correlation Coefficient: 0.2943
# Validation Recall: 0.6478
# Validation Precision: 0.7022
# Validation Accuracy: 0.6481
#
# ######  Epoch 39/59 ######
# Learning rate: 0.00047839664942613707
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3232  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6165  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4492  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.2741  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5083  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3781  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4497  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.3821  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.5361  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.4748  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.3719  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.5245  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4779, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6468  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6539, Completed in 0:04:22
# Validation F2-score: 0.7518
# Validation Matthew Correlation Coefficient: 0.3071
# Validation Recall: 0.774
# Validation Precision: 0.6745
# Validation Accuracy: 0.6636
#
# ######  Epoch 40/59 ######
# Learning rate: 0.00045249999999986745
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3572  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5910  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4778  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3374  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5408  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5627  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5955  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.2823  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.5473  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5037  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.7024  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.5196  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4736, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6662  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6514, Completed in 0:04:22
# Validation F2-score: 0.7608
# Validation Matthew Correlation Coefficient: 0.3162
# Validation Recall: 0.7856
# Validation Precision: 0.6758
# Validation Accuracy: 0.6681
#
# ######  Epoch 41/59 ######
# Learning rate: 0.00042498730970723543
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6115  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4168  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5962  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.4772  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3782  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3164  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4968  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4391  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4717  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5520  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4811  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.3708  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4705, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6538  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6600, Completed in 0:04:21
# Validation F2-score: 0.7574
# Validation Matthew Correlation Coefficient: 0.2944
# Validation Recall: 0.7844
# Validation Precision: 0.6659
# Validation Accuracy: 0.6581
#
# ######  Epoch 42/59 ######
# Learning rate: 0.0003961600133404892
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5022  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3082  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4949  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.4506  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3943  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.6284  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4892  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.3978  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.5145  Elapsed: 0:34:13.
# Batch 10,000  of  12,464.  Loss 0.5312  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.3461  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.5314  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4679, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6712  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6888, Completed in 0:04:21
# Validation F2-score: 0.7893
# Validation Matthew Correlation Coefficient: 0.3132
# Validation Recall: 0.8289
# Validation Precision: 0.6625
# Validation Accuracy: 0.6669
#
# ######  Epoch 43/59 ######
# Learning rate: 0.00036633394879112584
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6868  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.2980  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3967  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3745  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3757  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3158  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5830  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4690  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.3698  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.4007  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4262  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.7748  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4638, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6245  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6527, Completed in 0:04:21
# Validation F2-score: 0.616
# Validation Matthew Correlation Coefficient: 0.3051
# Validation Recall: 0.5936
# Validation Precision: 0.7256
# Validation Accuracy: 0.6459
#
# ######  Epoch 44/59 ######
# Learning rate: 0.0003358358966638512
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5739  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.5690  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4958  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5439  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4580  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.3455  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4410  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4474  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.3841  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.5225  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.6072  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.4238  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4590, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6286  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6436, Completed in 0:04:21
# Validation F2-score: 0.7345
# Validation Matthew Correlation Coefficient: 0.3225
# Validation Recall: 0.7465
# Validation Precision: 0.69
# Validation Accuracy: 0.6695
#
# ######  Epoch 45/59 ######
# Learning rate: 0.00030499999999990295
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6284  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.2843  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4076  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3710  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.5888  Elapsed: 0:19:01.
# Batch 6,000  of  12,464.  Loss 0.4813  Elapsed: 0:22:49.
# Batch 7,000  of  12,464.  Loss 0.4221  Elapsed: 0:26:37.
# Batch 8,000  of  12,464.  Loss 0.3855  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.4419  Elapsed: 0:34:12.
# Batch 10,000  of  12,464.  Loss 0.4159  Elapsed: 0:38:00.
# Batch 11,000  of  12,464.  Loss 0.3904  Elapsed: 0:41:48.
# Batch 12,000  of  12,464.  Loss 0.4705  Elapsed: 0:45:36.
#
# Avg Training Loss 0.4567, Completed in 0:47:24
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5361  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6535, Completed in 0:04:22
# Validation F2-score: 0.7196
# Validation Matthew Correlation Coefficient: 0.3322
# Validation Recall: 0.7242
# Validation Precision: 0.7018
# Validation Accuracy: 0.6725
#
# ######  Epoch 46/59 ######
# Learning rate: 0.0002741641033359549
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5225  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.5146  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.3627  Elapsed: 0:11:28.
# Batch 4,000  of  12,464.  Loss 0.4980  Elapsed: 0:15:16.
# Batch 5,000  of  12,464.  Loss 0.4440  Elapsed: 0:19:04.
# Batch 6,000  of  12,464.  Loss 0.4328  Elapsed: 0:22:52.
# Batch 7,000  of  12,464.  Loss 0.5234  Elapsed: 0:26:40.
# Batch 8,000  of  12,464.  Loss 0.3362  Elapsed: 0:30:28.
# Batch 9,000  of  12,464.  Loss 0.6073  Elapsed: 0:34:16.
# Batch 10,000  of  12,464.  Loss 0.5706  Elapsed: 0:38:04.
# Batch 11,000  of  12,464.  Loss 0.5806  Elapsed: 0:41:52.
# Batch 12,000  of  12,464.  Loss 0.4441  Elapsed: 0:45:40.
#
# Avg Training Loss 0.4540, Completed in 0:47:29
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6137  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6424, Completed in 0:04:22
# Validation F2-score: 0.676
# Validation Matthew Correlation Coefficient: 0.3206
# Validation Recall: 0.6675
# Validation Precision: 0.7123
# Validation Accuracy: 0.6621
#
# ######  Epoch 47/59 ######
# Learning rate: 0.0002436660512087387
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5148  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3376  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4155  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.4053  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.2988  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4236  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.5551  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.6047  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.4461  Elapsed: 0:34:15.
# Batch 10,000  of  12,464.  Loss 0.3785  Elapsed: 0:38:03.
# Batch 11,000  of  12,464.  Loss 0.6159  Elapsed: 0:41:51.
# Batch 12,000  of  12,464.  Loss 0.4103  Elapsed: 0:45:39.
#
# Avg Training Loss 0.4495, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5756  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6490, Completed in 0:04:22
# Validation F2-score: 0.7361
# Validation Matthew Correlation Coefficient: 0.3275
# Validation Recall: 0.748
# Validation Precision: 0.6921
# Validation Accuracy: 0.6718
#
# ######  Epoch 48/59 ######
# Learning rate: 0.00021383998665937127
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3428  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4466  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3453  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.7189  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4482  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.5913  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.2944  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4844  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4071  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.3893  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.5596  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.5100  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4456, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6216  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6429, Completed in 0:04:22
# Validation F2-score: 0.7673
# Validation Matthew Correlation Coefficient: 0.3339
# Validation Recall: 0.7919
# Validation Precision: 0.6825
# Validation Accuracy: 0.6764
#
# ######  Epoch 49/59 ######
# Learning rate: 0.00018501269029262267
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5314  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.5130  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.5054  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.3905  Elapsed: 0:15:16.
# Batch 5,000  of  12,464.  Loss 0.3181  Elapsed: 0:19:04.
# Batch 6,000  of  12,464.  Loss 0.2993  Elapsed: 0:22:52.
# Batch 7,000  of  12,464.  Loss 0.4609  Elapsed: 0:26:40.
# Batch 8,000  of  12,464.  Loss 0.5938  Elapsed: 0:30:29.
# Batch 9,000  of  12,464.  Loss 0.4308  Elapsed: 0:34:17.
# Batch 10,000  of  12,464.  Loss 0.3240  Elapsed: 0:38:05.
# Batch 11,000  of  12,464.  Loss 0.4132  Elapsed: 0:41:54.
# Batch 12,000  of  12,464.  Loss 0.3805  Elapsed: 0:45:42.
#
# Avg Training Loss 0.4422, Completed in 0:47:30
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6420  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6415, Completed in 0:04:22
# Validation F2-score: 0.7212
# Validation Matthew Correlation Coefficient: 0.3396
# Validation Recall: 0.7251
# Validation Precision: 0.7056
# Validation Accuracy: 0.6759
#
# ######  Epoch 50/59 ######
# Learning rate: 0.00015749999999998556
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4188  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4264  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.5732  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.4047  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.5845  Elapsed: 0:19:03.
# Batch 6,000  of  12,464.  Loss 0.5539  Elapsed: 0:22:51.
# Batch 7,000  of  12,464.  Loss 0.4225  Elapsed: 0:26:39.
# Batch 8,000  of  12,464.  Loss 0.6253  Elapsed: 0:30:27.
# Batch 9,000  of  12,464.  Loss 0.3886  Elapsed: 0:34:16.
# Batch 10,000  of  12,464.  Loss 0.4237  Elapsed: 0:38:04.
# Batch 11,000  of  12,464.  Loss 0.3243  Elapsed: 0:41:52.
# Batch 12,000  of  12,464.  Loss 0.3930  Elapsed: 0:45:40.
#
# Avg Training Loss 0.4383, Completed in 0:47:28
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7087  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6604, Completed in 0:04:22
# Validation F2-score: 0.677
# Validation Matthew Correlation Coefficient: 0.3258
# Validation Recall: 0.6681
# Validation Precision: 0.7153
# Validation Accuracy: 0.6645
#
# ######  Epoch 51/59 ######
# Learning rate: 0.0001316033505737097
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3143  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.2899  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5887  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.5170  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.5023  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4075  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.4281  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4668  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4404  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.4471  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.4766  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.3058  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4367, Completed in 0:47:26
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6716  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6758, Completed in 0:04:21
# Validation F2-score: 0.7911
# Validation Matthew Correlation Coefficient: 0.3429
# Validation Recall: 0.8261
# Validation Precision: 0.6766
# Validation Accuracy: 0.6808
#
# ######  Epoch 52/59 ######
# Learning rate: 0.00010760647112415653
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3929  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.2827  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.4063  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.4104  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.6235  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.3710  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.4947  Elapsed: 0:26:35.
# Batch 8,000  of  12,464.  Loss 0.4903  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.5621  Elapsed: 0:34:10.
# Batch 10,000  of  12,464.  Loss 0.3532  Elapsed: 0:37:57.
# Batch 11,000  of  12,464.  Loss 0.6190  Elapsed: 0:41:45.
# Batch 12,000  of  12,464.  Loss 0.5823  Elapsed: 0:45:32.
#
# Avg Training Loss 0.4328, Completed in 0:47:20
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6730  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6672, Completed in 0:04:21
# Validation F2-score: 0.702
# Validation Matthew Correlation Coefficient: 0.3206
# Validation Recall: 0.7021
# Validation Precision: 0.7019
# Validation Accuracy: 0.6654
#
# ######  Epoch 53/59 ######
# Learning rate: 8.577227648418352e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2984  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4086  Elapsed: 0:07:37.
# Batch 3,000  of  12,464.  Loss 0.4142  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.4692  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.4232  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.4069  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.4474  Elapsed: 0:26:35.
# Batch 8,000  of  12,464.  Loss 0.4624  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.6048  Elapsed: 0:34:10.
# Batch 10,000  of  12,464.  Loss 0.3839  Elapsed: 0:37:58.
# Batch 11,000  of  12,464.  Loss 0.4590  Elapsed: 0:41:46.
# Batch 12,000  of  12,464.  Loss 0.4868  Elapsed: 0:45:33.
#
# Avg Training Loss 0.4301, Completed in 0:47:21
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6941  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6605, Completed in 0:04:21
# Validation F2-score: 0.7084
# Validation Matthew Correlation Coefficient: 0.3226
# Validation Recall: 0.7103
# Validation Precision: 0.7005
# Validation Accuracy: 0.667
#
# ######  Epoch 54/59 ######
# Learning rate: 6.633998665941166e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3996  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6415  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3843  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.3883  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.3169  Elapsed: 0:19:00.
# Batch 6,000  of  12,464.  Loss 0.5952  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.5654  Elapsed: 0:26:36.
# Batch 8,000  of  12,464.  Loss 0.2865  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.4377  Elapsed: 0:34:11.
# Batch 10,000  of  12,464.  Loss 0.3534  Elapsed: 0:37:58.
# Batch 11,000  of  12,464.  Loss 0.4900  Elapsed: 0:41:46.
# Batch 12,000  of  12,464.  Loss 0.5084  Elapsed: 0:45:34.
#
# Avg Training Loss 0.4274, Completed in 0:47:22
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6605  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6677, Completed in 0:04:21
# Validation F2-score: 0.7179
# Validation Matthew Correlation Coefficient: 0.3302
# Validation Recall: 0.7222
# Validation Precision: 0.7013
# Validation Accuracy: 0.6714
#
# ######  Epoch 55/59 ######
# Learning rate: 4.952250588361468e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4728  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3474  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.5601  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.2666  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.6839  Elapsed: 0:19:01.
# Batch 6,000  of  12,464.  Loss 0.3816  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.2979  Elapsed: 0:26:36.
# Batch 8,000  of  12,464.  Loss 0.3699  Elapsed: 0:30:23.
# Batch 9,000  of  12,464.  Loss 0.4275  Elapsed: 0:34:11.
# Batch 10,000  of  12,464.  Loss 0.4210  Elapsed: 0:37:59.
# Batch 11,000  of  12,464.  Loss 0.4481  Elapsed: 0:41:46.
# Batch 12,000  of  12,464.  Loss 0.4964  Elapsed: 0:45:34.
#
# Avg Training Loss 0.4254, Completed in 0:47:22
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6269  Elapsed: 0:03:27.
#
# Avg Validation Loss 0.6653, Completed in 0:04:21
# Validation F2-score: 0.7335
# Validation Matthew Correlation Coefficient: 0.3337
# Validation Recall: 0.7433
# Validation Precision: 0.6968
# Validation Accuracy: 0.6744
#
# ######  Epoch 56/59 ######
# Learning rate: 3.550408999545586e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3662  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4980  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.3297  Elapsed: 0:11:25.
# Batch 4,000  of  12,464.  Loss 0.3900  Elapsed: 0:15:13.
# Batch 5,000  of  12,464.  Loss 0.2631  Elapsed: 0:19:01.
# Batch 6,000  of  12,464.  Loss 0.2841  Elapsed: 0:22:48.
# Batch 7,000  of  12,464.  Loss 0.5296  Elapsed: 0:26:36.
# Batch 8,000  of  12,464.  Loss 0.3102  Elapsed: 0:30:24.
# Batch 9,000  of  12,464.  Loss 0.4992  Elapsed: 0:34:12.
# Batch 10,000  of  12,464.  Loss 0.4062  Elapsed: 0:38:00.
# Batch 11,000  of  12,464.  Loss 0.2784  Elapsed: 0:41:47.
# Batch 12,000  of  12,464.  Loss 0.5529  Elapsed: 0:45:35.
#
# Avg Training Loss 0.4250, Completed in 0:47:24
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6337  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6687, Completed in 0:04:21
# Validation F2-score: 0.7308
# Validation Matthew Correlation Coefficient: 0.3341
# Validation Recall: 0.7394
# Validation Precision: 0.6982
# Validation Accuracy: 0.6744
#
# ######  Epoch 57/59 ######
# Learning rate: 2.4438327692957146e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4396  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3556  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.2727  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.3082  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.3858  Elapsed: 0:19:01.
# Batch 6,000  of  12,464.  Loss 0.2745  Elapsed: 0:22:49.
# Batch 7,000  of  12,464.  Loss 0.4802  Elapsed: 0:26:37.
# Batch 8,000  of  12,464.  Loss 0.3649  Elapsed: 0:30:25.
# Batch 9,000  of  12,464.  Loss 0.5437  Elapsed: 0:34:13.
# Batch 10,000  of  12,464.  Loss 0.4088  Elapsed: 0:38:01.
# Batch 11,000  of  12,464.  Loss 0.5778  Elapsed: 0:41:49.
# Batch 12,000  of  12,464.  Loss 0.3267  Elapsed: 0:45:37.
#
# Avg Training Loss 0.4224, Completed in 0:47:25
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6661  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6672, Completed in 0:04:22
# Validation F2-score: 0.7429
# Validation Matthew Correlation Coefficient: 0.3358
# Validation Recall: 0.7562
# Validation Precision: 0.6941
# Validation Accuracy: 0.6761
#
# ######  Epoch 58/59 ######
# Learning rate: 1.6446457783539695e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4283  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4500  Elapsed: 0:07:38.
# Batch 3,000  of  12,464.  Loss 0.4666  Elapsed: 0:11:26.
# Batch 4,000  of  12,464.  Loss 0.2978  Elapsed: 0:15:14.
# Batch 5,000  of  12,464.  Loss 0.4239  Elapsed: 0:19:02.
# Batch 6,000  of  12,464.  Loss 0.4331  Elapsed: 0:22:50.
# Batch 7,000  of  12,464.  Loss 0.3392  Elapsed: 0:26:38.
# Batch 8,000  of  12,464.  Loss 0.4609  Elapsed: 0:30:26.
# Batch 9,000  of  12,464.  Loss 0.4224  Elapsed: 0:34:14.
# Batch 10,000  of  12,464.  Loss 0.3938  Elapsed: 0:38:02.
# Batch 11,000  of  12,464.  Loss 0.5042  Elapsed: 0:41:50.
# Batch 12,000  of  12,464.  Loss 0.2740  Elapsed: 0:45:38.
#
# Avg Training Loss 0.4230, Completed in 0:47:27
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6710  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6635, Completed in 0:04:22
# Validation F2-score: 0.7374
# Validation Matthew Correlation Coefficient: 0.3335
# Validation Recall: 0.7488
# Validation Precision: 0.6951
# Validation Accuracy: 0.6746
#
# ######  Epoch 59/59 ######
# Learning rate: 1.161604086636253e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4707  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4740  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.4382  Elapsed: 0:11:27.
# Batch 4,000  of  12,464.  Loss 0.5979  Elapsed: 0:15:15.
# Batch 5,000  of  12,464.  Loss 0.3719  Elapsed: 0:19:04.
# Batch 6,000  of  12,464.  Loss 0.5082  Elapsed: 0:22:52.
# Batch 7,000  of  12,464.  Loss 0.4828  Elapsed: 0:26:40.
# Batch 8,000  of  12,464.  Loss 0.3155  Elapsed: 0:30:29.
# Batch 9,000  of  12,464.  Loss 0.4142  Elapsed: 0:34:17.
# Batch 10,000  of  12,464.  Loss 0.6141  Elapsed: 0:38:05.
# Batch 11,000  of  12,464.  Loss 0.2388  Elapsed: 0:41:53.
# Batch 12,000  of  12,464.  Loss 0.3836  Elapsed: 0:45:42.
#
# Avg Training Loss 0.4212, Completed in 0:47:30
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6724  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6673, Completed in 0:04:22
# Validation F2-score: 0.7448
# Validation Matthew Correlation Coefficient: 0.3365
# Validation Recall: 0.7588
# Validation Precision: 0.6937
# Validation Accuracy: 0.6765

# %%
# Test LR = 6.28e-4, Optim = AdamW. Continue Training
# Store the average loss after each epoch so we can plot them.
best_accuracy = 0
train_loss_values = []
val_loss_values = []
learning_rates = []

for epoch in range(EPOCHS):
    print ('######  Epoch {}/{} ######'.format(epoch+60, EPOCHS+59))
    print('Learning rate:', str(scheduler.get_last_lr()[0]))
    print()
    learning_rates.append(scheduler.get_last_lr())

    print ('-----  Training -----')
    train_loss, train_time = train(train_loader, model, criterion, optimizer)
    train_loss_values.append(train_loss)

    print ('-----  Validation -----')
    val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
    val_loss_values.append(val_loss)
    y_val_true, y_val_score, y_val_pred, val_accuracy = compute_metrics(val_outputs, val_targets, prefix="Validation")
    print()

    # Get the best loss
    is_best = val_accuracy > best_accuracy
    best_accuracy = max(val_accuracy, best_accuracy)

    # Save Checkpoint
    save_checkpoint(
        {'epoch': epoch+1,
         'state_dict': model.state_dict(),
         'best_accuracy': best_accuracy,
         'optimizer': optimizer.state_dict()
         },
        is_best
    )

    if train_loss < 0.2:
        break
# Out:
# ######  Epoch 60/109 ######
# Learning rate: 0.0001
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6127  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.5757  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.3513  Elapsed: 0:11:31.
# Batch 5,000  of  12,464.  Loss 0.5168  Elapsed: 0:19:11.
# Batch 6,000  of  12,464.  Loss 0.5069  Elapsed: 0:23:00.
# Batch 7,000  of  12,464.  Loss 0.5035  Elapsed: 0:26:50.
# Batch 8,000  of  12,464.  Loss 0.2719  Elapsed: 0:30:40.
# Batch 9,000  of  12,464.  Loss 0.5922  Elapsed: 0:34:29.
# Batch 10,000  of  12,464.  Loss 0.5730  Elapsed: 0:38:19.
# Batch 11,000  of  12,464.  Loss 0.5501  Elapsed: 0:42:09.
# Batch 12,000  of  12,464.  Loss 0.5888  Elapsed: 0:45:59.
#
# Avg Training Loss 0.4322, Completed in 0:47:47
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7333  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6874, Completed in 0:04:22
# Validation F2-score: 0.7803
# Validation Matthew Correlation Coefficient: 0.3207
# Validation Recall: 0.8137
# Validation Precision: 0.67
# Validation Accuracy: 0.6705
#
# ######  Epoch 61/109 ######
# Learning rate: 9.990232305720008e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5007  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4787  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.6575  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.3117  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4371  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.5389  Elapsed: 0:23:04.
# Batch 7,000  of  12,464.  Loss 0.3822  Elapsed: 0:26:54.
# Batch 8,000  of  12,464.  Loss 0.6722  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.4708  Elapsed: 0:34:36.
# Batch 10,000  of  12,464.  Loss 0.3315  Elapsed: 0:38:27.
# Batch 11,000  of  12,464.  Loss 0.5000  Elapsed: 0:42:17.
# Batch 12,000  of  12,464.  Loss 0.4358  Elapsed: 0:46:08.
#
# Avg Training Loss 0.4315, Completed in 0:47:55
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6898  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6660, Completed in 0:04:22
# Validation F2-score: 0.7629
# Validation Matthew Correlation Coefficient: 0.3359
# Validation Recall: 0.785
# Validation Precision: 0.6856
# Validation Accuracy: 0.6772
#
# ######  Epoch 62/109 ######
# Learning rate: 9.960967771506713e-05
#
# -----  Training -----
# Batch 2,000  of  12,464.  Loss 0.3407  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.6483  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.4792  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.8410  Elapsed: 0:19:14.
# Batch 6,000  of  12,464.  Loss 0.3400  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.3565  Elapsed: 0:26:55.
# Batch 8,000  of  12,464.  Loss 0.3084  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.3694  Elapsed: 0:34:35.
# Batch 10,000  of  12,464.  Loss 0.5574  Elapsed: 0:38:25.
# Batch 11,000  of  12,464.  Loss 0.2571  Elapsed: 0:42:15.
# Batch 12,000  of  12,464.  Loss 0.4555  Elapsed: 0:46:05.
#
# Avg Training Loss 0.4321, Completed in 0:47:53
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6099  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6484, Completed in 0:04:22
# Validation F2-score: 0.7279
# Validation Matthew Correlation Coefficient: 0.3355
# Validation Recall: 0.7352
# Validation Precision: 0.7003
# Validation Accuracy: 0.6747
#
# ######  Epoch 63/109 ######
# Learning rate: 9.91232189110705e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3897  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4120  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.3571  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.5902  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.6337  Elapsed: 0:19:15.
# Batch 6,000  of  12,464.  Loss 0.4706  Elapsed: 0:23:06.
# Batch 7,000  of  12,464.  Loss 0.4401  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.2955  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.3924  Elapsed: 0:34:36.
# Batch 10,000  of  12,464.  Loss 0.4310  Elapsed: 0:38:26.
# Batch 11,000  of  12,464.  Loss 0.4956  Elapsed: 0:42:16.
# Batch 12,000  of  12,464.  Loss 0.5734  Elapsed: 0:46:06.
#
# Avg Training Loss 0.4317, Completed in 0:47:54
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5845  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6598, Completed in 0:04:22
# Validation F2-score: 0.7513
# Validation Matthew Correlation Coefficient: 0.3464
# Validation Recall: 0.7664
# Validation Precision: 0.6966
# Validation Accuracy: 0.6815
#
# ######  Epoch 64/109 ######
# Learning rate: 9.8444866475868e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4903  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4015  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.2913  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.3194  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.2843  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.5076  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.3761  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.8382  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.5452  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.3032  Elapsed: 0:38:22.
# Batch 11,000  of  12,464.  Loss 0.3509  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.3554  Elapsed: 0:46:02.
#
# Avg Training Loss 0.4318, Completed in 0:47:50
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6883  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6650, Completed in 0:04:22
# Validation F2-score: 0.7238
# Validation Matthew Correlation Coefficient: 0.327
# Validation Recall: 0.7309
# Validation Precision: 0.6969
# Validation Accuracy: 0.6705
#
# ######  Epoch 65/109 ######
# Learning rate: 9.757729755661027e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3355  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2700  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.2928  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.6975  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4540  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.4396  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.3286  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.4234  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.4052  Elapsed: 0:34:33.
# Batch 10,000  of  12,464.  Loss 0.4174  Elapsed: 0:38:23.
# Batch 11,000  of  12,464.  Loss 0.4300  Elapsed: 0:42:13.
# Batch 12,000  of  12,464.  Loss 0.4027  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4315, Completed in 0:47:51
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7084  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6758, Completed in 0:04:22
# Validation F2-score: 0.7499
# Validation Matthew Correlation Coefficient: 0.3293
# Validation Recall: 0.7674
# Validation Precision: 0.6874
# Validation Accuracy: 0.6736
#
# ######  Epoch 66/109 ######
# Learning rate: 9.652393605146821e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4130  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3997  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.3923  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3603  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.3949  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.4748  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.5496  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.4942  Elapsed: 0:30:44.
# Batch 9,000  of  12,464.  Loss 0.4769  Elapsed: 0:34:34.
# Batch 10,000  of  12,464.  Loss 0.3528  Elapsed: 0:38:24.
# Batch 11,000  of  12,464.  Loss 0.3894  Elapsed: 0:42:14.
# Batch 12,000  of  12,464.  Loss 0.6159  Elapsed: 0:46:04.
#
# Avg Training Loss 0.4308, Completed in 0:47:52
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6857  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6658, Completed in 0:04:22
# Validation F2-score: 0.7688
# Validation Matthew Correlation Coefficient: 0.3383
# Validation Recall: 0.7933
# Validation Precision: 0.6842
# Validation Accuracy: 0.6785
#
# ######  Epoch 67/109 ######
# Learning rate: 9.528893909706743e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3665  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4836  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.3234  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3891  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.4841  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.4906  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.3060  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.3681  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.3142  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.7757  Elapsed: 0:38:23.
# Batch 11,000  of  12,464.  Loss 0.4220  Elapsed: 0:42:13.
# Batch 12,000  of  12,464.  Loss 0.5475  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4307, Completed in 0:47:50
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6407  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6517, Completed in 0:04:22
# Validation F2-score: 0.7536
# Validation Matthew Correlation Coefficient: 0.337
# Validation Recall: 0.7713
# Validation Precision: 0.6902
# Validation Accuracy: 0.6773
#
# ######  Epoch 68/109 ######
# Learning rate: 9.387718066217077e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3845  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2941  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.4845  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.5935  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4927  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3563  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.3266  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.5675  Elapsed: 0:30:44.
# Batch 9,000  of  12,464.  Loss 0.3260  Elapsed: 0:34:34.
# Batch 10,000  of  12,464.  Loss 0.3109  Elapsed: 0:38:24.
# Batch 11,000  of  12,464.  Loss 0.4984  Elapsed: 0:42:14.
# Batch 12,000  of  12,464.  Loss 0.3763  Elapsed: 0:46:04.
#
# Avg Training Loss 0.4317, Completed in 0:47:52
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7394  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6671, Completed in 0:04:22
# Validation F2-score: 0.7575
# Validation Matthew Correlation Coefficient: 0.3353
# Validation Recall: 0.7772
# Validation Precision: 0.6875
# Validation Accuracy: 0.6767
#
# ######  Epoch 69/109 ######
# Learning rate: 9.229423231234888e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3647  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.3312  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.5668  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.5816  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4059  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3606  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.4888  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.3883  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.4378  Elapsed: 0:34:33.
# Batch 10,000  of  12,464.  Loss 0.4335  Elapsed: 0:38:24.
# Batch 11,000  of  12,464.  Loss 0.4624  Elapsed: 0:42:14.
# Batch 12,000  of  12,464.  Loss 0.5372  Elapsed: 0:46:04.
#
# Avg Training Loss 0.4299, Completed in 0:47:52
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6582  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6875, Completed in 0:04:22
# Validation F2-score: 0.7854
# Validation Matthew Correlation Coefficient: 0.3334
# Validation Recall: 0.8192
# Validation Precision: 0.6742
# Validation Accuracy: 0.6764
#
# ######  Epoch 70/109 ######
# Learning rate: 9.05463412215589e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4506  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.6997  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.4413  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.3007  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.3812  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.6498  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.2890  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.2921  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.5281  Elapsed: 0:34:34.
# Batch 10,000  of  12,464.  Loss 0.2104  Elapsed: 0:38:24.
# Batch 11,000  of  12,464.  Loss 0.4665  Elapsed: 0:42:15.
# Batch 12,000  of  12,464.  Loss 0.2921  Elapsed: 0:46:05.
#
# Avg Training Loss 0.4296, Completed in 0:47:52
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5978  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6656, Completed in 0:04:22
# Validation F2-score: 0.6443
# Validation Matthew Correlation Coefficient: 0.332
# Validation Recall: 0.6254
# Validation Precision: 0.7332
# Validation Accuracy: 0.662
#
# ######  Epoch 71/109 ######
# Learning rate: 8.864040551739906e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3190  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3181  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.4839  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4118  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.5496  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3449  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.6234  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.3102  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.5204  Elapsed: 0:34:33.
# Batch 10,000  of  12,464.  Loss 0.4389  Elapsed: 0:38:23.
# Batch 11,000  of  12,464.  Loss 0.4542  Elapsed: 0:42:13.
# Batch 12,000  of  12,464.  Loss 0.4309  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4302, Completed in 0:47:51
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6285  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6794, Completed in 0:04:23
# Validation F2-score: 0.7475
# Validation Matthew Correlation Coefficient: 0.3309
# Validation Recall: 0.7636
# Validation Precision: 0.6893
# Validation Accuracy: 0.6742
#
# ######  Epoch 72/109 ######
# Learning rate: 8.65839470573569e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3639  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4078  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.4773  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.3853  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.3327  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.2825  Elapsed: 0:23:04.
# Batch 7,000  of  12,464.  Loss 0.4378  Elapsed: 0:26:54.
# Batch 8,000  of  12,464.  Loss 0.3056  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.6388  Elapsed: 0:34:35.
# Batch 10,000  of  12,464.  Loss 0.2480  Elapsed: 0:38:26.
# Batch 11,000  of  12,464.  Loss 0.4224  Elapsed: 0:42:16.
# Batch 12,000  of  12,464.  Loss 0.3051  Elapsed: 0:46:06.
#
# Avg Training Loss 0.4290, Completed in 0:47:54
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6082  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6525, Completed in 0:04:22
# Validation F2-score: 0.743
# Validation Matthew Correlation Coefficient: 0.3469
# Validation Recall: 0.7545
# Validation Precision: 0.7005
# Validation Accuracy: 0.6812
#
# ######  Epoch 73/109 ######
# Learning rate: 8.438508174346753e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4140  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4429  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.2609  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.4362  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4754  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3437  Elapsed: 0:23:04.
# Batch 7,000  of  12,464.  Loss 0.5110  Elapsed: 0:26:54.
# Batch 8,000  of  12,464.  Loss 0.3670  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.6260  Elapsed: 0:34:35.
# Batch 10,000  of  12,464.  Loss 0.2820  Elapsed: 0:38:25.
# Batch 11,000  of  12,464.  Loss 0.2056  Elapsed: 0:42:15.
# Batch 12,000  of  12,464.  Loss 0.3905  Elapsed: 0:46:05.
#
# Avg Training Loss 0.4280, Completed in 0:47:53
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6574  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6475, Completed in 0:04:22
# Validation F2-score: 0.776
# Validation Matthew Correlation Coefficient: 0.3494
# Validation Recall: 0.8019
# Validation Precision: 0.6871
# Validation Accuracy: 0.6839
#
# ######  Epoch 74/109 ######
# Learning rate: 8.205248749255773e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6079  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3073  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.4911  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4904  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.3236  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.3628  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.5754  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.2755  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.4460  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.4058  Elapsed: 0:38:22.
# Batch 11,000  of  12,464.  Loss 0.4693  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.5075  Elapsed: 0:46:02.
#
# Avg Training Loss 0.4289, Completed in 0:47:50
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6266  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6604, Completed in 0:04:22
# Validation F2-score: 0.7603
# Validation Matthew Correlation Coefficient: 0.3385
# Validation Recall: 0.7807
# Validation Precision: 0.6881
# Validation Accuracy: 0.6783
#
# ######  Epoch 75/109 ######
# Learning rate: 7.959536998847454e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4511  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.6589  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.5306  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3818  Elapsed: 0:15:20.
# Batch 5,000  of  12,464.  Loss 0.4474  Elapsed: 0:19:10.
# Batch 6,000  of  12,464.  Loss 0.4881  Elapsed: 0:23:00.
# Batch 7,000  of  12,464.  Loss 0.5986  Elapsed: 0:26:50.
# Batch 8,000  of  12,464.  Loss 0.4796  Elapsed: 0:30:40.
# Batch 9,000  of  12,464.  Loss 0.4075  Elapsed: 0:34:29.
# Batch 10,000  of  12,464.  Loss 0.3401  Elapsed: 0:38:19.
# Batch 11,000  of  12,464.  Loss 0.3476  Elapsed: 0:42:09.
# Batch 12,000  of  12,464.  Loss 0.4802  Elapsed: 0:46:00.
#
# Avg Training Loss 0.4283, Completed in 0:47:48
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7265  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6621, Completed in 0:04:22
# Validation F2-score: 0.746
# Validation Matthew Correlation Coefficient: 0.3349
# Validation Recall: 0.7608
# Validation Precision: 0.6922
# Validation Accuracy: 0.6759
#
# ######  Epoch 76/109 ######
# Learning rate: 7.702342635145717e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5065  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3326  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.2969  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.4652  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.4076  Elapsed: 0:19:11.
# Batch 6,000  of  12,464.  Loss 0.4561  Elapsed: 0:23:01.
# Batch 7,000  of  12,464.  Loss 0.3759  Elapsed: 0:26:51.
# Batch 8,000  of  12,464.  Loss 0.5322  Elapsed: 0:30:41.
# Batch 9,000  of  12,464.  Loss 0.3699  Elapsed: 0:34:31.
# Batch 10,000  of  12,464.  Loss 0.4343  Elapsed: 0:38:21.
# Batch 11,000  of  12,464.  Loss 0.3505  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.4023  Elapsed: 0:46:02.
#
# Avg Training Loss 0.4272, Completed in 0:47:49
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6555  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6478, Completed in 0:04:22
# Validation F2-score: 0.7577
# Validation Matthew Correlation Coefficient: 0.3493
# Validation Recall: 0.7751
# Validation Precision: 0.6954
# Validation Accuracy: 0.6832
#
# ######  Epoch 77/109 ######
# Learning rate: 7.434680686803255e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4017  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3509  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.4186  Elapsed: 0:11:30.
# Batch 4,000  of  12,464.  Loss 0.4497  Elapsed: 0:15:20.
# Batch 5,000  of  12,464.  Loss 0.3779  Elapsed: 0:19:10.
# Batch 6,000  of  12,464.  Loss 0.5331  Elapsed: 0:23:00.
# Batch 7,000  of  12,464.  Loss 0.2870  Elapsed: 0:26:49.
# Batch 8,000  of  12,464.  Loss 0.5228  Elapsed: 0:30:39.
# Batch 9,000  of  12,464.  Loss 0.3127  Elapsed: 0:34:28.
# Batch 10,000  of  12,464.  Loss 0.3955  Elapsed: 0:38:18.
# Batch 11,000  of  12,464.  Loss 0.3237  Elapsed: 0:42:07.
# Batch 12,000  of  12,464.  Loss 0.4125  Elapsed: 0:45:57.
#
# Avg Training Loss 0.4281, Completed in 0:47:45
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5884  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6442, Completed in 0:04:21
# Validation F2-score: 0.7475
# Validation Matthew Correlation Coefficient: 0.3494
# Validation Recall: 0.7603
# Validation Precision: 0.7
# Validation Accuracy: 0.6826
#
# ######  Epoch 78/109 ######
# Learning rate: 7.157607493246939e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4755  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4000  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.5900  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.3284  Elapsed: 0:15:19.
# Batch 5,000  of  12,464.  Loss 0.3506  Elapsed: 0:19:09.
# Batch 6,000  of  12,464.  Loss 0.3899  Elapsed: 0:22:58.
# Batch 7,000  of  12,464.  Loss 0.3611  Elapsed: 0:26:48.
# Batch 8,000  of  12,464.  Loss 0.3923  Elapsed: 0:30:37.
# Batch 9,000  of  12,464.  Loss 0.3432  Elapsed: 0:34:26.
# Batch 10,000  of  12,464.  Loss 0.4205  Elapsed: 0:38:15.
# Batch 11,000  of  12,464.  Loss 0.6680  Elapsed: 0:42:05.
# Batch 12,000  of  12,464.  Loss 0.3221  Elapsed: 0:45:54.
#
# Avg Training Loss 0.4268, Completed in 0:47:41
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6875  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6603, Completed in 0:04:21
# Validation F2-score: 0.7137
# Validation Matthew Correlation Coefficient: 0.3334
# Validation Recall: 0.7159
# Validation Precision: 0.705
# Validation Accuracy: 0.6724
#
# ######  Epoch 79/109 ######
# Learning rate: 6.872216535789017e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5785  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.1994  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.3369  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.2209  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.3663  Elapsed: 0:19:07.
# Batch 6,000  of  12,464.  Loss 0.2919  Elapsed: 0:22:56.
# Batch 7,000  of  12,464.  Loss 0.5164  Elapsed: 0:26:45.
# Batch 8,000  of  12,464.  Loss 0.3669  Elapsed: 0:30:34.
# Batch 9,000  of  12,464.  Loss 0.5365  Elapsed: 0:34:23.
# Batch 10,000  of  12,464.  Loss 0.5327  Elapsed: 0:38:13.
# Batch 11,000  of  12,464.  Loss 0.4048  Elapsed: 0:42:02.
# Batch 12,000  of  12,464.  Loss 0.4294  Elapsed: 0:45:51.
#
# Avg Training Loss 0.4260, Completed in 0:47:38
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6516  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6731, Completed in 0:04:20
# Validation F2-score: 0.7695
# Validation Matthew Correlation Coefficient: 0.3417
# Validation Recall: 0.7936
# Validation Precision: 0.6858
# Validation Accuracy: 0.6801
#
# ######  Epoch 80/109 ######
# Learning rate: 6.579634122155879e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4753  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3830  Elapsed: 0:07:39.
# Batch 3,000  of  12,464.  Loss 0.6512  Elapsed: 0:11:28.
# Batch 4,000  of  12,464.  Loss 0.3961  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.2834  Elapsed: 0:19:07.
# Batch 6,000  of  12,464.  Loss 0.4962  Elapsed: 0:22:56.
# Batch 7,000  of  12,464.  Loss 0.3948  Elapsed: 0:26:45.
# Batch 8,000  of  12,464.  Loss 0.5884  Elapsed: 0:30:34.
# Batch 9,000  of  12,464.  Loss 0.4595  Elapsed: 0:34:23.
# Batch 10,000  of  12,464.  Loss 0.3083  Elapsed: 0:38:13.
# Batch 11,000  of  12,464.  Loss 0.4353  Elapsed: 0:42:02.
# Batch 12,000  of  12,464.  Loss 0.4051  Elapsed: 0:45:51.
#
# Avg Training Loss 0.4258, Completed in 0:47:38
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6131  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6711, Completed in 0:04:21
# Validation F2-score: 0.7104
# Validation Matthew Correlation Coefficient: 0.3329
# Validation Recall: 0.7115
# Validation Precision: 0.706
# Validation Accuracy: 0.6718
#
# ######  Epoch 81/109 ######
# Learning rate: 6.281014941465887e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3266  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.5340  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.2885  Elapsed: 0:11:30.
# Batch 4,000  of  12,464.  Loss 0.3814  Elapsed: 0:15:19.
# Batch 5,000  of  12,464.  Loss 0.4716  Elapsed: 0:19:08.
# Batch 6,000  of  12,464.  Loss 0.3309  Elapsed: 0:22:58.
# Batch 7,000  of  12,464.  Loss 0.5072  Elapsed: 0:26:48.
# Batch 8,000  of  12,464.  Loss 0.4165  Elapsed: 0:30:37.
# Batch 9,000  of  12,464.  Loss 0.3877  Elapsed: 0:34:26.
# Batch 10,000  of  12,464.  Loss 0.4023  Elapsed: 0:38:16.
# Batch 11,000  of  12,464.  Loss 0.4404  Elapsed: 0:42:05.
# Batch 12,000  of  12,464.  Loss 0.3315  Elapsed: 0:45:54.
#
# Avg Training Loss 0.4258, Completed in 0:47:41
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.7327  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6722, Completed in 0:04:21
# Validation F2-score: 0.7804
# Validation Matthew Correlation Coefficient: 0.3327
# Validation Recall: 0.8117
# Validation Precision: 0.6761
# Validation Accuracy: 0.6761
#
# ######  Epoch 82/109 ######
# Learning rate: 5.977537507200494e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3845  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4840  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.4767  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.3630  Elapsed: 0:15:19.
# Batch 5,000  of  12,464.  Loss 0.3188  Elapsed: 0:19:08.
# Batch 6,000  of  12,464.  Loss 0.3708  Elapsed: 0:22:57.
# Batch 7,000  of  12,464.  Loss 0.2977  Elapsed: 0:26:47.
# Batch 8,000  of  12,464.  Loss 0.4698  Elapsed: 0:30:36.
# Batch 9,000  of  12,464.  Loss 0.3867  Elapsed: 0:34:26.
# Batch 10,000  of  12,464.  Loss 0.4607  Elapsed: 0:38:15.
# Batch 11,000  of  12,464.  Loss 0.5264  Elapsed: 0:42:05.
# Batch 12,000  of  12,464.  Loss 0.4769  Elapsed: 0:45:54.
#
# Avg Training Loss 0.4255, Completed in 0:47:42
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6542  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6644, Completed in 0:04:21
# Validation F2-score: 0.7358
# Validation Matthew Correlation Coefficient: 0.3351
# Validation Recall: 0.7463
# Validation Precision: 0.6967
# Validation Accuracy: 0.6752
#
# ######  Epoch 83/109 ######
# Learning rate: 5.6703995061444005e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4887  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4373  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3708  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4423  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.3581  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.3763  Elapsed: 0:23:01.
# Batch 7,000  of  12,464.  Loss 0.3789  Elapsed: 0:26:51.
# Batch 8,000  of  12,464.  Loss 0.4022  Elapsed: 0:30:41.
# Batch 9,000  of  12,464.  Loss 0.6053  Elapsed: 0:34:31.
# Batch 10,000  of  12,464.  Loss 0.2476  Elapsed: 0:38:21.
# Batch 11,000  of  12,464.  Loss 0.2819  Elapsed: 0:42:11.
# Batch 12,000  of  12,464.  Loss 0.6184  Elapsed: 0:46:01.
#
# Avg Training Loss 0.4249, Completed in 0:47:49
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6263  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6571, Completed in 0:04:22
# Validation F2-score: 0.7508
# Validation Matthew Correlation Coefficient: 0.346
# Validation Recall: 0.7657
# Validation Precision: 0.6965
# Validation Accuracy: 0.6813
#
# ######  Epoch 84/109 ######
# Learning rate: 5.360813071671126e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5344  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.5029  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3862  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.2851  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.5216  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3633  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.3191  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.2799  Elapsed: 0:30:44.
# Batch 9,000  of  12,464.  Loss 0.4322  Elapsed: 0:34:34.
# Batch 10,000  of  12,464.  Loss 0.3111  Elapsed: 0:38:25.
# Batch 11,000  of  12,464.  Loss 0.3949  Elapsed: 0:42:15.
# Batch 12,000  of  12,464.  Loss 0.4727  Elapsed: 0:46:06.
#
# Avg Training Loss 0.4227, Completed in 0:47:54
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6758  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6644, Completed in 0:04:23
# Validation F2-score: 0.7537
# Validation Matthew Correlation Coefficient: 0.3356
# Validation Recall: 0.7716
# Validation Precision: 0.6894
# Validation Accuracy: 0.6767
#
# ######  Epoch 85/109 ######
# Learning rate: 5.050000000000965e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4387  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2371  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.3969  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.3843  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.4854  Elapsed: 0:19:15.
# Batch 6,000  of  12,464.  Loss 0.2146  Elapsed: 0:23:06.
# Batch 7,000  of  12,464.  Loss 0.5921  Elapsed: 0:26:57.
# Batch 8,000  of  12,464.  Loss 0.4245  Elapsed: 0:30:47.
# Batch 9,000  of  12,464.  Loss 0.5385  Elapsed: 0:34:38.
# Batch 10,000  of  12,464.  Loss 0.5999  Elapsed: 0:38:28.
# Batch 11,000  of  12,464.  Loss 0.3443  Elapsed: 0:42:19.
# Batch 12,000  of  12,464.  Loss 0.3471  Elapsed: 0:46:10.
#
# Avg Training Loss 0.4227, Completed in 0:47:58
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6428  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6608, Completed in 0:04:23
# Validation F2-score: 0.7405
# Validation Matthew Correlation Coefficient: 0.3364
# Validation Recall: 0.7527
# Validation Precision: 0.6954
# Validation Accuracy: 0.6762
#
# ######  Epoch 86/109 ######
# Learning rate: 4.739186928330775e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2996  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4454  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.3627  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.4823  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.4852  Elapsed: 0:19:15.
# Batch 6,000  of  12,464.  Loss 0.4069  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.4298  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.5994  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.6789  Elapsed: 0:34:36.
# Batch 10,000  of  12,464.  Loss 0.3052  Elapsed: 0:38:27.
# Batch 11,000  of  12,464.  Loss 0.7359  Elapsed: 0:42:17.
# Batch 12,000  of  12,464.  Loss 0.3931  Elapsed: 0:46:07.
#
# Avg Training Loss 0.4220, Completed in 0:47:54
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6162  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6597, Completed in 0:04:22
# Validation F2-score: 0.7085
# Validation Matthew Correlation Coefficient: 0.3409
# Validation Recall: 0.7077
# Validation Precision: 0.7118
# Validation Accuracy: 0.6751
#
# ######  Epoch 87/109 ######
# Learning rate: 4.4296004938574774e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4875  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4043  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.2557  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4573  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.3931  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.4123  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.3126  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.4476  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.4529  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.5111  Elapsed: 0:38:22.
# Batch 11,000  of  12,464.  Loss 0.5066  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.4268  Elapsed: 0:46:02.
#
# Avg Training Loss 0.4222, Completed in 0:47:50
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6084  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6590, Completed in 0:04:22
# Validation F2-score: 0.6972
# Validation Matthew Correlation Coefficient: 0.346
# Validation Recall: 0.6917
# Validation Precision: 0.72
# Validation Accuracy: 0.676
#
# ######  Epoch 88/109 ######
# Learning rate: 4.122462492801404e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5714  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4574  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.3761  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3814  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.4831  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.5516  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.2034  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.5180  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.6386  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.3907  Elapsed: 0:38:22.
# Batch 11,000  of  12,464.  Loss 0.4961  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.3199  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4221, Completed in 0:47:51
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6027  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6649, Completed in 0:04:22
# Validation F2-score: 0.7322
# Validation Matthew Correlation Coefficient: 0.3373
# Validation Recall: 0.7409
# Validation Precision: 0.6995
# Validation Accuracy: 0.6759
#
# ######  Epoch 89/109 ######
# Learning rate: 3.818985058534664e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3813  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.3153  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.4029  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.3945  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.3783  Elapsed: 0:19:14.
# Batch 6,000  of  12,464.  Loss 0.2613  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.6312  Elapsed: 0:26:55.
# Batch 8,000  of  12,464.  Loss 0.4033  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.4637  Elapsed: 0:34:37.
# Batch 10,000  of  12,464.  Loss 0.4269  Elapsed: 0:38:27.
# Batch 11,000  of  12,464.  Loss 0.3802  Elapsed: 0:42:18.
# Batch 12,000  of  12,464.  Loss 0.6071  Elapsed: 0:46:09.
#
# Avg Training Loss 0.4208, Completed in 0:47:57
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6337  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6574, Completed in 0:04:23
# Validation F2-score: 0.7257
# Validation Matthew Correlation Coefficient: 0.3478
# Validation Recall: 0.73
# Validation Precision: 0.7087
# Validation Accuracy: 0.6801
#
# ######  Epoch 90/109 ######
# Learning rate: 3.520365877844653e-05
#
# -----  Training -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 15
#      12 learning_rates.append(scheduler.get_last_lr())
#      14 print ('-----  Training -----')
# ---> 15 train_loss, train_time = train(train_loader, model, criterion, optimizer)
#      16 train_loss_values.append(train_loss)
#      18 print ('-----  Validation -----')
#
# Cell In[39], line 33, in train(train_loader, model, criterion, optimizer, verbose)
#      30 loss = criterion(output, target)
#      32 # Accumulate the training loss over all of the batches
# ---> 33 total_loss += loss.item()
#      35 # Report progress every 200 batches
#      36 if step % 1000 == 0 and not step == 0 and verbose==True:
#
# KeyboardInterrupt:

# %%
# # Test LR = 6.28e-4, Optim = AdamW. Continue Training
# # Store the average loss after each epoch so we can plot them.
# best_accuracy = 0
# train_loss_values = []
# val_loss_values = []
# learning_rates = []

# for epoch in range(EPOCHS):
#     print ('######  Epoch {}/{} ######'.format(epoch+60, EPOCHS+59))
#     print('Learning rate:', str(scheduler.get_last_lr()[0]))
#     print()
#     learning_rates.append(scheduler.get_last_lr())

#     print ('-----  Training -----')
#     train_loss, train_time = train(train_loader, model, criterion, optimizer)
#     train_loss_values.append(train_loss)

#     print ('-----  Validation -----')
#     val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
#     val_loss_values.append(val_loss)
#     y_val_true, y_val_score, y_val_pred, val_accuracy = compute_metrics(val_outputs, val_targets, prefix="Validation")
#     print()

#     # Get the best loss
#     is_best = val_accuracy > best_accuracy
#     best_accuracy = max(val_accuracy, best_accuracy)

#     # Save Checkpoint
#     save_checkpoint(
#         {'epoch': epoch+1,
#          'state_dict': model.state_dict(),
#          'best_accuracy': best_accuracy,
#          'optimizer': optimizer.state_dict()
#          },
#         is_best
#     )

#     if train_loss < 0.2:
#         break
# Out:
# ######  Epoch 60/89 ######
# Learning rate: 4.671169657780796e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6416  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3149  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3882  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4811  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.2350  Elapsed: 0:19:14.
# Batch 6,000  of  12,464.  Loss 0.3734  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.2929  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.5437  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.4655  Elapsed: 0:34:37.
# Batch 10,000  of  12,464.  Loss 0.4469  Elapsed: 0:38:28.
# Batch 12,000  of  12,464.  Loss 0.2974  Elapsed: 0:46:09.
#
# Avg Training Loss 0.4135, Completed in 0:47:58
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5978  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6657, Completed in 0:04:23
# Validation F2-score: 0.7374
# Validation Matthew Correlation Coefficient: 0.3458
# Validation Recall: 0.7467
# Validation Precision: 0.7024
# Validation Accuracy: 0.6802
#
# ######  Epoch 61/89 ######
# Learning rate: 3.3229156299012764e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4042  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.3914  Elapsed: 0:07:44.
# Batch 3,000  of  12,464.  Loss 0.6502  Elapsed: 0:11:35.
# Batch 4,000  of  12,464.  Loss 0.4984  Elapsed: 0:15:26.
# Batch 5,000  of  12,464.  Loss 0.4565  Elapsed: 0:19:18.
# Batch 6,000  of  12,464.  Loss 0.5178  Elapsed: 0:23:09.
# Batch 7,000  of  12,464.  Loss 0.3583  Elapsed: 0:27:01.
# Batch 8,000  of  12,464.  Loss 0.3738  Elapsed: 0:30:52.
# Batch 9,000  of  12,464.  Loss 0.6161  Elapsed: 0:34:44.
# Batch 10,000  of  12,464.  Loss 0.5363  Elapsed: 0:38:35.
# Batch 11,000  of  12,464.  Loss 0.4370  Elapsed: 0:42:27.
# Batch 12,000  of  12,464.  Loss 0.3623  Elapsed: 0:46:18.
#
# Avg Training Loss 0.4115, Completed in 0:48:07
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6275  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6732, Completed in 0:04:23
# Validation F2-score: 0.7552
# Validation Matthew Correlation Coefficient: 0.3421
# Validation Recall: 0.7727
# Validation Precision: 0.6924
# Validation Accuracy: 0.6798
#
# ######  Epoch 62/89 ######
# Learning rate: 2.2724194255508205e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2723  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.7153  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.5803  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.3952  Elapsed: 0:15:25.
# Batch 5,000  of  12,464.  Loss 0.2980  Elapsed: 0:19:16.
# Batch 6,000  of  12,464.  Loss 0.4869  Elapsed: 0:23:06.
# Batch 7,000  of  12,464.  Loss 0.3144  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.4142  Elapsed: 0:30:47.
# Batch 9,000  of  12,464.  Loss 0.3111  Elapsed: 0:34:37.
# Batch 10,000  of  12,464.  Loss 0.3740  Elapsed: 0:38:28.
# Batch 11,000  of  12,464.  Loss 0.3666  Elapsed: 0:42:18.
# Batch 12,000  of  12,464.  Loss 0.2926  Elapsed: 0:46:09.
#
# Avg Training Loss 0.4106, Completed in 0:47:57
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6089  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6669, Completed in 0:04:23
# Validation F2-score: 0.7466
# Validation Matthew Correlation Coefficient: 0.3445
# Validation Recall: 0.76
# Validation Precision: 0.6975
# Validation Accuracy: 0.6803
#
# ######  Epoch 63/89 ######
# Learning rate: 1.5311905009737042e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4172  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4909  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.2520  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.3256  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.5632  Elapsed: 0:19:14.
# Batch 6,000  of  12,464.  Loss 0.5206  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.6865  Elapsed: 0:26:55.
# Batch 8,000  of  12,464.  Loss 0.6823  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.4479  Elapsed: 0:34:36.
# Batch 10,000  of  12,464.  Loss 0.5774  Elapsed: 0:38:27.
# Batch 11,000  of  12,464.  Loss 0.4833  Elapsed: 0:42:19.
# Batch 12,000  of  12,464.  Loss 0.2375  Elapsed: 0:46:10.
#
# Avg Training Loss 0.4096, Completed in 0:47:58
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5899  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6694, Completed in 0:04:23
# Validation F2-score: 0.7421
# Validation Matthew Correlation Coefficient: 0.3428
# Validation Recall: 0.7539
# Validation Precision: 0.6985
# Validation Accuracy: 0.6792
#
# ######  Epoch 64/89 ######
# Learning rate: 1.1073499153816246e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2041  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.6194  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.5172  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.4565  Elapsed: 0:15:26.
# Batch 5,000  of  12,464.  Loss 0.4065  Elapsed: 0:19:16.
# Batch 6,000  of  12,464.  Loss 0.3811  Elapsed: 0:23:07.
# Batch 7,000  of  12,464.  Loss 0.3347  Elapsed: 0:26:57.
# Batch 8,000  of  12,464.  Loss 0.4722  Elapsed: 0:30:48.
# Batch 9,000  of  12,464.  Loss 0.4289  Elapsed: 0:34:39.
# Batch 10,000  of  12,464.  Loss 0.2553  Elapsed: 0:38:30.
# Batch 11,000  of  12,464.  Loss 0.3161  Elapsed: 0:42:21.
# Batch 12,000  of  12,464.  Loss 0.2353  Elapsed: 0:46:11.
#
# Avg Training Loss 0.4099, Completed in 0:47:59
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5867  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6681, Completed in 0:04:23
# Validation F2-score: 0.7368
# Validation Matthew Correlation Coefficient: 0.3419
# Validation Recall: 0.7465
# Validation Precision: 0.7003
# Validation Accuracy: 0.6784
#
# ######  Epoch 65/89 ######
# Learning rate: 1.0055413554428501e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3764  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.7635  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.3417  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.3790  Elapsed: 0:15:25.
# Batch 5,000  of  12,464.  Loss 0.3402  Elapsed: 0:19:16.
# Batch 6,000  of  12,464.  Loss 0.3852  Elapsed: 0:23:07.
# Batch 7,000  of  12,464.  Loss 0.3482  Elapsed: 0:26:58.
# Batch 8,000  of  12,464.  Loss 0.4817  Elapsed: 0:30:49.
# Batch 9,000  of  12,464.  Loss 0.3429  Elapsed: 0:34:40.
# Batch 10,000  of  12,464.  Loss 0.5560  Elapsed: 0:38:32.
# Batch 11,000  of  12,464.  Loss 0.3723  Elapsed: 0:42:23.
# Batch 12,000  of  12,464.  Loss 0.2560  Elapsed: 0:46:14.
#
# Avg Training Loss 0.4115, Completed in 0:48:02
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5979  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6614, Completed in 0:04:23
# Validation F2-score: 0.7503
# Validation Matthew Correlation Coefficient: 0.3462
# Validation Recall: 0.765
# Validation Precision: 0.6969
# Validation Accuracy: 0.6813
#
# ######  Epoch 66/89 ######
# Learning rate: 1.2268802767107564e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4219  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4200  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.4286  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.3790  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.5453  Elapsed: 0:19:15.
# Batch 6,000  of  12,464.  Loss 0.2854  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.3889  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.3725  Elapsed: 0:30:47.
# Batch 9,000  of  12,464.  Loss 0.2548  Elapsed: 0:34:38.
# Batch 10,000  of  12,464.  Loss 0.2704  Elapsed: 0:38:28.
# Batch 11,000  of  12,464.  Loss 0.4323  Elapsed: 0:42:19.
# Batch 12,000  of  12,464.  Loss 0.2399  Elapsed: 0:46:10.
#
# Avg Training Loss 0.4098, Completed in 0:47:58
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6077  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6710, Completed in 0:04:23
# Validation F2-score: 0.7545
# Validation Matthew Correlation Coefficient: 0.3452
# Validation Recall: 0.7712
# Validation Precision: 0.6944
# Validation Accuracy: 0.6811
#
# ######  Epoch 67/89 ######
# Learning rate: 1.7689416536836184e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3035  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2493  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.5454  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.6530  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.5052  Elapsed: 0:19:15.
# Batch 6,000  of  12,464.  Loss 0.3756  Elapsed: 0:23:06.
# Batch 7,000  of  12,464.  Loss 0.4667  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.2899  Elapsed: 0:30:48.
# Batch 9,000  of  12,464.  Loss 0.4336  Elapsed: 0:34:39.
# Batch 10,000  of  12,464.  Loss 0.5084  Elapsed: 0:38:30.
# Batch 11,000  of  12,464.  Loss 0.3876  Elapsed: 0:42:21.
# Batch 12,000  of  12,464.  Loss 0.5126  Elapsed: 0:46:11.
#
# Avg Training Loss 0.4114, Completed in 0:47:59
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5881  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6664, Completed in 0:04:23
# Validation F2-score: 0.7552
# Validation Matthew Correlation Coefficient: 0.3413
# Validation Recall: 0.7729
# Validation Precision: 0.6919
# Validation Accuracy: 0.6794
#
# ######  Epoch 68/89 ######
# Learning rate: 2.625786548481917e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3910  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2298  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3830  Elapsed: 0:11:33.
# Batch 4,000  of  12,464.  Loss 0.2382  Elapsed: 0:15:24.
# Batch 5,000  of  12,464.  Loss 0.2472  Elapsed: 0:19:14.
# Batch 6,000  of  12,464.  Loss 0.4882  Elapsed: 0:23:05.
# Batch 7,000  of  12,464.  Loss 0.3865  Elapsed: 0:26:56.
# Batch 8,000  of  12,464.  Loss 0.4247  Elapsed: 0:30:46.
# Batch 9,000  of  12,464.  Loss 0.5282  Elapsed: 0:34:37.
# Batch 10,000  of  12,464.  Loss 0.4054  Elapsed: 0:38:27.
# Batch 11,000  of  12,464.  Loss 0.4918  Elapsed: 0:42:18.
# Batch 12,000  of  12,464.  Loss 0.3798  Elapsed: 0:46:09.
#
# Avg Training Loss 0.4123, Completed in 0:47:57
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5832  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6605, Completed in 0:04:23
# Validation F2-score: 0.7432
# Validation Matthew Correlation Coefficient: 0.3456
# Validation Recall: 0.7549
# Validation Precision: 0.6997
# Validation Accuracy: 0.6806
#
# ######  Epoch 69/89 ######
# Learning rate: 3.78802718913443e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5675  Elapsed: 0:03:53.
# Batch 2,000  of  12,464.  Loss 0.5264  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.3148  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.4367  Elapsed: 0:15:25.
# Batch 5,000  of  12,464.  Loss 0.3516  Elapsed: 0:19:17.
# Batch 6,000  of  12,464.  Loss 0.4623  Elapsed: 0:23:08.
# Batch 7,000  of  12,464.  Loss 0.3924  Elapsed: 0:26:59.
# Batch 8,000  of  12,464.  Loss 0.3750  Elapsed: 0:30:49.
# Batch 9,000  of  12,464.  Loss 0.5826  Elapsed: 0:34:40.
# Batch 10,000  of  12,464.  Loss 0.2702  Elapsed: 0:38:30.
# Batch 11,000  of  12,464.  Loss 0.3648  Elapsed: 0:42:21.
# Batch 12,000  of  12,464.  Loss 0.4289  Elapsed: 0:46:11.
#
# Avg Training Loss 0.4139, Completed in 0:47:59
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6147  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6799, Completed in 0:04:23
# Validation F2-score: 0.7522
# Validation Matthew Correlation Coefficient: 0.3413
# Validation Recall: 0.7686
# Validation Precision: 0.6932
# Validation Accuracy: 0.6792
#
# ######  Epoch 70/89 ######
# Learning rate: 5.242929823964319e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4189  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.3809  Elapsed: 0:07:44.
# Batch 3,000  of  12,464.  Loss 0.3533  Elapsed: 0:11:35.
# Batch 4,000  of  12,464.  Loss 0.7568  Elapsed: 0:15:26.
# Batch 5,000  of  12,464.  Loss 0.3997  Elapsed: 0:19:16.
# Batch 6,000  of  12,464.  Loss 0.3663  Elapsed: 0:23:07.
# Batch 7,000  of  12,464.  Loss 0.4027  Elapsed: 0:26:57.
# Batch 8,000  of  12,464.  Loss 0.4943  Elapsed: 0:30:48.
# Batch 9,000  of  12,464.  Loss 0.2564  Elapsed: 0:34:38.
# Batch 10,000  of  12,464.  Loss 0.6792  Elapsed: 0:38:29.
# Batch 11,000  of  12,464.  Loss 0.4010  Elapsed: 0:42:19.
# Batch 12,000  of  12,464.  Loss 0.4336  Elapsed: 0:46:10.
#
# Avg Training Loss 0.4166, Completed in 0:47:57
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5694  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6615, Completed in 0:04:23
# Validation F2-score: 0.7348
# Validation Matthew Correlation Coefficient: 0.3488
# Validation Recall: 0.7426
# Validation Precision: 0.7053
# Validation Accuracy: 0.6814
#
# ######  Epoch 71/89 ######
# Learning rate: 6.97455423524927e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3385  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.4170  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.6524  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.3651  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4344  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.3820  Elapsed: 0:23:04.
# Batch 7,000  of  12,464.  Loss 0.4305  Elapsed: 0:26:54.
# Batch 8,000  of  12,464.  Loss 0.3564  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.6507  Elapsed: 0:34:35.
# Batch 10,000  of  12,464.  Loss 0.5026  Elapsed: 0:38:26.
# Batch 11,000  of  12,464.  Loss 0.3211  Elapsed: 0:42:17.
# Batch 12,000  of  12,464.  Loss 0.2702  Elapsed: 0:46:08.
#
# Avg Training Loss 0.4195, Completed in 0:47:56
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6499  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.7453, Completed in 0:04:23
# Validation F2-score: 0.8115
# Validation Matthew Correlation Coefficient: 0.3274
# Validation Recall: 0.8612
# Validation Precision: 0.6593
# Validation Accuracy: 0.6723
#
# ######  Epoch 72/89 ######
# Learning rate: 8.963928383570688e-05
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4704  Elapsed: 0:03:53.
# Batch 2,000  of  12,464.  Loss 0.4800  Elapsed: 0:07:44.
# Batch 3,000  of  12,464.  Loss 0.4492  Elapsed: 0:11:35.
# Batch 4,000  of  12,464.  Loss 0.4152  Elapsed: 0:15:26.
# Batch 5,000  of  12,464.  Loss 0.5690  Elapsed: 0:19:17.
# Batch 6,000  of  12,464.  Loss 0.2533  Elapsed: 0:23:08.
# Batch 7,000  of  12,464.  Loss 0.3986  Elapsed: 0:26:58.
# Batch 8,000  of  12,464.  Loss 0.5128  Elapsed: 0:30:49.
# Batch 9,000  of  12,464.  Loss 0.5547  Elapsed: 0:34:39.
# Batch 10,000  of  12,464.  Loss 0.3887  Elapsed: 0:38:30.
# Batch 11,000  of  12,464.  Loss 0.4078  Elapsed: 0:42:21.
# Batch 12,000  of  12,464.  Loss 0.2736  Elapsed: 0:46:11.
#
# Avg Training Loss 0.4217, Completed in 0:47:59
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6249  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6722, Completed in 0:04:23
# Validation F2-score: 0.7247
# Validation Matthew Correlation Coefficient: 0.3284
# Validation Recall: 0.7319
# Validation Precision: 0.6974
# Validation Accuracy: 0.6713
#
# ######  Epoch 73/89 ######
# Learning rate: 0.0001118925626945718
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4971  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.3745  Elapsed: 0:07:43.
# Batch 3,000  of  12,464.  Loss 0.4887  Elapsed: 0:11:34.
# Batch 4,000  of  12,464.  Loss 0.2897  Elapsed: 0:15:25.
# Batch 5,000  of  12,464.  Loss 0.5167  Elapsed: 0:19:16.
# Batch 6,000  of  12,464.  Loss 0.3320  Elapsed: 0:23:07.
# Batch 7,000  of  12,464.  Loss 0.4149  Elapsed: 0:26:59.
# Batch 8,000  of  12,464.  Loss 0.5596  Elapsed: 0:30:50.
# Batch 9,000  of  12,464.  Loss 0.4268  Elapsed: 0:34:40.
# Batch 10,000  of  12,464.  Loss 0.5893  Elapsed: 0:38:31.
# Batch 11,000  of  12,464.  Loss 0.4797  Elapsed: 0:42:22.
# Batch 12,000  of  12,464.  Loss 0.4548  Elapsed: 0:46:13.
#
# Avg Training Loss 0.4236, Completed in 0:48:01
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5637  Elapsed: 0:03:30.
#
# Avg Validation Loss 0.6647, Completed in 0:04:23
# Validation F2-score: 0.7651
# Validation Matthew Correlation Coefficient: 0.3467
# Validation Recall: 0.7863
# Validation Precision: 0.6905
# Validation Accuracy: 0.6823
#
# ######  Epoch 74/89 ######
# Learning rate: 0.00013626156734915042
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4534  Elapsed: 0:03:52.
# Batch 2,000  of  12,464.  Loss 0.2262  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3991  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.5152  Elapsed: 0:15:23.
# Batch 5,000  of  12,464.  Loss 0.4191  Elapsed: 0:19:13.
# Batch 6,000  of  12,464.  Loss 0.4039  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.4664  Elapsed: 0:26:54.
# Batch 8,000  of  12,464.  Loss 0.5030  Elapsed: 0:30:45.
# Batch 9,000  of  12,464.  Loss 0.3650  Elapsed: 0:34:35.
# Batch 10,000  of  12,464.  Loss 0.5991  Elapsed: 0:38:26.
# Batch 11,000  of  12,464.  Loss 0.3324  Elapsed: 0:42:16.
# Batch 12,000  of  12,464.  Loss 0.3070  Elapsed: 0:46:06.
#
# Avg Training Loss 0.4286, Completed in 0:47:54
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5218  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6636, Completed in 0:04:22
# Validation F2-score: 0.727
# Validation Matthew Correlation Coefficient: 0.3486
# Validation Recall: 0.7317
# Validation Precision: 0.7086
# Validation Accuracy: 0.6805
#
# ######  Epoch 75/89 ######
# Learning rate: 0.00016247930588484256
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2826  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3508  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.3951  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.2671  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.4586  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.4654  Elapsed: 0:23:03.
# Batch 7,000  of  12,464.  Loss 0.3927  Elapsed: 0:26:53.
# Batch 8,000  of  12,464.  Loss 0.2848  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.4844  Elapsed: 0:34:33.
# Batch 10,000  of  12,464.  Loss 0.3040  Elapsed: 0:38:23.
# Batch 11,000  of  12,464.  Loss 0.6460  Elapsed: 0:42:13.
# Batch 12,000  of  12,464.  Loss 0.6010  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4309, Completed in 0:47:51
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6165  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6468, Completed in 0:04:21
# Validation F2-score: 0.7722
# Validation Matthew Correlation Coefficient: 0.3446
# Validation Recall: 0.7972
# Validation Precision: 0.6862
# Validation Accuracy: 0.6815
#
# ######  Epoch 76/89 ######
# Learning rate: 0.00019025853127186453
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.8959  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4140  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.6612  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3288  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.4678  Elapsed: 0:19:10.
# Batch 6,000  of  12,464.  Loss 0.3232  Elapsed: 0:23:00.
# Batch 7,000  of  12,464.  Loss 0.6615  Elapsed: 0:26:50.
# Batch 8,000  of  12,464.  Loss 0.5102  Elapsed: 0:30:40.
# Batch 9,000  of  12,464.  Loss 0.4275  Elapsed: 0:34:30.
# Batch 10,000  of  12,464.  Loss 0.4247  Elapsed: 0:38:19.
# Batch 11,000  of  12,464.  Loss 0.5059  Elapsed: 0:42:09.
# Batch 12,000  of  12,464.  Loss 0.5768  Elapsed: 0:45:58.
#
# Avg Training Loss 0.4359, Completed in 0:47:46
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6891  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6689, Completed in 0:04:21
# Validation F2-score: 0.7808
# Validation Matthew Correlation Coefficient: 0.3288
# Validation Recall: 0.8131
# Validation Precision: 0.6739
# Validation Accuracy: 0.6743
#
# ######  Epoch 77/89 ######
# Learning rate: 0.00021929488850369375
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.3989  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4475  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.4931  Elapsed: 0:11:30.
# Batch 4,000  of  12,464.  Loss 0.6842  Elapsed: 0:15:19.
# Batch 5,000  of  12,464.  Loss 0.4590  Elapsed: 0:19:09.
# Batch 6,000  of  12,464.  Loss 0.3151  Elapsed: 0:22:58.
# Batch 7,000  of  12,464.  Loss 0.5304  Elapsed: 0:26:48.
# Batch 8,000  of  12,464.  Loss 0.4591  Elapsed: 0:30:37.
# Batch 9,000  of  12,464.  Loss 0.5643  Elapsed: 0:34:27.
# Batch 10,000  of  12,464.  Loss 0.5992  Elapsed: 0:38:16.
# Batch 11,000  of  12,464.  Loss 0.3251  Elapsed: 0:42:06.
# Batch 12,000  of  12,464.  Loss 0.4461  Elapsed: 0:45:55.
#
# Avg Training Loss 0.4390, Completed in 0:47:42
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5345  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6464, Completed in 0:04:21
# Validation F2-score: 0.7173
# Validation Matthew Correlation Coefficient: 0.3296
# Validation Recall: 0.7215
# Validation Precision: 0.7012
# Validation Accuracy: 0.6711
#
# ######  Epoch 78/89 ######
# Learning rate: 0.0002492702491742834
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4193  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3526  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.5057  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.3124  Elapsed: 0:15:19.
# Batch 5,000  of  12,464.  Loss 0.3739  Elapsed: 0:19:08.
# Batch 6,000  of  12,464.  Loss 0.4165  Elapsed: 0:22:57.
# Batch 7,000  of  12,464.  Loss 0.5263  Elapsed: 0:26:47.
# Batch 8,000  of  12,464.  Loss 0.2762  Elapsed: 0:30:37.
# Batch 9,000  of  12,464.  Loss 0.3721  Elapsed: 0:34:27.
# Batch 10,000  of  12,464.  Loss 0.4776  Elapsed: 0:38:16.
# Batch 11,000  of  12,464.  Loss 0.3824  Elapsed: 0:42:06.
# Batch 12,000  of  12,464.  Loss 0.4870  Elapsed: 0:45:55.
#
# Avg Training Loss 0.4433, Completed in 0:47:42
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5453  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.7117, Completed in 0:04:21
# Validation F2-score: 0.7488
# Validation Matthew Correlation Coefficient: 0.3182
# Validation Recall: 0.7677
# Validation Precision: 0.6817
# Validation Accuracy: 0.6685
#
# ######  Epoch 79/89 ######
# Learning rate: 0.0002798561969593619
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.2936  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.3809  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.2921  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.3871  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.4368  Elapsed: 0:19:08.
# Batch 6,000  of  12,464.  Loss 0.5802  Elapsed: 0:22:57.
# Batch 7,000  of  12,464.  Loss 0.5022  Elapsed: 0:26:46.
# Batch 8,000  of  12,464.  Loss 0.5715  Elapsed: 0:30:36.
# Batch 9,000  of  12,464.  Loss 0.5570  Elapsed: 0:34:25.
# Batch 10,000  of  12,464.  Loss 0.3872  Elapsed: 0:38:14.
# Batch 11,000  of  12,464.  Loss 0.3431  Elapsed: 0:42:03.
# Batch 12,000  of  12,464.  Loss 0.4402  Elapsed: 0:45:52.
#
# Avg Training Loss 0.4471, Completed in 0:47:40
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5258  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.7069, Completed in 0:04:21
# Validation F2-score: 0.8103
# Validation Matthew Correlation Coefficient: 0.3337
# Validation Recall: 0.8581
# Validation Precision: 0.6629
# Validation Accuracy: 0.6754
#
# ######  Epoch 80/89 ######
# Learning rate: 0.0003107176258144391
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4523  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.4050  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.4968  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.4180  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.2607  Elapsed: 0:19:07.
# Batch 6,000  of  12,464.  Loss 0.4083  Elapsed: 0:22:56.
# Batch 7,000  of  12,464.  Loss 0.2812  Elapsed: 0:26:46.
# Batch 8,000  of  12,464.  Loss 0.5938  Elapsed: 0:30:35.
# Batch 9,000  of  12,464.  Loss 0.4692  Elapsed: 0:34:24.
# Batch 10,000  of  12,464.  Loss 0.3179  Elapsed: 0:38:13.
# Batch 11,000  of  12,464.  Loss 0.3007  Elapsed: 0:42:03.
# Batch 12,000  of  12,464.  Loss 0.5528  Elapsed: 0:45:52.
#
# Avg Training Loss 0.4510, Completed in 0:47:39
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5016  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6649, Completed in 0:04:21
# Validation F2-score: 0.7086
# Validation Matthew Correlation Coefficient: 0.3224
# Validation Recall: 0.7107
# Validation Precision: 0.7003
# Validation Accuracy: 0.6669
#
# ######  Epoch 81/89 ######
# Learning rate: 0.0003415164114668343
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4447  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3477  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.4552  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.3841  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.3933  Elapsed: 0:19:07.
# Batch 6,000  of  12,464.  Loss 0.3278  Elapsed: 0:22:57.
# Batch 7,000  of  12,464.  Loss 0.3796  Elapsed: 0:26:46.
# Batch 8,000  of  12,464.  Loss 0.4404  Elapsed: 0:30:35.
# Batch 9,000  of  12,464.  Loss 0.4768  Elapsed: 0:34:24.
# Batch 10,000  of  12,464.  Loss 0.4815  Elapsed: 0:38:14.
# Batch 11,000  of  12,464.  Loss 0.3971  Elapsed: 0:42:03.
# Batch 12,000  of  12,464.  Loss 0.4499  Elapsed: 0:45:52.
#
# Avg Training Loss 0.4553, Completed in 0:47:40
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5686  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6527, Completed in 0:04:21
# Validation F2-score: 0.7569
# Validation Matthew Correlation Coefficient: 0.3121
# Validation Recall: 0.7805
# Validation Precision: 0.6752
# Validation Accuracy: 0.6661
#
# ######  Epoch 82/89 ######
# Learning rate: 0.0003719151159758848
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.1888  Elapsed: 0:03:50.
# Batch 2,000  of  12,464.  Loss 0.6259  Elapsed: 0:07:40.
# Batch 3,000  of  12,464.  Loss 0.5697  Elapsed: 0:11:29.
# Batch 4,000  of  12,464.  Loss 0.5215  Elapsed: 0:15:18.
# Batch 5,000  of  12,464.  Loss 0.6403  Elapsed: 0:19:07.
# Batch 6,000  of  12,464.  Loss 0.4575  Elapsed: 0:22:57.
# Batch 7,000  of  12,464.  Loss 0.5992  Elapsed: 0:26:46.
# Batch 8,000  of  12,464.  Loss 0.2842  Elapsed: 0:30:35.
# Batch 9,000  of  12,464.  Loss 0.5038  Elapsed: 0:34:25.
# Batch 10,000  of  12,464.  Loss 0.4613  Elapsed: 0:38:14.
# Batch 11,000  of  12,464.  Loss 0.2811  Elapsed: 0:42:03.
# Batch 12,000  of  12,464.  Loss 0.3017  Elapsed: 0:45:53.
#
# Avg Training Loss 0.4583, Completed in 0:47:40
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.4580  Elapsed: 0:03:28.
#
# Avg Validation Loss 0.6237, Completed in 0:04:21
# Validation F2-score: 0.699
# Validation Matthew Correlation Coefficient: 0.3433
# Validation Recall: 0.6946
# Validation Precision: 0.7174
# Validation Accuracy: 0.675
#
# ######  Epoch 83/89 ######
# Learning rate: 0.0004015806847736404
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4466  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.6266  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.6000  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.5451  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.5242  Elapsed: 0:19:11.
# Batch 6,000  of  12,464.  Loss 0.4716  Elapsed: 0:23:00.
# Batch 7,000  of  12,464.  Loss 0.5903  Elapsed: 0:26:50.
# Batch 8,000  of  12,464.  Loss 0.5778  Elapsed: 0:30:40.
# Batch 9,000  of  12,464.  Loss 0.6391  Elapsed: 0:34:30.
# Batch 10,000  of  12,464.  Loss 0.5306  Elapsed: 0:38:19.
# Batch 11,000  of  12,464.  Loss 0.4206  Elapsed: 0:42:09.
# Batch 12,000  of  12,464.  Loss 0.5697  Elapsed: 0:45:58.
#
# Avg Training Loss 0.4626, Completed in 0:47:46
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.6773  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.7283, Completed in 0:04:22
# Validation F2-score: 0.8325
# Validation Matthew Correlation Coefficient: 0.302
# Validation Recall: 0.9012
# Validation Precision: 0.6378
# Validation Accuracy: 0.6573
#
# ######  Epoch 84/89 ######
# Learning rate: 0.00043018809568044596
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.4237  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4504  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.4228  Elapsed: 0:11:31.
# Batch 4,000  of  12,464.  Loss 0.3392  Elapsed: 0:15:21.
# Batch 5,000  of  12,464.  Loss 0.4710  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.5174  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.5517  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.5419  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.5079  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.2790  Elapsed: 0:38:22.
# Batch 11,000  of  12,464.  Loss 0.3890  Elapsed: 0:42:12.
# Batch 12,000  of  12,464.  Loss 0.4611  Elapsed: 0:46:02.
#
# Avg Training Loss 0.4652, Completed in 0:47:50
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.4719  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6481, Completed in 0:04:22
# Validation F2-score: 0.7268
# Validation Matthew Correlation Coefficient: 0.3263
# Validation Recall: 0.7351
# Validation Precision: 0.6953
# Validation Accuracy: 0.6705
#
# ######  Epoch 85/89 ######
# Learning rate: 0.00045742391991590895
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.5755  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.3383  Elapsed: 0:07:41.
# Batch 3,000  of  12,464.  Loss 0.4071  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.3338  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.6158  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.3499  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.4921  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.3156  Elapsed: 0:30:43.
# Batch 9,000  of  12,464.  Loss 0.5947  Elapsed: 0:34:33.
# Batch 10,000  of  12,464.  Loss 0.4621  Elapsed: 0:38:23.
# Batch 11,000  of  12,464.  Loss 0.6144  Elapsed: 0:42:14.
# Batch 12,000  of  12,464.  Loss 0.4567  Elapsed: 0:46:04.
#
# Avg Training Loss 0.4664, Completed in 0:47:52
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.5105  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6441, Completed in 0:04:22
# Validation F2-score: 0.7039
# Validation Matthew Correlation Coefficient: 0.3049
# Validation Recall: 0.707
# Validation Precision: 0.6917
# Validation Accuracy: 0.6587
#
# ######  Epoch 86/89 ######
# Learning rate: 0.0004829897560902566
#
# -----  Training -----
# Batch 1,000  of  12,464.  Loss 0.6272  Elapsed: 0:03:51.
# Batch 2,000  of  12,464.  Loss 0.4566  Elapsed: 0:07:42.
# Batch 3,000  of  12,464.  Loss 0.2903  Elapsed: 0:11:32.
# Batch 4,000  of  12,464.  Loss 0.4460  Elapsed: 0:15:22.
# Batch 5,000  of  12,464.  Loss 0.4648  Elapsed: 0:19:12.
# Batch 6,000  of  12,464.  Loss 0.4953  Elapsed: 0:23:02.
# Batch 7,000  of  12,464.  Loss 0.5760  Elapsed: 0:26:52.
# Batch 8,000  of  12,464.  Loss 0.4280  Elapsed: 0:30:42.
# Batch 9,000  of  12,464.  Loss 0.4721  Elapsed: 0:34:32.
# Batch 10,000  of  12,464.  Loss 0.5489  Elapsed: 0:38:22.
# Batch 12,000  of  12,464.  Loss 0.6239  Elapsed: 0:46:03.
#
# Avg Training Loss 0.4693, Completed in 0:47:51
#
# -----  Validation -----
# Batch 1,000  of  1,249.  Loss 0.4942  Elapsed: 0:03:29.
#
# Avg Validation Loss 0.6717, Completed in 0:04:22
# Validation F2-score: 0.7682
# Validation Matthew Correlation Coefficient: 0.2972
# Validation Recall: 0.8
# Validation Precision: 0.6631
# Validation Accuracy: 0.6596
#
# ######  Epoch 87/89 ######
# Learning rate: 0.0005066054995522105
#
# -----  Training -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 15
#      12 learning_rates.append(scheduler.get_last_lr())
#      14 print ('-----  Training -----')
# ---> 15 train_loss, train_time = train(train_loader, model, criterion, optimizer)
#      16 train_loss_values.append(train_loss)
#      18 print ('-----  Validation -----')
#
# Cell In[18], line 33, in train(train_loader, model, criterion, optimizer, verbose)
#      30 loss = criterion(output, target)
#      32 # Accumulate the training loss over all of the batches
# ---> 33 total_loss += loss.item()
#      35 # Report progress every 200 batches
#      36 if step % 1000 == 0 and not step == 0 and verbose==True:
#
# KeyboardInterrupt:

# %%
combined_train_losses = train_loss_values[:29]
combined_train_losses.extend(train_loss_values2)

combined_val_losses = val_loss_values[:29]
combined_val_losses.extend(val_loss_values2)

# %%
### Plot Training & Validation Loss
data = {'Epoch': range(1, 60), 'Training Loss': combined_train_losses, 'Validation Loss': combined_val_losses}
df = pd.DataFrame(data)

fig, ax = plt.subplots(figsize=(10, 6))
sns.set_style('whitegrid')
sns.set(font_scale=1.5)

# Plot train & val loss
sns.lineplot(data=df, x="Epoch", y="Training Loss", label="Training Loss", marker='o')
sns.lineplot(data=df, x="Epoch", y="Validation Loss", label="Validation Loss", marker='o')

# set the axis labels and title
ax.set(xlabel='Epoch', ylabel='Loss')
ax.set_title('Training and Validation Loss', fontsize=18)
ax.set_ylim(0)

# set the legend and adjust its position
plt.legend(fontsize=14)

# set the ticks fontsize
ax.tick_params(axis='both', which='major', labelsize=14)

# %% [markdown]
# ### Evaluation

# %%
checkpoint = torch.load("model_best_morgan300_bioclinical.pth.tar")  #Epoch 59
model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
# Predicting with Test Set # epochs 89
print('Evaluation metrics for Test Set:')
test_outputs, test_targets, test_loss, test_time = validate(test_loader, model, criterion, verbose=True)
print()
y_test_true, y_test_score, y_test_pred, accuracy= compute_metrics(test_outputs, test_targets, prefix="Testing")
# Out:
# Evaluation metrics for Test Set:
# Batch 1,000  of  7,771.  Loss 0.6532  Elapsed: 0:03:29.
# Batch 2,000  of  7,771.  Loss 0.7830  Elapsed: 0:06:57.
# Batch 3,000  of  7,771.  Loss 0.5232  Elapsed: 0:10:25.
# Batch 4,000  of  7,771.  Loss 0.6025  Elapsed: 0:13:54.
# Batch 5,000  of  7,771.  Loss 0.7986  Elapsed: 0:17:22.
# Batch 6,000  of  7,771.  Loss 0.3727  Elapsed: 0:20:50.
# Batch 7,000  of  7,771.  Loss 0.6337  Elapsed: 0:24:18.
#
# Avg Validation Loss 0.6567, Completed in 0:26:59
#
# Testing F2-score: 0.7679
# Testing Matthew Correlation Coefficient: 0.3073
# Testing Recall: 0.7671
# Testing Precision: 0.7713
# Testing Accuracy: 0.6922

# %%
# Predicting with Test Set # epochs 59
# print('Evaluation metrics for Test Set:')
# test_outputs, test_targets, test_loss, test_time = validate(test_loader, model, criterion, verbose=True)
# print()
# y_test_true, y_test_score, y_test_pred = compute_metrics(test_outputs, test_targets, prefix="Testing")
# Out:
# Evaluation metrics for Test Set:
# Batch 1,000  of  7,771.  Loss 0.5243  Elapsed: 0:03:28.
# Batch 2,000  of  7,771.  Loss 0.5056  Elapsed: 0:06:54.
# Batch 3,000  of  7,771.  Loss 0.3859  Elapsed: 0:10:20.
# Batch 4,000  of  7,771.  Loss 0.7188  Elapsed: 0:13:47.
# Batch 5,000  of  7,771.  Loss 0.5332  Elapsed: 0:17:13.
# Batch 6,000  of  7,771.  Loss 0.6279  Elapsed: 0:20:39.
# Batch 7,000  of  7,771.  Loss 0.5696  Elapsed: 0:24:05.
#
# Avg Validation Loss 0.6315, Completed in 0:26:46
#
# Testing F2-score: 0.8004
# Testing Matthew Correlation Coefficient: 0.2815
# Testing Recall: 0.814
# Testing Precision: 0.7501
# Testing Accuracy: 0.6943

# %%
# Predicting with Test Set # epochs 71
checkpoint = torch.load("models/checkpoint-ep71.pth.tar")
model.load_state_dict(checkpoint['state_dict'])

print('Evaluation metrics for Test Set:')
test_outputs, test_targets, test_loss, test_time = validate(test_loader, model, criterion, verbose=True)
print()
y_test_true, y_test_score, y_test_pred, accuracy = compute_metrics(test_outputs, test_targets, prefix="Testing")
# Out:
# Evaluation metrics for Test Set:
# Batch 1,000  of  7,771.  Loss 0.4700  Elapsed: 0:03:29.
# Batch 2,000  of  7,771.  Loss 0.6760  Elapsed: 0:06:57.
# Batch 3,000  of  7,771.  Loss 0.6527  Elapsed: 0:10:26.
# Batch 4,000  of  7,771.  Loss 0.8559  Elapsed: 0:13:54.
# Batch 5,000  of  7,771.  Loss 0.7081  Elapsed: 0:17:22.
# Batch 6,000  of  7,771.  Loss 0.4709  Elapsed: 0:20:50.
# Batch 7,000  of  7,771.  Loss 1.0977  Elapsed: 0:24:18.
#
# Avg Validation Loss 0.6820, Completed in 0:27:00
#
# Testing F2-score: 0.8255
# Testing Matthew Correlation Coefficient: 0.3064
# Testing Recall: 0.8465
# Testing Precision: 0.7511
# Testing Accuracy: 0.7098

# %%
# Save Model Checkpoint for CPU
# Load Best Model
model = MorganBioBertClassification()
model = model.to(device)

checkpoint = torch.load("models/checkpoint_ep71_morgan300_bioclinical.pth.tar")
model.load_state_dict(checkpoint['state_dict'])

model = model.to('cpu')
filename = "models/morgan300-bioclinicalbert-cpu.pth.tar"
state = {'epoch': 47,
         'state_dict': model.state_dict()}

torch.save(state, filename)

# %%
# Extract AUPRC & AP # epochs 89
def plot_AUPRC(y_true, y_score, title='Area Under Precision Recall Curve'):
    sns.set_style('white')
    plt.figure(figsize=(8,8))

    # Compute precision-recall pairs
    precision, recall, thresholds = precision_recall_curve(y_true, y_score)
    # Compute AUPRC
    auprc = auc(recall, precision)
    plt.plot(recall, precision, color="#663399", lw=2, alpha=0.9,
             label=f'AUPRC = {round(auprc, 3)})'
             )
    plt.xlabel('Recall', fontsize=14)
    plt.ylabel('Precision', fontsize=14)
    plt.ylim(bottom=0)
    plt.title(title, fontsize=16)
    plt.legend()
    plt.show()

plot_AUPRC(y_test_true, y_test_score)

# %%
# Extract AUPRC & AP # epochs 71
def plot_AUPRC(y_true, y_score, title='Area Under Precision Recall Curve'):
    sns.set_style('white')
    plt.figure(figsize=(8,8))

    # Compute precision-recall pairs
    precision, recall, thresholds = precision_recall_curve(y_true, y_score)
    # Compute AUPRC
    auprc = auc(recall, precision)
    plt.plot(recall, precision, color="#663399", lw=2, alpha=0.9,
             label=f'AUPRC = {round(auprc, 3)})'
             )
    plt.xlabel('Recall', fontsize=14)
    plt.ylabel('Precision', fontsize=14)
    plt.ylim(bottom=0)
    plt.title(title, fontsize=16)
    plt.legend()
    plt.show()

plot_AUPRC(y_test_true, y_test_score)

# %%
target_names = ['class ' + str(x) for x in range(2)]
val_classification_report = classification_report(y_test_true, y_test_pred, target_names=target_names)
print("Validation Set - Classification Report:")
print(val_classification_report)
# Out:
# Validation Set - Classification Report:
#               precision    recall  f1-score   support
#
#      class 0       0.58      0.43      0.50     61798
#      class 1       0.75      0.85      0.80    124689
#
#     accuracy                           0.71    186487
#    macro avg       0.67      0.64      0.65    186487
# weighted avg       0.70      0.71      0.70    186487

# %%
conf_matrix = confusion_matrix(y_test_true, y_test_pred)
conf_matrix = conf_matrix/conf_matrix.sum(axis=1, keepdims=True) * 100 #Convert to percentage
conf_matrix
# Out:
# array([[43.39946277, 56.60053723],
#        [15.35019128, 84.64980872]])

# %%
def plot_conf_matrix_high(conf_matrix):
    """Plot confusion matrix"""
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(
        conf_matrix, annot=True,
        cmap=sns.cubehelix_palette(as_cmap=True),
        xticklabels= ['Negative', 'Positive'],
        yticklabels= ['Negative', 'Positive'],
        # fmt=',.0f'
        fmt='.1f'
    )
    ax.set_xlabel("Predicted Label", fontsize=16)
    ax.set_ylabel("True Label", fontsize=16)
    ax.set_title("Normalized Confusion Matrix (%)", fontsize=18)
    plt.show()

conf_matrix = np.array([[56.60053723, 43.39946277],[15.35019128, 84.64980872]])
plot_conf_matrix_high(conf_matrix)

# %%
def plot_conf_matrix_high(conf_matrix):
    """Plot confusion matrix"""
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(
        conf_matrix, annot=True,
        cmap=sns.cubehelix_palette(as_cmap=True),
        xticklabels= ['Negative', 'Positive'],
        yticklabels= ['Negative', 'Positive'],
        fmt=',.0f'
    )
    ax.set_xlabel("Predicted Label", fontsize=16)
    ax.set_ylabel("True Label", fontsize=16)
    ax.set_title("Confusion Matrix", fontsize=18)
    
    plt.show()

conf_matrix = np.array([[34978, 26820], [ 19140, 105549]])
plot_conf_matrix_high(conf_matrix)

# %% [markdown]
# ## Double SMILES Morgan768 & BioClinicalBERT

# %% [markdown]
# ### Build Model

# %%
RANDOM_SEED = 40
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed_all(RANDOM_SEED)

# %%
# Define hyperparameters
BATCH_SIZE = 24
EPOCHS = 30
LEARNING_RATE = 0.001
# MOMENTUM = 0.9
WEIGHT_DECAY = 0.01
WORKERS = int(os.cpu_count())

# %%
# Clear out cuda before training
torch.cuda.empty_cache()

# %%
# BERT Model
class MorganBioBertClassification(nn.Module):
    def __init__(self,output_dim=1,
                 hidden_size=68, hidden_size2=54, hidden_size3=40,
                 dropout=0.1, unfreeze=False):
        super(MorganBioBertClassification, self).__init__()
        self.bert_model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

        # Unfreeze the last BERT transformer layer
        if unfreeze == "last layer":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "last two":
            for name, param in self.bert_model.named_parameters():
                if 'bert_model.encoder.layer.11' in name or 'bert_model.encoder.layer.10' in name:
                    param.requires_grad = True
                else:
                    param.requires_grad = False
        if unfreeze == "all layers":
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = True
        else:
            for name, param in self.bert_model.named_parameters():
                param.requires_grad = False

        self.bert_hidden_size = self.bert_model.config.hidden_size
        self.hidden_size = hidden_size
        self.hidden_size2 = hidden_size2
        self.hidden_size3 = hidden_size3
        self.hidden_layer = nn.Linear(self.bert_hidden_size, self.hidden_size)
        self.hidden_layer2 = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3 = nn.Linear(self.hidden_size2, self.hidden_size3)

        # Morgan Embedding First hidden layer
        self.hidden_layer_morgan = nn.Linear(1536, self.hidden_size)
        self.hidden_layer2_morgan = nn.Linear(self.hidden_size, self.hidden_size2)
        self.hidden_layer3_morgan = nn.Linear(self.hidden_size2, self.hidden_size3)

        # One hidden Layer after combining both branches
        self.hidden_layer_combine = nn.Linear(2*self.hidden_size3, 16)

        self.drop_out = nn.Dropout(dropout)

        self.classification = nn.Linear(16, output_dim)

        self.GeLU = nn.GELU()
        self.Sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask, morgan_embedding):
        # Output for target data
        bert_output = self.bert_model(input_ids=input_ids,
                                      attention_mask=attention_mask)

        pooler_token = bert_output[1]

        hidden_ouput = self.GeLU(self.hidden_layer(pooler_token))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer2(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)
        hidden_ouput = self.GeLU(self.hidden_layer3(hidden_ouput))
        hidden_ouput = self.drop_out(hidden_ouput)

        # Output for SMILES Morgan Embedding
        hidden_morgan_output = self.GeLU(self.hidden_layer_morgan(morgan_embedding))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer2_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)
        hidden_morgan_output = self.GeLU(self.hidden_layer3_morgan(hidden_morgan_output))
        hidden_morgan_output = self.drop_out(hidden_morgan_output)

        # Concatenate hidden_output and morgan_output
        concat_output = torch.cat((hidden_morgan_output, hidden_ouput), 1)
        hidden_concat_output = self.GeLU(self.hidden_layer_combine(concat_output))
        hidden_concat_output = self.drop_out(hidden_concat_output)

        # logits = self.classification(x)
        output = self.Sigmoid(self.classification(hidden_concat_output))
        output = output.flatten()

        # return logits
        return output

# %%
# Initialize model
model = MorganBioBertClassification()
model = model.to(device)

#load the pre-trained Bio-ClinicalBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')

# Print out models params for checking
params = list(model.named_parameters())
for p in params[-30:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

# %%
# Import data
train_file = 'data/binary_ddi/ddi_train_balanced_150k.csv'
dev_file = 'data/binary_ddi/ddi_val_binary.csv'
test_file = 'data/binary_ddi/ddi_test_binary.csv'

df_train = pd.read_csv(train_file, sep='\t')
df_val= pd.read_csv(dev_file, sep='\t')
df_test = pd.read_csv(test_file, sep='\t')

print(f'''mean length of smiles1: {df_train['smiles1'].map(len).mean()}''')
print(f'''min length of smiles1: {df_train['smiles1'].map(len).min()}''')
print(f'''max length of smiles1: {df_train['smiles1'].map(len).max()}''')
print(f'''mean length of smiles2: {df_train['smiles2'].map(len).mean()}''')
print(f'''min length of smiles2: {df_train['smiles2'].map(len).min()}''')
print(f'''max length of smiles2: {df_train['smiles2'].map(len).max()}''')
print('Value Counts of Labels in Train Set:')
df_train.interaction_type.value_counts()
df_train.head(2)

# %%
from sklearn.utils import resample

# Choose a smaller subset of val data for faster training
df_val_small = resample(df_val,
                        replace=False,     # sample without replacement
                        n_samples=30000,
                        # random_state=1
                        )
print(df_val_small.shape)
df_val_small.head(2)

# %%
# Import Drug2Vec Embedding - Morgan Fingerprints, Cosine Similarity
# drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_300clusters_morgan_cosine.txt", binary=False)
# Import Drug2Vec Embedding - Morgan Fingerprints, Tanimoto Similarity, 768 clusters
drug2vec_model = gensim.models.KeyedVectors.load_word2vec_format(fname=f"data/binary_ddi/drug2vec_768clusters_morgan_tanimoto.txt", binary=False)

print('Number of drugs available:', len(drug2vec_model.index_to_key))
print('Example - top 10 keys:', drug2vec_model.index_to_key[:10])
print('Embedding dimension:', len(drug2vec_model[drug2vec_model.index_to_key[0]]))

# %%
def build_data_loader(df, shuffle=True, verbose=False):
    # Extract Morgan Fingerprint Embedding
    # Remove the 4 SMILES causing error, only include SMILES in drug2vec.txt
    valid_smiles = drug2vec_model.index_to_key
    df = df[df['d1'].isin(valid_smiles) & df['d2'].isin(valid_smiles)]

    # Extract embedding
    df['d1_embedding'] = df['d1'].apply(lambda x: drug2vec_model[x])
    df['d2_embedding'] = df['d2'].apply(lambda x: drug2vec_model[x])

    # Drop all records that could not extract embedding (SMILES errors)
    df = df.dropna(subset=['d1_embedding', 'd2_embedding'], how='any')
    d1_embed = np.array(df['d1_embedding'].tolist())
    d2_embed = np.array(df['d2_embedding'].tolist())
    X_smiles = np.hstack((d1_embed, d2_embed))
    morgan_embedding = torch.from_numpy(X_smiles)
    if verbose:
        print('Drug1 Embedding Dimension:',d1_embed.shape)
        print('Drug2 Embedding Dimension:',d2_embed.shape)
        print('Drug 1 Concatenate with Drug 2 Embedding Dimension:', X_smiles.shape)
        print('Torch tensor Embedding Dimension:', morgan_embedding.shape)

    # Combine SMILES1 & SMILE2 Together, using [SEP] token to distingush between drug1 & drug2
    df["features"] = df["smiles1"].str[:254] + " [SEP] " + df["smiles2"].str[:254]
    X = df["features"]
    y = df["interaction_type"]

    # Combine Target2 and Target2 Together, using [SEP] token to distingush between drug1 & drug2
    # df["target_features"] = "Drug1: " + df["d1_target_action"] + " [SEP] " + "Drug2: " + df["d2_target_action"] + " [SEP]"
    # X_target = df["target_features"]

    # Tokenize Target
    _encodings = tokenizer(
        list(X.values),
        max_length=512,
        truncation=True,
        pad_to_max_length=True,
        return_token_type_ids=False,
        return_tensors='pt'
    )

    _ids = _encodings.input_ids
    _mask = _encodings.attention_mask
    _labels = torch.tensor(y.values)
    if verbose:
        print('Torch tensor target_ids Dimension:', _ids.shape)
        print('Torch tensor labels Dimension:', _labels.shape)

    _dataset = TensorDataset(_ids, _mask, _labels, morgan_embedding)
    _loader = DataLoader(_dataset, batch_size=BATCH_SIZE, shuffle=shuffle, num_workers=WORKERS)

    return _loader

# %%
# Val Data Loader
print('Validation Data Loader:')
val_loader = build_data_loader(df_val_small, shuffle=False, verbose=True)

# %%
# Train Data Loader
print('Testing Data Loader:')
test_loader = build_data_loader(df_test, verbose=True)

# %%
# Train Data Loader
print('Training Data Loader:')
train_loader = build_data_loader(df_train, verbose=True)

# %%
print('Train batches:', len(train_loader))
print('Val subset batches:', len(val_loader))
print('Test batches:', len(test_loader))

# %% [markdown]
# ### Training
#
# #### Learning Rate Finder

# %%
model = MorganBioBertClassification()
model = model.to(device)

# Initiate loss to Binary Cross Entropy
criterion = nn.BCELoss()

# Optimizer
# optimizer = optim.Adadelta(model.parameters(), lr=1e-7, weight_decay=1e-2)
optimizer = optim.AdamW(model.parameters(), lr=1e-7, weight_decay=1e-2)

# %%
# Function to adjust the Learning Rate manually for Finding a good learning rate
# Increase LR from 1e-7 to 10 in exponential manner
n_step_lr = 100
learning_rates = np.logspace(-7, 0, n_step_lr)

def adjust_learning_rate(optimizer, step):
    """This function is for testing different learning rate in an epoch to find the best LR range"""
    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rates[step]

learning_rates

# %%
def format_time(seconds):
    return str(datetime.timedelta(seconds=int(round(seconds))))

# %%
import math

## Define Learning Rate Finding fuction
def train_LRFinder(train_loader, model, criterion, optimizer, verbose=True):
    # reset total loss for each epoch
    total_loss = 0

    # LR Finding initialization
    losses = []
    lrs = []
    loss_100iters = 0


    # switch model to train mode
    model.train()

    # start time
    t0 = time.time()

    for step, data in enumerate(train_loader):
        # zero out gradients in the optimizer each step
        optimizer.zero_grad()

        # send the data to cuda device
        ids = data[0].to(device, dtype = torch.long)
        mask = data[1].to(device, dtype = torch.long)
        target = data[2].float().to(device)
        morgan_embedding = data[3].to(device)
    
        # compute output
        output = model(input_ids=ids, 
                       attention_mask=mask,
                       morgan_embedding=morgan_embedding
                      )

        # compute loss
        loss = criterion(output, target)

        # Accumulate the training loss over all of the batches
        total_loss += loss.item()
        loss_100iters += loss.item()

        # compute gradient
        # backprop!
        loss.backward()

        # update the weights!
        optimizer.step()

        # Report progress
        update_lr_step = int(math.ceil(len(train_loader)/n_step_lr))  #step = 125
        if step % update_lr_step == 0 and not step == 0 and verbose==True:
            n_iter_lr = int(step//update_lr_step)
            # Average loss for the current LR
            loss_100iters = loss_100iters / update_lr_step
            lr = learning_rates[n_iter_lr]

            print('Batch {:>5,}  of  {:>5,}.   Step Loss {:0.4f}   Avg Loss {:0.4f}   Learning Rate {:}    Elapsed: {:}.'.format(
                step,
                len(train_loader),
                loss.item(),
                loss_100iters,
                lr,
                format_time(time.time() - t0)))

            # Add loss & lr to list for ploting later
            losses.append(loss_100iters)
            lrs.append(lr)

            # update learning rate
            # scheduler.step()
            adjust_learning_rate(optimizer, n_iter_lr)

            # Reset loss for next lr
            loss_100iters = 0

    # Last iteration
    resid = len(train_loader) - 125*(n_step_lr-1)
    loss_100iters = loss_100iters / resid
    # Add loss & lr to list for ploting later
    losses.append(loss_100iters)
    lrs.append(learning_rates[-1])

    avg_train_loss = total_loss / len(train_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Training Loss {:0.4f}, Completed in {:} \n".format(
            avg_train_loss,
            format_time(elapsed_time)
        ))

    # return model, avg_train_loss, elapsed_time
    return losses, lrs

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "TRUE"

# %%
print ('-----  Learning Rate Finder -----')
losses, lrs = train_LRFinder(train_loader, model, criterion, optimizer)
print('Losses Dim:', len(losses))
print('LR Dim:', len(lrs))

# %%
plt.title("Learning Rate Finder")
plt.ylabel("Loss")
plt.xlabel("Learning Rate (log scale)")
plt.plot(lrs[:80], losses[:80])
plt.xscale('log')

# %%
plt.title("Learning Rate Finder - Zoomed In")
plt.ylabel("Loss")
plt.xlabel("Learning Rate (log scale)")
plt.plot(lrs[:79], losses[:79])
plt.xscale('log')

# %% [markdown]
# #### Training with Best LR

# %%
# Define hyperparameters
BATCH_SIZE = 24
EPOCHS = 30
LEARNING_RATE = 0.0006
WEIGHT_DECAY = 1e-2
WORKERS = int(os.cpu_count())

# %%
# from transformers import get_linear_schedule_with_warmup
# Initialize Model
model = MorganBioBertClassification(unfreeze=False)

# Continue training
model = model.to(device)
# checkpoint = torch.load("models/checkpoint.pth.tar")
# model.load_state_dict(checkpoint['state_dict'])

# Initiate loss to Binary Cross Entropy
criterion = nn.BCELoss()

# Optimizer
# optimizer = optim.Adadelta(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

# Create learning rate scheduler.
T_max = EPOCHS*len(train_loader)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max, eta_min = 1e-5)
# scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*T_max, num_training_steps=T_max)

# %%
## Define train function
def train(train_loader, model, criterion, optimizer, verbose=True):
    # reset total loss for each epoch
    total_loss = 0

    # switch model to train mode
    model.train()

    # start time
    t0 = time.time()

    for step, data in enumerate(train_loader):
        # zero out gradients in the optimizer each step
        optimizer.zero_grad()

        # send the data to cuda device
        ids = data[0].to(device, dtype = torch.long)
        mask = data[1].to(device, dtype = torch.long)
        target = data[2].float().to(device)   # 1 head
        # target = data[2].to(device, dtype = torch.long)   # 2 heads
        morgan_embedding = data[3].to(device)
    
        # compute output
        output = model(input_ids=ids, 
                       attention_mask=mask,
                       morgan_embedding=morgan_embedding
                      )

        # compute loss
        loss = criterion(output, target)

        # Accumulate the training loss over all of the batches
        total_loss += loss.item()

        # Report progress every 200 batches
        if step % 1000 == 0 and not step == 0 and verbose==True:
            print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                step,
                len(train_loader),
                loss.item(),
                format_time(time.time() - t0)))

        # compute gradient and do SGD
        # backprop!
        loss.backward()

        # update the weights!
        optimizer.step()

        # update learning rate with scheduler
        scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Training Loss {:0.4f}, Completed in {:} \n".format(
            avg_train_loss,
            format_time(elapsed_time)
        ))

    # return model, avg_train_loss, elapsed_time
    return avg_train_loss, elapsed_time

# %%
## Define validate function
def validate(val_loader, model, criterion, verbose=True):
    # Initialize
    targets=[]
    outputs=[]
    t0 = time.time()
    total_val_loss = 0

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        for step, data in enumerate(val_loader):

            # send the data to cuda device
            ids = data[0].to(device, dtype = torch.long)
            mask = data[1].to(device, dtype = torch.long)
            target = data[2].float().to(device)
            morgan_embedding = data[3].to(device)
        
            # compute output
            output = model(input_ids=ids, 
                           attention_mask=mask,
                           morgan_embedding=morgan_embedding
                          )

            # compute loss
            loss = criterion(output, target)

            # Accumulate the validation loss over all of the batches to calculate average loss
            total_val_loss += loss.item()

            targets.extend(target.cpu().detach().numpy().tolist())
            outputs.extend(output.cpu().detach().numpy().tolist())

            if step % 1000 == 0 and not step == 0 and verbose==True:
                print('Batch {:>5,}  of  {:>5,}.  Loss {:0.4f}  Elapsed: {:}.'.format(
                    step,
                    len(val_loader),
                    loss.item(),
                    format_time(time.time() - t0)))

    avg_val_loss = total_val_loss / len(val_loader)
    elapsed_time = time.time() - t0
    if verbose:
        print ("\nAvg Validation Loss {:0.4f}, Completed in {:}".format(
            avg_val_loss,
            format_time(elapsed_time)
        ))

    return outputs, targets, avg_val_loss, elapsed_time

# %%
# calculate the F1 score, auc, accuracy of our predictions vs labels
def compute_metrics(outputs, targets, prefix="Training"):
    y_pred = (np.array(outputs) >= 0.5).astype(float)
    y_score = np.array(outputs)
    y_true = np.array(targets)

    f2 =  metrics.fbeta_score(y_true, y_pred, average="binary", pos_label=1, beta=2)
    print(f"{prefix} F2-score: {round(f2,4)}")

    mcc = metrics.matthews_corrcoef(y_true, y_pred)
    print(f"{prefix} Matthew Correlation Coefficient: {round(mcc,4)}")

    recall_macro = metrics.recall_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Recall: {round(recall_macro,4)}")

    precision_macro = metrics.precision_score(y_true, y_pred, average="binary", pos_label=1)
    print(f"{prefix} Precision: {round(precision_macro,4)}")

    accuracy_macro = metrics.accuracy_score(y_true, y_pred)
    print(f"{prefix} Accuracy: {round(accuracy_macro,4)}")

    return y_true, y_score, y_pred, accuracy_macro

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "TRUE"

# %%
filename = "models/checkpoint.pth.tar"

def save_checkpoint(state, is_best, filename=filename):
    torch.save(state, filename)

    if is_best:
        shutil.copyfile(filename, 'models/model_best.pth.tar')

# %%
##### Test LR = 0.002, Optim = AdamW, Seed=40
# Store the average loss after each epoch so we can plot them.
best_accuracy = 0
train_loss_values = []
val_loss_values = []
learning_rates = []

for epoch in range(EPOCHS):
    print ('######  Epoch {}/{} ######'.format(epoch+1, EPOCHS))
    print('Learning rate:', str(scheduler.get_last_lr()[0]))
    print()
    learning_rates.append(scheduler.get_last_lr())

    print ('-----  Training -----')
    train_loss, train_time = train(train_loader, model, criterion, optimizer)
    train_loss_values.append(train_loss)

    print ('-----  Validation -----')
    val_outputs, val_targets, val_loss, val_time = validate(val_loader, model, criterion)
    val_loss_values.append(val_loss)
    y_val_true, y_val_score, y_val_pred, val_accuracy = compute_metrics(val_outputs, val_targets, prefix="Validation")
    print()

    # Get the best loss
    is_best = val_accuracy > best_accuracy
    best_accuracy = max(val_accuracy, best_accuracy)

    # Save Checkpoint
    save_checkpoint(
        {'epoch': epoch+1,
         'state_dict': model.state_dict(),
         'best_accuracy': best_accuracy,
         'optimizer': optimizer.state_dict()
         },
        is_best
    )

    if train_loss < 0.2:
        break

# %%
### Plot Training & Validation Loss
data = {'Epoch': range(1, 30), 'Training Loss': train_loss_values, 'Validation Loss': val_loss_values}
df = pd.DataFrame(data)

fig, ax = plt.subplots(figsize=(10, 6))
sns.set_style('whitegrid')
sns.set(font_scale=1.5)

# Plot train & val loss
sns.lineplot(data=df, x="Epoch", y="Training Loss", label="Training Loss", marker='o')
sns.lineplot(data=df, x="Epoch", y="Validation Loss", label="Validation Loss", marker='o')

# set the axis labels and title
ax.set(xlabel='Epoch', ylabel='Loss')
ax.set_title('Training and Validation Loss', fontsize=18)
ax.set_ylim(0)

# set the legend and adjust its position
plt.legend(fontsize=14)

# set the ticks fontsize
ax.tick_params(axis='both', which='major', labelsize=14)

# %%
# Predicting with Test Set # First 29 epochs
print('Evaluation metrics for Test Set:')
test_outputs, test_targets, test_loss, test_time = validate(test_loader, model, criterion, verbose=True)
print()
y_test_true, y_test_score, y_test_pred, accuracy = compute_metrics(test_outputs, test_targets, prefix="Testing")

# %%
# Extract AUPRC & AP
def plot_AUPRC(y_true, y_score, title='Area Under Precision Recall Curve'):
    sns.set_style('white')
    plt.figure(figsize=(8,8))

    # Compute precision-recall pairs
    precision, recall, thresholds = precision_recall_curve(y_true, y_score)
    # Compute AUPRC
    auprc = auc(recall, precision)
    plt.plot(recall, precision, color="#663399", lw=2, alpha=0.9,
             label=f'AUPRC = {round(auprc, 3)})'
             )
    plt.xlabel('Recall', fontsize=14)
    plt.ylabel('Precision', fontsize=14)
    plt.ylim(bottom=0)
    plt.title(title, fontsize=16)
    plt.legend()
    plt.show()

plot_AUPRC(y_test_true, y_test_score)

# %%
target_names = ['class ' + str(x) for x in range(2)]
val_classification_report = classification_report(y_test_true, y_test_pred, target_names=target_names)
print("Validation Set - Classification Report:")
print(val_classification_report)

# %%
conf_matrix = confusion_matrix(y_test_true, y_test_pred)
conf_matrix = conf_matrix/conf_matrix.sum(axis=1, keepdims=True) * 100 #Convert to percentage
conf_matrix

# %%
def plot_conf_matrix_high(conf_matrix):
    """Plot confusion matrix"""
    fig, ax = plt.subplots(figsize=(6, 6))
    sns.heatmap(
        conf_matrix, annot=True,
        cmap=sns.cubehelix_palette(as_cmap=True),
        xticklabels= ['Negative', 'Positive'],
        yticklabels= ['Negative', 'Positive'],
        # fmt=',.0f'
        fmt='.1f'
    )
    ax.set_xlabel("Predicted Label", fontsize=16)
    ax.set_ylabel("True Label", fontsize=16)
    ax.set_title("Normalized Confusion Matrix (%)", fontsize=18)
    plt.show()

plot_conf_matrix_high(conf_matrix)
