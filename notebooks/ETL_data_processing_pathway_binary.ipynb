# %% [markdown]
# # ETL & Data Processing

# %% [markdown]
# ## 1. Set up

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd ..
# %cd media/capstone-project
# Out:
# D:\OneDrive\w210\capstone-project

# %%
import random
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import itertools
import re

# %matplotlib inline
sns.set_theme(color_codes=True)

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 200)

# %%
from pyspark.sql import SparkSession

try:
    spark
    print("Spark is already running")
    print(f"{sc.master} appName: {sc.appName}")
except NameError:
    print('starting Spark')
    app_name = 'notebook'
    master = "local[*]"
    spark = SparkSession\
            .builder\
            .appName(app_name)\
            .master(master)\
            .getOrCreate()
sc = spark.sparkContext

# %%
spark

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## 2. EDA

# %%
raw_data = pd.read_csv('data/ddis_from_api_full.csv', delimiter='\t')
# Filter out drug_pairs without SMILES data
raw_data = raw_data.dropna(subset=['smiles1', 'smiles2', 'd1_name', 'd2_name', 'interaction'], how='any')
# Update All positive interactions to 1
raw_data['interaction_type'] = np.where(raw_data['interaction_type']==0, 0, 1)
raw_data = raw_data.drop_duplicates(('d1', 'd2'))

# Add a drug-pair column 
raw_data['d1_d2'] = raw_data.apply(lambda x: str([x['d1'], x['d2']]), axis=1)
raw_data['drug_pair'] = raw_data.apply(lambda x: str(set(sorted([x['d1'], x['d2']]))), axis=1)

print('Raw data dimension:', raw_data.shape)
print('Number of distinct drugs in d1:', len(raw_data['d1'].unique()))
print('Number of distinct drugs in d2:', len(raw_data['d2'].unique()))
print('Number of distinct d1-d2 sequence:', len(raw_data['d1_d2'].unique()))
print('Number of distinct drug-pair:', len(raw_data['drug_pair'].unique()))
raw_data.head()
# Out:
# Raw data dimension: (1400774, 11)
# Number of distinct drugs in d1: 2415
# Number of distinct drugs in d2: 2448
# Number of distinct d1-d2 sequence: 1400774
# Number of distinct drug-pair: 755017
#         d1       d2      d1_name         d2_name  \
# 0  DB00006  DB02709  Bivalirudin     Resveratrol
# 1  DB00006  DB01435  Bivalirudin      Antipyrine
# 2  DB00006  DB08867  Bivalirudin      Ulipristal
# 3  DB00006  DB00428  Bivalirudin    Streptozocin
# 4  DB00006  DB01138  Bivalirudin  Sulfinpyrazone
#
#                                                                                              interaction  \
# 0                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
# 1  The risk or severity of bleeding and hemorrhage can be increased when #Drug1 is combined with #Drug2.
# 2              The therapeutic efficacy of #Drug1 can be decreased when used in combination with #Drug2.
# 3                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
# 4                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
#
#   severity  \
# 0     high
# 1     high
# 2  unknown
# 3     high
# 4     high
#
#                                                                                                                                                                                                    smiles1  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 2  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 3  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
#
#                                                                                 smiles2  \
# 0                                                  OC1=CC=C(\C=C\C2=CC(O)=CC(O)=C2)C=C1
# 1                                                           CN1N(C(=O)C=C1C)C1=CC=CC=C1
# 2  CN(C)C1=CC=C(C=C1)[C@H]1C[C@@]2(C)[C@@H](CC[C@]2(O)C(C)=O)[C@@H]2CCC3=CC(=O)CCC3=C12
# 3                               CN(N=O)C(=O)N[C@H]1[C@@H](O)O[C@H](CO)[C@@H](O)[C@@H]1O
# 4                             O=C1C(CCS(=O)C2=CC=CC=C2)C(=O)N(N1C1=CC=CC=C1)C1=CC=CC=C1
#
#    interaction_type                   d1_d2               drug_pair
# 0                 1  ['DB00006', 'DB02709']  {'DB02709', 'DB00006'}
# 1                 1  ['DB00006', 'DB01435']  {'DB01435', 'DB00006'}
# 2                 1  ['DB00006', 'DB08867']  {'DB08867', 'DB00006'}
# 3                 1  ['DB00006', 'DB00428']  {'DB00428', 'DB00006'}
# 4                 1  ['DB00006', 'DB01138']  {'DB01138', 'DB00006'}

# %%
# Count the number of repeated pairs in the dataset
count_pair = dict(raw_data.d1_d2.value_counts())

# Display drug-pairs that have more than 1 interaction in the dataset
raw_data['count_pair'] = raw_data.d1_d2.map(count_pair)

pair_1count = len(raw_data[raw_data.count_pair == 1]['d1_d2'].unique())
pair_2count = len(raw_data[raw_data.count_pair > 1]['d1_d2'].unique())
print('Number of drug-pairs have 1 interaction:', pair_1count)
print('Number of drug-pairs have >1 interactions:', pair_2count)
# raw_data[raw_data.count_pair > 1].sort_values('d1_d2')
# Out:
# Number of drug-pairs have 1 interaction: 1400774
# Number of drug-pairs have >1 interactions: 0

# %%
# Number of distinct Drugs in the dataset
all_drug_id = set(raw_data['d1'].unique()) | set(raw_data['d2'].unique())
print('Number of distinct drugs:', len(all_drug_id))
# Out:
# Number of distinct drugs: 2448

# %% [markdown]
# ## 3. Extract Drug-Pair With Unknown-Interaction (Negative Control)

# %%
# SMILES dataset
drug_smiles = pd.read_csv('data/archive/drug_smiles.csv')
# drug_smiles = pd.read_csv('data/scraping_drug_smiles.csv')
# drug_smiles = drug_smiles[drug_smiles["SMILES"] != "Not Available"]
drug_smiles = drug_smiles[['drug_id', 'smiles']]

print('Drug Smiles dimension:', drug_smiles.shape)
drug_smiles.head()
# Out:
# Drug Smiles dimension: (1704, 2)
#    drug_id                                                              smiles
# 0  DB04571                                 CC1=CC2=CC3=C(OC(=O)C=C3C)C(C)=C2O1
# 1  DB00855                                                     NCC(=O)CCC(O)=O
# 2  DB09536                                                            O=[Ti]=O
# 3  DB01878                                         O=C(C1=CC=CC=C1)C1=CC=CC=C1
# 4  DB00140  CC1=C(C)C=C2N(C[C@H](O)[C@H](O)[C@H](O)CO)C3=NC(=O)NC(=O)C3=NC2=C1

# %%
# All potential Drug-Pair could be formed in the database
all_pairs = {str(set(pair)) for pair in itertools.combinations(sorted(drug_smiles.drug_id), 2)}
# all_pairs = {str(set(pair)) for pair in itertools.combinations(sorted(all_drug_id), 2)}
print("Total pairs could be formed:", len(all_pairs))

# All drug-pair with known interactions
interact_pairs = {pair for pair in raw_data.drug_pair.unique()}
print("Number of pairs have interactions:", len(interact_pairs))

# All drug-pair with NO interactions found
# negative_pairs = [pair for pair in all_pairs if pair not in interact_pairs]
negative_pairs = all_pairs - interact_pairs
print("Number of pairs with NO interactions found:", len(negative_pairs))

print("Quick look of negative control drug pairs:")
list(negative_pairs)[:10]
# Out:
# Total pairs could be formed: 1450956
# Number of pairs have interactions: 755017
# Number of pairs with NO interactions found: 1022612
# Quick look of negative control drug pairs:
# ["{'DB00293', 'DB06712'}",
#  "{'DB00381', 'DB00362'}",
#  "{'DB00905', 'DB00338'}",
#  "{'DB05260', 'DB00330'}",
#  "{'DB00462', 'DB01087'}",
#  "{'DB01588', 'DB13146'}",
#  "{'DB06282', 'DB09021'}",
#  "{'DB00352', 'DB08865'}",
#  "{'DB06626', 'DB11231'}",
#  "{'DB00992', 'DB01095'}"]

# %%
# def convert_pair_to_df(negative_pairs):
#     string_rdd = sc.parallelize(list(negative_pairs))
#     negative_rdd = string_rdd.map(lambda x: re.sub('[{}\']', '', x).split(", "))
#     negative_df = negative_rdd.toDF(["d1", "d2"]).toPandas()
#     return negative_df
    
# negative_df = convert_pair_to_df(negative_pairs)
# negative_df

# %%
negative_df = pd.DataFrame(negative_pairs)
negative_df.columns = ['drug_pair']
negative_df['d1'] = negative_df['drug_pair'].apply(lambda x: re.sub('[{}\']', '', x).split(", ")[0])
negative_df['d2'] = negative_df['drug_pair'].apply(lambda x: re.sub('[{}\']', '', x).split(", ")[1])
negative_df = negative_df.drop('drug_pair', axis=1)
negative_df
# Out:
#               d1       d2
# 0        DB00293  DB06712
# 1        DB00381  DB00362
# 2        DB00905  DB00338
# 3        DB05260  DB00330
# 4        DB00462  DB01087
# ...          ...      ...
# 1022607  DB00743  DB00474
# 1022608  DB01416  DB00938
# 1022609  DB00992  DB06605
# 1022610  DB00542  DB04845
# 1022611  DB00250  DB02546
#
# [1022612 rows x 2 columns]

# %%
# # Drug Name
# drug_names = pd.read_csv('data/archive/drugbank vocabulary.csv')
# drug_names = drug_names[['DrugBank ID', 'Common name']]
# # drug_names = pd.read_csv('data/scraping_drug_info.csv', delimiter='\t')
# # drug_names = drug_names[['drug_id', 'generic_name', 'SMILES']]
# drug_names = drug_names.rename(columns={'DrugBank ID': 'drug_id', 'Common name':'name'})
#
# print('Drug Names dimension:', drug_names.shape)
# drug_names.head()

# %%
# SMILES dataset
drug_smiles2 = pd.read_csv('data/scraping_drug_smiles.csv')
drug_smiles2 = drug_smiles2[drug_smiles2["SMILES"] != "Not Available"]
# drug_smiles2 = drug_smiles2[['drug_id', 'smiles']]

print('Drug Smiles dimension From Web Scraping:', drug_smiles2.shape)
drug_smiles2.head()
# Out:
# Drug Smiles dimension From Web Scraping: (2567, 3)
#    drug_id  generic_name  \
# 0  DB00006   Bivalirudin
# 1  DB00007    Leuprolide
# 2  DB00014     Goserelin
# 3  DB00027  Gramicidin D
# 4  DB00035  Desmopressin
#
#                                                                                                                                                                                                     SMILES
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=C1C=CC=C2)NC(=O)[C@H](CC1=CNC=N1)NC(=O)[C@@H]1CCC(=...
# 2  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=CC=CC=C12)NC(=O)[C@H](CC1=CN=CN1)NC(=O)[C@@H]1CCC(=O)N1)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@H]1...
# 3  CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@H](C(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@H](C(C)C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@H](CC(C)C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2...
# 4                                      NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)[C@H](CC2=CC=C(O)C=C2)NC(=O)CCSSC[C@H](NC(=O)[C@H](CC(N)=O)NC1=O)C(=O)N1CCC[C@H]1C(=O)N[C@H](CCCNC(N)=N)C(=O)NCC(N)=O

# %%
# Add Interaction Type and Smiles1, Smiles 2 into negative_df
merged_df = pd.merge(negative_df, drug_smiles2, left_on="d1", right_on="drug_id", how="left")
merged_df = merged_df.rename(columns={"generic_name": "d1_name", "SMILES": "smiles1"})
# merged_df = pd.merge(negative_df, drug_names, left_on="d1", right_on="drug_id", how="left")
# merged_df = merged_df.rename(columns={"name": "d1_name"})

merged_df = pd.merge(merged_df, drug_smiles2, left_on="d2", right_on="drug_id", how="left")
merged_df = merged_df.rename(columns={"generic_name": "d2_name", "SMILES": "smiles2"})
# merged_df = pd.merge(merged_df, drug_names, left_on="d2", right_on="drug_id", how="left")
# merged_df = merged_df.rename(columns={"name": "d2_name"})                                      

merged_df['interaction'] = 'Unknown'
merged_df['interaction_type'] = 0
merged_df['severity'] = 'unknown'


# merged_df = pd.merge(merged_df, drug_smiles, left_on="d1", right_on="drug_id", how="left")
# merged_df = merged_df.rename(columns={"smiles": "smiles1"})

# merged_df = pd.merge(merged_df, drug_smiles, left_on="d2", right_on="drug_id", how="left")
# merged_df = merged_df.rename(columns={"smiles": "smiles2"})

merged_df = merged_df[['d1', 'd2', 'd1_name', 'd2_name', 'interaction','interaction_type', 'severity', 'smiles1', 'smiles2']]
merged_df = merged_df.dropna(subset=['smiles1', 'smiles2', 'd1_name', 'd2_name'], how='any')
merged_df.head(2)
# Out:
#         d1       d2      d1_name        d2_name interaction  interaction_type  \
# 0  DB00293  DB06712  Raltitrexed    Nilvadipine     Unknown                 0
# 1  DB00381  DB00362   Amlodipine  Anidulafungin     Unknown                 0
#
#   severity  \
# 0  unknown
# 1  unknown
#
#                                                                  smiles1  \
# 0  CN(CC1=CC2=C(NC(C)=NC2=O)C=C1)C1=CC=C(S1)C(=O)N[C@@H](CCC(O)=O)C(O)=O
# 1                     CCOC(=O)C1=C(COCCN)NC(C)=C(C1C1=CC=CC=C1Cl)C(=O)OC
#
#                                                                                                                                                                                                    smiles2
# 0                                                                                                                                          COC(=O)C1=C(NC(C)=C(C1C1=CC(=CC=C1)[N+]([O-])=O)C(=O)OC(C)C)C#N
# 1  [H][C@]1(NC(=O)[C@@H](NC(=O)[C@@H]2C[C@@H](O)CN2C(=O)[C@@H](NC(=O)[C@H](C[C@@H](O)[C@@H](O)NC(=O)[C@@H]2[C@@H](O)[C@@H](C)CN2C1=O)NC(=O)C1=CC=C(C=C1)C1=CC=C(C=C1)C1=CC=C(OCCCCC)C=C1)[C@@H](C)O)[C@...

# %% [markdown]
# ## 4. Combine Interaction Data & Negative Control Data

# %%
raw_data = raw_data[['d1', 'd2', 'd1_name', 'd2_name', 'interaction','interaction_type', 'severity', 'smiles1', 'smiles2']]
master_df = pd.concat([merged_df, raw_data])
# master_df = master_df.dropna(subset=['smiles1', 'smiles2', 'd1_name', 'd2_name', 'interaction_type'], how='any')
master_df = master_df.dropna(subset=['smiles1'], how='any')
master_df = master_df.dropna(subset=['smiles2'], how='any')
master_df = master_df.dropna(subset=['interaction_type'], how='any')

master_df = master_df.drop_duplicates()
master_df = master_df.sort_values(by='d1')

master_df.reset_index(inplace=True)
master_df = master_df.drop('index', axis=1)

print("Shape of Master data:", master_df.shape)
print('Number of distinct drugs in d1:', len(master_df['d1'].unique()))
print('Number of distinct drugs in d2:', len(master_df['d2'].unique()))
total_drugs = set(master_df['d1'].unique()) | set(master_df['d2'].unique())
print('Number of distinct drugs:', len(total_drugs))
print("Value Count of Interaction Type")
print(master_df['interaction_type'].value_counts())
# print("Value Count of Interaction Type - Bottom 20:")
# print(master_df['interaction_type'].value_counts()[-20:])
print('Number of missing values:\n', master_df.isnull().sum())
# Out:
# Shape of Master data: (2403016, 9)
# Number of distinct drugs in d1: 2538
# Number of distinct drugs in d2: 2567
# Number of distinct drugs: 2567
# Value Count of Interaction Type
# 1    1400774
# 0    1002242
# Name: interaction_type, dtype: int64
# Number of missing values:
#  d1                  0
# d2                  0
# d1_name             0
# d2_name             0
# interaction         0
# interaction_type    0
# severity            0
# smiles1             0
# smiles2             0
# dtype: int64

# %%
master_df.head(2)
# Out:
#         d1       d2      d1_name      d2_name  \
# 0  DB00006  DB00621  Bivalirudin  Oxandrolone
# 1  DB00006  DB09053  Bivalirudin    Ibrutinib
#
#                                                                                              interaction  \
# 0                                                                                                Unknown
# 1  The risk or severity of bleeding and hemorrhage can be increased when #Drug1 is combined with #Drug2.
#
#    interaction_type severity  \
# 0                 0  unknown
# 1                 1     high
#
#                                                                                                                                                                                                    smiles1  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
#
#                                                                                smiles2
# 0  [H][C@@]12CC[C@](C)(O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC[C@@]2([H])CC(=O)OC[C@]12C
# 1                 NC1=NC=NC2=C1C(=NN2[C@@H]1CCCN(C1)C(=O)C=C)C1=CC=C(OC2=CC=CC=C2)C=C1

# %%
master_df[master_df["smiles1"].isnull()]
# Out:
# Empty DataFrame
# Columns: [d1, d2, d1_name, d2_name, interaction, interaction_type, severity, smiles1, smiles2]
# Index: []

# %%
master_df[master_df["smiles1"] == '']
# Out:
# Empty DataFrame
# Columns: [d1, d2, d1_name, d2_name, interaction, interaction_type, severity, smiles1, smiles2]
# Index: []

# %%
master_df[master_df["smiles1"] == ' ']
# Out:
# Empty DataFrame
# Columns: [d1, d2, d1_name, d2_name, interaction, interaction_type, severity, smiles1, smiles2]
# Index: []

# %%
master_df[master_df["d2_name"] == 'Sodium phosphate']
# Out:
# Empty DataFrame
# Columns: [d1, d2, d1_name, d2_name, interaction, interaction_type, severity, smiles1, smiles2]
# Index: []

# %%
master_df[master_df["interaction"] == 'The risk or severity of myopathy']
# Out:
# Empty DataFrame
# Columns: [d1, d2, d1_name, d2_name, interaction, interaction_type, severity, smiles1, smiles2]
# Index: []

# %%
# Save data
# master_df.to_csv("data/binary_ddi/ddis_from_api_binary.csv", index=False, sep='\t')
master_df = pd.read_csv("data/binary_ddi/ddis_from_api_binary.csv", sep='\t')

# %%
test_drug = master_df[master_df['d1']=='DB00338']
print(test_drug.shape)
# test_drug.head(2)
test_drug[test_drug['interaction_type'] != 0][test_drug['severity'] == 'high'].head(2)
# Out:
# (1557, 9)
# C:\Users\ltmai\AppData\Local\Temp\ipykernel_24976\1879203424.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_drug[test_drug['interaction_type'] != 0][test_drug['severity'] == 'high'].head(2)
#              d1       d2     d1_name       d2_name  \
# 238234  DB00338  DB00738  Omeprazole   Pentamidine
# 238457  DB00338  DB01035  Omeprazole  Procainamide
#
#                                                                  interaction  \
# 238234  The metabolism of #Drug2 can be decreased when combined with #Drug1.
# 238457  The metabolism of #Drug2 can be decreased when combined with #Drug1.
#
#         interaction_type severity  \
# 238234                 1     high
# 238457                 1     high
#
#                                                  smiles1  \
# 238234  COC1=CC2=C(C=C1)N=C(N2)S(=O)CC1=NC=C(C)C(OC)=C1C
# 238457  COC1=CC2=C(C=C1)N=C(N2)S(=O)CC1=NC=C(C)C(OC)=C1C
#
#                                               smiles2
# 238234  NC(=N)C1=CC=C(OCCCCCOC2=CC=C(C=C2)C(N)=N)C=C1
# 238457                  CCN(CC)CCNC(=O)C1=CC=C(N)C=C1

# %%
test_drug[test_drug['d2_name'] == "Testosterone"]
# Out:
#              d1       d2     d1_name       d2_name  \
# 239366  DB00338  DB00624  Omeprazole  Testosterone
#
#                                                                                          interaction  \
# 239366  #Drug1 may decrease the excretion rate of #Drug2 which could result in a higher serum level.
#
#         interaction_type severity  \
# 239366                 1  unknown
#
#                                                  smiles1  \
# 239366  COC1=CC2=C(C=C1)N=C(N2)S(=O)CC1=NC=C(C)C(OC)=C1C
#
#                                                                           smiles2
# 239366  [H][C@@]12CC[C@H](O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])CCC2=CC(=O)CC[C@]12C

# %%
# Add a drug-pair column 
# master_df['d1_d2'] = master_df.apply(lambda x: str([x['d1'], x['d2']]), axis=1)
# raw_data['drug_pair'] = raw_data.apply(lambda x: str(set(sorted([x['d1'], x['d2']]))), axis=1)

print('Raw data dimension:', master_df.shape)
print('Number of distinct drugs in d1:', len(master_df['d1'].unique()))
print('Number of distinct drugs in d2:', len(master_df['d2'].unique()))
# print('Number of distinct d1-d2 sequence:', len(master_df['d1_d2'].unique()))
# Out:
# Raw data dimension: (2403016, 9)
# Number of distinct drugs in d1: 2538
# Number of distinct drugs in d2: 2567

# %%
master_df['interaction_type'].value_counts().plot(kind='bar', logy=True)
sns.set_style('white')

plt.ylabel('Count')
plt.xlabel('Interaction Type')
plt.title('Distribution of Interaction Types')
labels = [0, 1]
plt.xticks(labels)
plt.ylim(bottom=1) 
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
sns.set_style('white')
sns.histplot(data=master_df, x='interaction_type', bins = 30, alpha=1, hue="severity", multiple="stack", palette='cool_r')
plt.ylabel('Count', fontsize=14)
plt.xlabel('Interaction Type', fontsize=14)
plt.title('Distribution of Interaction Types by Severity', fontsize=16)
# plt.xticks(rotation=0)
# labels = list(range(0, 90, 5))
labels = [0, 1]
plt.xticks(labels)
plt.show()

# %%
data = [master_df[master_df['interaction_type'] != 0].shape[0], master_df[master_df['interaction_type'] == 0].shape[0]]
labels = ['Positive Interactions', 'Negative Control']


def func(pct, allvals):                    
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:,})".format(pct, absolute)


fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(data, 
                                  autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"),
                                  explode=(0.03, 0),
                                  colors=['royalblue', 'lightsteelblue'],
                                  startangle=90
                                 )
ax.legend(wedges, labels,
          title="Interaction Type",
          loc="lower center",
          bbox_to_anchor=(0.25, -0.1, 0.5, 1)
         )

plt.setp(autotexts, size=12, weight="bold")
ax.set_title("Interaction Types", fontsize=16, y=0.95)
plt.show()

# %%
positive_df = master_df[master_df['interaction_type'] == 1]
data = [positive_df[positive_df['severity'] == 'high'].shape[0], positive_df[positive_df['severity'] != 'high'].shape[0]]
labels = ['High', 'Unknown']


def func(pct, allvals):                    
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:,})".format(pct, absolute)


fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(data, 
                                  autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"),
                                  explode=(0.03, 0),
                                  colors=['royalblue', 'lightsteelblue'],
                                  startangle=90
                                 )
ax.legend(wedges, labels,
          title="Severity",
          loc="lower center",
          bbox_to_anchor=(0.25, -0.1, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")
ax.set_title("Interaction Severity", fontsize=16, y=0.95)
plt.show()

# %%
# # Save new interaction_information
# interaction_df = master_df[['interaction_type', 'interaction']]
# interaction_df = interaction_df.drop_duplicates().sort_values('interaction_type')
# interaction_df.reset_index(inplace=True)
# interaction_df = interaction_df.drop('index', axis=1)
# interaction_df

# %%
# # save the dataframe to csv file
# interaction_df.to_csv('data/interaction_information_api.csv', index=False, sep='\t')

# %% [markdown]
# ## 5. Train / Test Split

# %%
master_df = pd.read_csv("data/binary_ddi/ddis_from_api_binary.csv", sep='\t')
master_df.head(2)
# Out:
#         d1       d2      d1_name     d2_name  \
# 0  DB00006  DB00721  Bivalirudin    Procaine
# 1  DB00006  DB02546  Bivalirudin  Vorinostat
#
#                                                                                              interaction  \
# 0  The risk or severity of bleeding and hemorrhage can be increased when #Drug1 is combined with #Drug2.
# 1                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
#
#    interaction_type severity  \
# 0                 1     high
# 1                 1     high
#
#                                                                                                                                                                                                    smiles1  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
#
#                           smiles2
# 0   CCN(CC)CCOC(=O)C1=CC=C(N)C=C1
# 1  ONC(=O)CCCCCCC(=O)NC1=CC=CC=C1

# %%
def trim_to_100_words(text):
    words = text.split()
    return " ".join(words[:100])

def clean_up_text(x):
    """Remove line breaks, special characters, punctuations within each post"""
    # Remove special characters and punctuations
    SPECIAL_CHARS_PATTERN = re.compile(r"(\*)|(\=\=)|(\~)|(\=)|(\.\.\.)|(\;)|(\:)|(\!)|(\?)|(\,)|(\")|(\|)|(\()|(\))|(\[)|(\])|(\%)|(\$)|(\>)|(\<)|(\{)|(\})")
    x = SPECIAL_CHARS_PATTERN.sub("", x.lower())

    # Remove different types of line breaks and white spaces
    x = re.sub(r"\n|\r|\r\n|<br\s*/?>", " ", x)

    # Remove extra white spaces
    x = re.sub(r"\s+", " ", x.strip())

    return x

## Extract Bit in the Approved Group
drug_info_df = pd.read_csv('data/scraping_drug_info.csv', delimiter='\t')
pathway_df = pd.read_csv('data/full_action_pathway_with_summary.csv')
pathway_df = pathway_df[["url", "summaries"]]
pathway_df = pathway_df.rename(columns={"summaries": "pathway"})

drug_info_df = pd.merge(drug_info_df, pathway_df, left_on="action_pathway", right_on="url", how="left")
drug_info_df["pathway"] = drug_info_df["pathway"].fillna("")
drug_info_df['pathway'] = drug_info_df["pathway"] + drug_info_df["mechanism_of_action"]
drug_info_df['pathway'] = drug_info_df["pathway"].apply(clean_up_text)
drug_info_df['pathway'] = drug_info_df["pathway"].apply(trim_to_100_words)
drug_info_df['smiles_pathway'] = drug_info_df["SMILES"].str[:250] + " " + drug_info_df['pathway']
drug_info_df = drug_info_df.drop('url', axis=1)
drug_info_df = drug_info_df.drop('action_pathway', axis=1)

drug_info_df.to_csv('data/drug_info_smiles_pathway.csv', index=False, sep='\t')

approved_drugs = drug_info_df[drug_info_df["approved_drug"] == 1]["drug_id"].values
not_approved_drugs = drug_info_df[drug_info_df["approved_drug"] != 1]["drug_id"].values
print("Number of approved drugs:", len(approved_drugs))
print("Number of not approved drugs:", len(not_approved_drugs))

drug_info_df.head(2)
# Out:
# Number of approved drugs: 2040
# Number of not approved drugs: 527
#    drug_id generic_name  \
# 0  DB00006  Bivalirudin
# 1  DB00007   Leuprolide
#
#                                                                                                                                                                                                     SMILES  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=C1C=CC=C2)NC(=O)[C@H](CC1=CNC=N1)NC(=O)[C@@H]1CCC(=...
#
#                                                                                                                                                                          drug_summary  \
# 0                      Bivalirudin is a direct thrombin inhibitor used to treat heparin-induced thrombocytopenia and to prevent thrombosis during percutaneous coronary intervention.
# 1  Leuprolide is a peptide-based GnRH receptor superagonist used for the palliative treatment of prostate cancer, uterine leiomyomata, endometriosis, and central precocious puberty.
#
#                                                                                           brand_names  \
# 0                                                                                            Angiomax
# 1  Camcevi, Eligard, Fensolvi, Lupaneta Pack 1-month, Lupron, Lupron Depot-ped, Viadur, Zeulide Depot
#
#              type                     groups  \
# 0  Small Molecule  Approved, Investigational
# 1  Small Molecule  Approved, Investigational
#
#                                             weight chemical_formula  \
# 0  Average: 2180.2853 Monoisotopic: 2178.985813062    C98H138N24O33
# 1  Average: 1209.3983 Monoisotopic: 1208.645462232     C59H84N16O12
#
#                                                     synonyms  \
# 0                 Bivalirudin | Bivalirudina | Bivalirudinum
# 1  Leuprorelin | Leuprorelina | Leuproreline | Leuprorelinum
#
#                                                                                                                                                                                                 indication  \
# 0  For treatment of heparin-induced thrombocytopenia and for the prevention of thrombosis. Bivalirudin is indicated for use in patients undergoing percutaneous coronary intervention (PCI), in patient...
# 1  Leuprolide is indicated for the treatment of advanced prostate cancer 6,12 and as palliative treatment of advanced prostate cancer.9 It is also used for the treatment of pediatric patients with ce...
#
#                                                                              conditions  \
# 0                                                                            Thrombosis
# 1  Advanced Prostate Cancer | Anemia | Central Precocious Puberty (CPP) | Endometriosis
#
#                                                                                                                                                                                           pharmacodynamics  \
# 0  Bivalirudin mediates an inhibitory action on thrombin by directly and specifically binding to both the catalytic site and anion-binding exosite of circulating and clot-bound thrombin. The action o...
# 1  Leuprolide is a gonadotropin-releasing hormone (GnRH) analogue that functions as a GnRH receptor superagonist.3,4 After an initial spike in GnRH-mediated steroidal production, including testostero...
#
#                                                                                                                                                                                        mechanism_of_action  \
# 0  Inhibits the action of thrombin by binding both to its catalytic site and to its anion-binding exosite. Thrombin is a serine proteinase that plays a central role in the thrombotic process, acting ...
# 1  Gonadotropin-releasing hormone (GnRH) is a naturally occurring decapeptide that modulates the hypothalamic-pituitary-gonadal (HPG) axis. GnRH binds to corresponding receptors (GnRHRs) on the anter...
#
#                                                                             target  \
# 0                            Category: A, Protein: Prothrombin, Actions: inhibitor
# 1  Category: A, Protein: Gonadotropin-releasing hormone receptor, Actions: agonist
#
#                                                                                      protein_binding  \
# 0             Other than thrombin and red blood cells, bivalirudin does not bind to plasma proteins.
# 1  Leuprolide displays in vitro binding to human plasma proteins between 43% and 49%.5,6,7,8,9,10,12
#
#       metabolism  \
# 0  Not Available
# 1  Not Available
#
#                                                                                                                             half_life  \
# 0  Normal renal function: 25 min (in normal conditions) | Creatinine clearance 10-29mL/min: 57min | Dialysis-dependant patients: 3.5h
# 1                                        Leuprolide has a terminal elimination half-life of approximately three hours.5,6,7,8,9,10,12
#
#                                                                          clearance  \
# 0                            Category: A, Protein: Prothrombin, Actions: inhibitor
# 1  Category: A, Protein: Gonadotropin-releasing hormone receptor, Actions: agonist
#
#   metabolism_pathway        UNII          CAS  approved_drug  \
# 0      Not Available  TN9BEX005G  128270-60-0              1
# 1      Not Available  EFY6W0M8TG   53714-56-0              1
#
#                                                                                                                                                                                                    pathway  \
# 0  bivalirudin is a new direct thrombin inhibitor approved by the food and drug administration for the treatment of deep vein thrombosis in patients who can not take unfractionated or low weight hepa...
# 1  gonadotropin-releasing hormone gnrh is a naturally occurring decapeptide that modulates the hypothalamic-pituitary-gonadal hpg axis. gnrh binds to corresponding receptors gnrhrs on the anterior pi...
#
#                                                                                                                                                                                             smiles_pathway
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=C1C=CC=C2)NC(=O)[C@H](CC1=CNC=N1)NC(=O)[C@@H]1CCC(=...

# %%
drug_info_df['smiles_pathway'][0]
# Out:
# 'CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1C bivalirudin is a new direct thrombin inhibitor approved by the food and drug administration for the treatment of deep vein thrombosis in patients who can not take unfractionated or low weight heparin . n it does not need co - antithrobin to be effective and it is not associated with an increased risk of bleeding or thrombotic complications such as thrombus formation or cardiac arrhythmias.inhibits the action of thrombin by binding both to its catalytic site and to its anion-binding exosite. thrombin is a serine proteinase that plays a central role in the thrombotic process acting to cleave fibrinogen into'

# %%
drug_info_df['smiles_pathway'][1]
# Out:
# 'CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=C1C=CC=C2)NC(=O)[C@H](CC1=CNC=N1)NC(=O)[C@@H]1CCC(=O)N1 gonadotropin-releasing hormone gnrh is a naturally occurring decapeptide that modulates the hypothalamic-pituitary-gonadal hpg axis. gnrh binds to corresponding receptors gnrhrs on the anterior pituitary gonadotropes which in turn release luteinizing hormone lh and follicle-stimulating hormone fsh these in turn affect the downstream synthesis and release of the sex hormones testosterone dihydrotestosterone estrone and estradiol.13 despite the variety of conditions indicated for treatment with leuprolide the mechanism of action underlying efficacy is the same in all cases. as a gnrhr agonist leuprolide binds to and initially activates downstream lh and fsh release this initial spike in gonadotropin levels is responsible for'

# %%
## Add Target and Mechanism of Action to Master DataFrame
target_df = drug_info_df[["drug_id", "smiles_pathway"]]

# Drug 1 merging
master_df2 = pd.merge(master_df, target_df, left_on="d1", right_on="drug_id", how="left")
master_df2 = master_df2.rename(columns={"smiles_pathway": "d1_smiles_pathway"})

# Drug 2 merging
master_df2 = pd.merge(master_df2, target_df, left_on="d2", right_on="drug_id", how="left")
master_df2 = master_df2.rename(columns={"smiles_pathway": "d2_smiles_pathway"})
master_df2 = master_df2.drop(["drug_id_x", "drug_id_y"], axis=1)
print('Number of missing values:\n', master_df2.isnull().sum())

master_df2["smiles_pathway_features"] = master_df2["d1_smiles_pathway"] + " [SEP] " + master_df2["d2_smiles_pathway"]

master_df2.head()
# Out:
# Number of missing values:
#  d1                   0
# d2                   0
# d1_name              0
# d2_name              0
# interaction          0
# interaction_type     0
# severity             0
# smiles1              0
# smiles2              0
# d1_smiles_pathway    0
# d2_smiles_pathway    0
# dtype: int64
#         d1       d2      d1_name       d2_name  \
# 0  DB00006  DB00721  Bivalirudin      Procaine
# 1  DB00006  DB02546  Bivalirudin    Vorinostat
# 2  DB00006  DB01101  Bivalirudin  Capecitabine
# 3  DB00006  DB00811  Bivalirudin     Ribavirin
# 4  DB00006  DB12364  Bivalirudin    Betrixaban
#
#                                                                                              interaction  \
# 0  The risk or severity of bleeding and hemorrhage can be increased when #Drug1 is combined with #Drug2.
# 1                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
# 2                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
# 3                                                                                                Unknown
# 4                 The risk or severity of bleeding can be increased when #Drug1 is combined with #Drug2.
#
#    interaction_type severity  \
# 0                 1     high
# 1                 1     high
# 2                 1     high
# 3                 0  unknown
# 4                 1     high
#
#                                                                                                                                                                                                    smiles1  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 2  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 3  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
#
#                                                                smiles2  \
# 0                                        CCN(CC)CCOC(=O)C1=CC=C(N)C=C1
# 1                                       ONC(=O)CCCCCCC(=O)NC1=CC=CC=C1
# 2        CCCCCOC(=O)NC1=NC(=O)N(C=C1F)[C@@H]1O[C@H](C)[C@@H](O)[C@H]1O
# 3                   NC(=O)C1=NN(C=N1)[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O
# 4  COC1=CC=C(NC(=O)C2=CC=C(C=C2)C(=N)N(C)C)C(=C1)C(=O)NC1=CC=C(Cl)C=N1
#
#                                                                                                                                                                                          d1_smiles_pathway  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 2  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 3  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
#
#                                                                                                                                                                                          d2_smiles_pathway  \
# 0  CCN(CC)CCOC(=O)C1=CC=C(N)C=C1 it is well known that procaine acts as an anaesthetic . n it exerts its local anaesthetic effect by blocking voltage-gated sodium channels across the neuronal plasma ...
# 1  ONC(=O)CCCCCCC(=O)NC1=CC=CC=C1 vorinostat inhibits the enzymatic activity of histone deacetylases hdac1 hdac2 and hdac3 class i and hdac6 class ii at nanomolar concentrations ic50 86 nm. these enz...
# 2  CCCCCOC(=O)NC1=NC(=O)N(C=C1F)[C@@H]1O[C@H](C)[C@@H](O)[C@H]1O fluoropyrimidine is an anticancer drug that is metabolized in the liver to 5-deoxy-5-fluorothymidiol 5-fdt by cytochrome p450 enzymes ...
# 3  NC(=O)C1=NN(C=N1)[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O ribavirin is reported to have several mechanism of actions that lead to inhibition of viral rna and protein synthesis. after activation by adenos...
# 4       COC1=CC=C(NC(=O)C2=CC=C(C=C2)C(=N)N(C)C)C(=C1)C(=O)NC1=CC=C(Cl)C=N1 betrixaban is a cofactor-independent direct inhibitor of the factor xa and inhibits free and prothrombinase-bound factor xa 1.
#
#                                                                                                                                                                                    smiles_pathway_features
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 2  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 3  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...
# 4  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=...

# %%
# # Create a new column to combine target & action to a single column, trim it to max 250 words for each drug
# df = master_df2.copy()
#
# def trim_to_250_words(text):
#     words = text.split()
#     return " ".join(words[:250])
#
# df["d1_target_action"] = df["d1_target"] + df["d1_action"]
# df["d1_target_action"] = df["d1_target_action"].apply(trim_to_250_words)
#
# df["d2_target_action"] = df["d2_target"] + df["d2_action"]
# df["d2_target_action"] = df["d2_target_action"].apply(trim_to_250_words)
#
#
#
# df.head()

# %%
# Extract DDI for approved drugs for train set
not_approved_df = master_df2[master_df2["d1"].isin(not_approved_drugs) | master_df2["d2"].isin(not_approved_drugs)]
approved_df = master_df2[master_df2["d1"].isin(approved_drugs) & master_df2["d2"].isin(approved_drugs)]
print("Approved drugs DDIS: ", approved_df.shape)
print("Not Approved Drugs DDIS: ", not_approved_df.shape)
# Out:
# Approved drugs DDIS:  (1978191, 12)
# Not Approved Drugs DDIS:  (424825, 12)

# %%
data = [approved_df.shape[0], not_approved_df.shape[0]]
labels = ['Approved Drugs', 'Other Drugs']


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:,})".format(pct, absolute)


fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(data,
                                  autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"),
                                  explode=(0.03, 0),
                                  colors=['royalblue', 'lightsteelblue'],
                                  startangle=90
                                 )
ax.legend(wedges, labels,
          title="Group Type",
          loc="lower center",
          bbox_to_anchor=(0.25, -0.1, 0.5, 1))

plt.setp(autotexts, size=12, weight="bold")
ax.set_title("Number of Interactions", fontsize=16, y=0.95)
plt.show()

# %%
# Save Not Approved Drugs for test set
val_test_drug_split = round(len(not_approved_drugs)/2)
np.random.shuffle(not_approved_drugs)
val_drugs = not_approved_drugs[:val_test_drug_split]

val_df = not_approved_df[not_approved_df["d1"].isin(val_drugs) | not_approved_df["d2"].isin(val_drugs)]
test_df = not_approved_df[~(not_approved_df["d1"].isin(val_drugs) | not_approved_df["d2"].isin(val_drugs))]

val_df = val_df.sample(frac=1, random_state=42)
val_df = val_df.reset_index()
val_df = val_df.drop('index', axis=1)


test_df = test_df.sample(frac=1, random_state=42)
test_df = test_df.reset_index()
test_df = test_df.drop('index', axis=1)

# Save test set
# save the dataframe to csv file
# not_approved_df.to_csv('data/ddi_test_api.csv', index=False)

# %%
print('Test dataset shape:', test_df.shape)
print('Number of interaction types in test set:', len(test_df.interaction_type.unique()))
print('Interaction type distribution in test set, Bottom 10:')
print(test_df.interaction_type.value_counts()[-10:])
test_df = test_df[["d1", "d2", "smiles1", "smiles2", "smiles_pathway_features", "interaction_type", "severity"]]
test_df.head(1)
# Out:
# Test dataset shape: (200088, 7)
# Number of interaction types in test set: 2
# Interaction type distribution in test set, Bottom 10:
# 1    128629
# 0     71459
# Name: interaction_type, dtype: int64
#         d1       d2  \
# 0  DB01329  DB00155
#
#                                                                                                      smiles1  \
# 0  [H][C@]12SCC(CSC3=NN=NN3C)=C(N1C(=O)[C@@]2([H])NC(=O)[C@H](NC(=O)N1CCN(CC)C(=O)C1=O)C1=CC=C(O)C=C1)C(O)=O
#
#                      smiles2  \
# 0  N[C@@H](CCCNC(N)=O)C(O)=O
#
#                                                                                                                                                                                    smiles_pathway_features  \
# 0  [H][C@]12SCC(CSC3=NN=NN3C)=C(N1C(=O)[C@@]2([H])NC(=O)[C@H](NC(=O)N1CCN(CC)C(=O)C1=O)C1=CC=C(O)C=C1)C(O)=O like all beta-lactam antibiotics cefoperazone binds to specific penicillin-binding protein...
#
#    interaction_type severity
# 0                 1  unknown

# %%
print('Validation dataset shape:', val_df.shape)
print('Number of interaction types in Validation set:', len(val_df.interaction_type.unique()))
print('Interaction type distribution in Validation set, Bottom 10:')
print(val_df.interaction_type.value_counts()[-10:])
val_df = val_df[["d1", "d2", "smiles1", "smiles2", "smiles_pathway_features", "interaction_type", "severity"]]
val_df.head(1)
# Out:
# Validation dataset shape: (224737, 7)
# Number of interaction types in Validation set: 2
# Interaction type distribution in Validation set, Bottom 10:
# 1    129912
# 0     94825
# Name: interaction_type, dtype: int64
#         d1       d2  \
# 0  DB04894  DB01203
#
#                                                                                                                                                                                    smiles1  \
# 0  CC(C)[C@@H]1NC(=O)[C@H](CCCCN)NC(=O)[C@@H](CC2=CNC3=CC=CC=C23)NC(=O)[C@H](CC2=CC=C(O)C=C2)NC(=O)[C@H](CSSC[C@H](NC1=O)C(=O)N[C@@H](CC1=CNC2=CC=CC=C12)C(N)=O)NC(=O)[C@H](N)CC1=CC=CC=C1
#
#                                            smiles2  \
# 0  CC(C)(C)NCC(O)COC1=CC=CC2=C1C[C@H](O)[C@H](O)C2
#
#                                                                                                                                                                                    smiles_pathway_features  \
# 0  CC(C)[C@@H]1NC(=O)[C@H](CCCCN)NC(=O)[C@@H](CC2=CNC3=CC=CC=C23)NC(=O)[C@H](CC2=CC=C(O)C=C2)NC(=O)[C@H](CSSC[C@H](NC1=O)C(=O)N[C@@H](CC1=CNC2=CC=CC=C12)C(N)=O)NC(=O)[C@H](N)CC1=CC=CC=C1 the exact me...
#
#    interaction_type severity
# 0                 0  unknown

# %%
approved_df = approved_df.sample(frac=1, random_state=42)
approved_df = approved_df.reset_index()
approved_df = approved_df.drop('index', axis=1)

print('Training dataset shape:', approved_df.shape)
print('Number of interaction types in Validation set:', len(approved_df.interaction_type.unique()))
print('Interaction type distribution in Validation set, Bottom 10:')
print(approved_df.interaction_type.value_counts()[-10:])

train_df = approved_df[["d1", "d2", "smiles1", "smiles2", "smiles_pathway_features", "interaction_type", "severity"]]
train_df.head(1)
# Out:
# Training dataset shape: (1978191, 12)
# Number of interaction types in Validation set: 2
# Interaction type distribution in Validation set, Bottom 10:
# 1    1142233
# 0     835958
# Name: interaction_type, dtype: int64
#         d1       d2                                                   smiles1  \
# 0  DB09281  DB13987  [Mg++].[Mg++].[O-][Si](=O)O[Si]([O-])([O-])O[Si]([O-])=O
#
#               smiles2  \
# 0  [Cl-].[Cl-].[Sr++]
#
#                                                                                                                                                                                    smiles_pathway_features  \
# 0  [Mg++].[Mg++].[O-][Si](=O)O[Si]([O-])([O-])O[Si]([O-])=O the gelatinous silicon dioxide formed by the reaction of magnesium trisilicate with gastric contents is said to protect ulcerated mucosal s...
#
#    interaction_type severity
# 0                 1  unknown

# %%
1142233/1978191
# Out:
# 0.577412898956673

# %%
# save the dataframe to csv file
test_df.to_csv('data/binary_ddi/ddi_test_binary_pathway.csv', index=False, sep='\t')
val_df.to_csv('data/binary_ddi/ddi_val_binary_pathway.csv', index=False, sep='\t')

train_df.to_csv('data/binary_ddi/ddi_train_binary_pathway.csv', index=False, sep='\t')

# %%
approved_df = pd.read_csv('data/binary_ddi/ddi_train_binary_pathway.csv', sep='\t')

# %% [markdown]
# ## 6. Under-Sampling & Up-Sampling

# %%
# Set the display.max_rows option to None
# pd.set_option("display.max_rows", None)

print('Training set label distribution:')
# approved_df = approved_df[["d1", "d2", "interaction_type", "severity"]]
approved_df.interaction_type.value_counts()
# Out:
# Training set label distribution:
# 1    1142233
# 0     835958
# Name: interaction_type, dtype: int64

# %%
fig = plt.figure(figsize=(8,8))
sns.set_style('white')
sns.histplot(data=approved_df, x='interaction_type', bins = 30, alpha=1,
             hue="severity", multiple="stack", palette='cool_r', stat='density')
plt.ylabel('Density', fontsize=14)
plt.xlabel('Interaction Type', fontsize=14)
plt.title('Training Set - Distribution of Interaction Types', fontsize=16)
# plt.xticks(rotation=0)
# labels = list(range(0, 90, 5))
plt.xticks(labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\axis.py:1732, in Axis.convert_units(self, x)
#    1731 try:
# -> 1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[26], line 10
#       7 plt.title('Training Set - Distribution of Interaction Types', fontsize=16)
#       8 # plt.xticks(rotation=0)
#       9 # labels = list(range(0, 90, 5))
# ---> 10 plt.xticks(labels)
#      11 plt.show()
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\pyplot.py:1886, in xticks(ticks, labels, minor, **kwargs)
#    1883         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    1884                         "without setting 'ticks'")
#    1885 else:
# -> 1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
#    1889     labels = ax.get_xticklabels(minor=minor)
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\axis.py:2074, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2071 if labels is None and kwargs:
#    2072     raise ValueError('labels argument cannot be None when '
#    2073                      'kwargs are passed')
# -> 2074 result = self._set_tick_locations(ticks, minor=minor)
#    2075 if labels is not None:
#    2076     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\axis.py:2014, in Axis._set_tick_locations(self, ticks, minor)
#    2010 def _set_tick_locations(self, ticks, *, minor=False):
#    2011     # see docstring of set_ticks
#    2012
#    2013     # XXX if the user changes units, the information will be lost here
# -> 2014     ticks = self.convert_units(ticks)
#    2015     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2016     for name, axis in self.axes._axis_map.items():
#
# File ~\.conda\envs\env310\lib\site-packages\matplotlib\axis.py:1734, in Axis.convert_units(self, x)
#    1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
# -> 1734     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1735                                  f'units: {x!r}') from e
#    1736 return ret
#
# ConversionError: Failed to convert value(s) to axis units: ['Approved Drugs', 'Other Drugs']

# %%
from sklearn.utils import resample

def balance_dataset(df, n_samples=10000, random_state=42):
    label_counts = df.interaction_type.value_counts()

    ## Downsample Majority cClasses
    # Get majority classes (all labels >= n_samples)
    majority_classes = approved_df.interaction_type.value_counts()\
        [approved_df.interaction_type.value_counts() >= n_samples].index

    # Initialize
    df_majorities = pd.DataFrame(data=[],
                                 columns=["d1", "d2", "smiles1", "smiles2", "smiles_pathway_features", "interaction_type", "severity"])

    for i in range(len(majority_classes)):
        label = majority_classes[i]
        df_majority = df[df["interaction_type"] == label]
        df_downsample = resample(df_majority,
                                replace=False,     # sample without replacement
                                n_samples=n_samples,    # change majority to minority clas
                                random_state=random_state)
        # Add each majority class to down_sample df:
        # Combine all downsampled majority classes
        df_majorities = pd.concat([df_majorities, df_downsample])


    ## Upsample Minority Classes
    # Get majority classes (all labels < n_samples)
    minority_classes = approved_df.interaction_type.value_counts()\
        [approved_df.interaction_type.value_counts() < n_samples].index

    # Initialize
    df_minorities = pd.DataFrame(data=[],
                                 columns=["d1", "d2", "smiles1", "smiles2", "smiles_pathway_features", "interaction_type", "severity"])

    for i in range(len(minority_classes)):
        label = minority_classes[i]
        df_minority = df[df["interaction_type"] == label]
        df_upsample = resample(df_minority,
                                replace=True,     # sample WITH replacement
                                n_samples=n_samples,    # change majority to minority clas
                                random_state=random_state)
        # Add each minority class to up-sample df:
        # Combine all Up-sampled minority classes
        df_minorities = pd.concat([df_minorities, df_upsample])

    ## Combine Upsample & Downsample data
    df = pd.concat([df_majorities, df_minorities])
    df = df.sample(frac=1, random_state=42)
    df = df.reset_index()
    df = df.drop('index', axis=1)

    return df

# %% [markdown]
# ### Balance to have 150,000 each label

# %%
## Balance data with each label = 150,000 samples
balance_df_150k = balance_dataset(approved_df, n_samples=150000)
print(balance_df_150k.shape)
balance_df_150k.head(2)
# Out:
# (300000, 7)
#         d1       d2  \
# 0  DB01501  DB00356
# 1  DB00208  DB00242
#
#                                                          smiles1  \
# 0  OC(=O)C1(CCN(CCC(C#N)(C2=CC=CC=C2)C2=CC=CC=C2)CC1)C1=CC=CC=C1
# 1                                ClC1=CC=CC=C1CN1CCC2=C(C1)C=CS2
#
#                                                smiles2  \
# 0                             ClC1=CC2=C(OC(=O)N2)C=C1
# 1  NC1=C2N=CN([C@H]3C[C@H](O)[C@@H](CO)O3)C2=NC(Cl)=N1
#
#                                                                                                                                                                                    smiles_pathway_features  \
# 0  OC(=O)C1(CCN(CCC(C#N)(C2=CC=CC=C2)C2=CC=CC=C2)CC1)C1=CC=CC=C1 difenoxin acts as an antidiarrheal by activating peripheral opioid receptors in the small intestine and thereby inhibiting peristalsis...
# 1  ClC1=CC=CC=C1CN1CCC2=C(C1)C=CS2 clopidogrel is the only antiplatelet drug approved for the treatment of angina pectoris . n it is metabolized in the liver to its active metabolite 2193'5'-hexachlo...
#
#   interaction_type severity
# 0                1     high
# 1                1     high

# %%
## Balance data with each label 400,000 samples
balance_df_300k = balance_dataset(approved_df, n_samples=300000)
print(balance_df_300k.shape)
balance_df_300k.head(2)
# Out:
# (600000, 7)
#         d1       d2                                         smiles1  \
# 0  DB00625  DB01558  FC(F)(F)[C@]1(OC(=O)NC2=C1C=C(Cl)C=C2)C#CC1CC1
# 1  DB08814  DB00351            CC(=O)OC1=C(C=CC(=C1)C(F)(F)F)C(O)=O
#
#                                                                                       smiles2  \
# 0                                                      BrC1=CC2=C(NC(=O)CN=C2C2=CC=CC=N2)C=C1
# 1  [H][C@@]12CC[C@](OC(C)=O)(C(C)=O)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])C=C(C)C2=CC(=O)CC[C@]12C
#
#                                                                                                                                                                                    smiles_pathway_features  \
# 0  FC(F)(F)[C@]1(OC(=O)NC2=C1C=C(Cl)C=C2)C#CC1CC1 rna interference rnai is a powerful tool for silencing tumor suppressor genes . n recently a new target has been identified the transcription factor ...
# 1  CC(=O)OC1=C(C=CC(=C1)C(F)(F)F)C(O)=O triflusal is chemically related to acetylsalicylic acid asa and irreversibly inhibits cycloxygenase-1 cox-1 in platelets. acetylation of the active group of co...
#
#   interaction_type severity
# 0                1     high
# 1                1     high

# %%
## Balance data with each label = 10,000 samples
# balance_df_835k = balance_dataset(approved_df, n_samples=835985)
# print(balance_df_835k.shape)
# balance_df_835k.head(2)
# Out:
# (1671970, 13)
#         d1       d2     d1_name               d2_name  \
# 0  DB00877  DB00944   Sirolimus            Demecarium
# 1  DB00238  DB00945  Nevirapine  Acetylsalicylic acid
#
#                                                             interaction  \
# 0                                                               Unknown
# 1  The metabolism of #Drug2 can be decreased when combined with #Drug1.
#
#   interaction_type severity  \
# 0                0  unknown
# 1                1  unknown
#
#                                                                                                                                                                                                    smiles1  \
# 0  [H][C@@]1(C[C@@H](C)[C@]2([H])CC(=O)[C@H](C)\C=C(C)\[C@@H](O)[C@@H](OC)C(=O)[C@H](C)C[C@H](C)\C=C\C=C\C=C(C)\[C@H](C[C@]3([H])CC[C@@H](C)[C@@](O)(O3)C(=O)C(=O)N3CCCC[C@@]3([H])C(=O)O2)OC)CC[C@@H](...
# 1                                                                                                                                                                CC1=C2NC(=O)C3=C(N=CC=C3)N(C3CC3)C2=NC=C1
#
#                                                                           smiles2  \
# 0  CN(CCCCCCCCCCN(C)C(=O)OC1=CC=CC(=C1)[N+](C)(C)C)C(=O)OC1=CC=CC(=C1)[N+](C)(C)C
# 1                                                        CC(=O)OC1=CC=CC=C1C(O)=O
#
#                                                                         d1_target  \
# 0  Category: A, Protein: Serine/threonine-protein kinase mTOR, Actions: inhibitor
# 1          Category: A, Protein: Reverse transcriptase/RNaseH, Actions: inhibitor
#
#                                                                                                                                                                                                  d1_action  \
# 0  Sirolimus works by inhibiting T-lymphocyte activation and proliferation stimulated by antigens and cytokines such as interleukin (IL)-2, IL-4, and IL-15. In target cells, sirolimus binds to the cy...
# 1  Nevirapine binds directly to reverse transcriptase (RT) and blocks the RNA-dependent and DNA-dependent DNA polymerase activities by causing a disruption of the enzyme's catalytic site. The activit...
#
#                                                                                                                                                                                                  d2_target  \
# 0                                                                                Category: A, Protein: Acetylcholinesterase, Actions: inhibitor | Category: U, Protein: Cholinesterase, Actions: inhibitor
# 1  Category: A, Protein: Prostaglandin G/H synthase 1, Actions: inhibitor | Category: A, Protein: Prostaglandin G/H synthase 2, Actions: inhibitor | Category: U, Protein: Aldo-keto reductase family 1...
#
#                                                                                                                                                                                                  d2_action
# 0  Demecarium is an indirect-acting parasympathomimetic agent, also known as a cholinesterase inhibitor and anticholinesterase. Cholinesterase inhibitors prolong the effect of acetylcholine, which is...
# 1  Acetylsalicylic acid (ASA) blocks prostaglandin synthesis. It is non-selective for COX-1 and COX-2 enzymes 9,10,11. Inhibition of COX-1 results in the inhibition of platelet aggregation for about ...

# %%
fig = plt.figure(figsize=(8,8))
sns.set_style('white')
sns.histplot(data=balance_df_150k, x='interaction_type',bins = 87, alpha=1,
             hue="severity", multiple="stack", palette='cool')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Interaction Type', fontsize=12)
plt.title('Balanced Training Set - Distribution of Interaction Types', fontsize=16)
# plt.xticks(rotation=0)
labels = list(range(2))
plt.xticks(labels)
plt.show()

# %%
# Save Balance Training Data
# save the dataframe to csv file
balance_df_150k.to_csv('data/binary_ddi/ddi_train_balanced_pathway_150k.csv', index=False, sep='\t')

# %%
# save the dataframe to csv file
balance_df_300k.to_csv('data/binary_ddi/ddi_train_balanced_pathway_300k.csv', index=False, sep='\t')

# %%
# Save Balance Training Data
# save the dataframe to csv file
# balance_df_835k.to_csv('data/binary_ddi/ddi_train_balanced_with_target_835k.csv', index=False, sep='\t')

# %%
# Create a new column to combine target & action to a single column, trim it to max 250 words for each drug
df = val_df.copy()

def trim_to_250_words(text):
    words = text.split()
    return " ".join(words[:250])

# df["d1_target_action"] = df["d1_target"] + " | " + df["d1_action"]
# df["d1_target_action"] = df["d1_target_action"].apply(trim_to_250_words)
#
# df["d2_target_action"] = df["d2_target"] + " | " + df["d2_action"]
# df["d2_target_action"] = df["d2_target_action"].apply(trim_to_250_words)

df["d1_target"] = df["d1_target"].str.replace('|', '.').str.replace(':','')
df["d1_target"] = df["d1_target"].apply(trim_to_250_words)
df["d2_target"] = df["d2_target"].str.replace('|', '.').str.replace(':','')
df["d2_target"] = df["d2_target"].apply(trim_to_250_words)

df["target_features"] = "Drug1: " + df["d1_target"] + " [SEP] " + "Drug2: " + df["d2_target"] + "[SEP]"


print(df["target_features"][2])
df.head()
# Out:
# C:\Users\ltmai\AppData\Local\Temp\ipykernel_24976\3516048953.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["d1_target"] = df["d1_target"].str.replace('|', '.').str.replace(':','')
# C:\Users\ltmai\AppData\Local\Temp\ipykernel_24976\3516048953.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["d2_target"] = df["d2_target"].str.replace('|', '.').str.replace(':','')
# Drug1: Not Available [SEP] Drug2: Category A, Protein Sodium-dependent serotonin transporter, Actions inhibitor . Category A, Protein Sodium-dependent noradrenaline transporter, Actions inhibitor . Category U, Protein NMDA receptor, Actions inhibitor[SEP]
#         d1       d2        d1_name                 d2_name  \
# 0  DB00318  DB12221        Codeine               Canrenone
# 1  DB00865  DB02134  Benzphetamine                Xanthine
# 2  DB04828  DB04896      Zomepirac             Milnacipran
# 3  DB00546  DB00987     Adinazolam              Cytarabine
# 4  DB00453  DB13925   Clomocycline  Dotatate gallium Ga-68
#
#                                                                                                interaction  \
# 0                The therapeutic efficacy of #Drug2 can be decreased when used in combination with #Drug1.
# 1            The risk or severity of adverse effects can be increased when #Drug1 is combined with #Drug2.
# 2  The risk or severity of gastrointestinal bleeding can be increased when #Drug1 is combined with #Drug2.
# 3                                                                                                  Unknown
# 4                                                                                                  Unknown
#
#    interaction_type severity  \
# 0                 1  unknown
# 1                 1     high
# 2                 1     high
# 3                 0  unknown
# 4                 0  unknown
#
#                                                                                                    smiles1  \
# 0                                        [H][C@]12C=C[C@H](O)[C@@H]3OC4=C5C(C[C@H]1N(C)CC[C@@]235)=CC=C4OC
# 1                                                                    C[C@@H](CC1=CC=CC=C1)N(C)CC1=CC=CC=C1
# 2                                                               CN1C(CC(O)=O)=CC(C)=C1C(=O)C1=CC=C(Cl)C=C1
# 3                                                      CN(C)CC1=NN=C2CN=C(C3=CC=CC=C3)C3=C(C=CC(Cl)=C3)N12
# 4  [H][C@@]12C[C@@]3([H])C(=C(O)[C@]1(O)C(=O)C(C(=O)NCO)=C(O)[C@H]2N(C)C)C(=O)C1=C(C(Cl)=CC=C1O)[C@@]3(C)O
#
#                                                                                                                                                                                                    smiles2  \
# 0                                                                                                                      [H][C@@]12CC[C@@]3(CCC(=O)O3)[C@@]1(C)CC[C@@]1([H])[C@@]2([H])C=CC2=CC(=O)CC[C@]12C
# 1                                                                                                                                                                                  O=C1NC2=C(NC=N2)C(=O)N1
# 2                                                                                                                                                                         CCN(CC)C(=O)C1(CC1CN)C1=CC=CC=C1
# 3                                                                                                                                                      NC1=NC(=O)N(C=C1)[C@@H]1O[C@H](CO)[C@@H](O)[C@@H]1O
# 4  [68Ga+3].C[C@@H](O)[C@H](NC(=O)[C@@H]1CSSC[C@H](NC(=O)[C@@H](CC2=CC=CC=C2)NC(=O)CN2CCN(CC([O-])=O)CCN(CC([O-])=O)CCN(CC([O-])=O)CC2)C(=O)N[C@@H](CC2=CC=C(O)C=C2)C(=O)N[C@H](CC2=CNC3=C2C=CC=C3)C(=O...
#
#                                                                                                                                                                                                  d1_target  \
# 0       Category A, Protein Mu-type opioid receptor, Actions agonist . Category A, Protein Kappa-type opioid receptor, Actions regulator . Category A, Protein Delta-type opioid receptor, Actions agonist
# 1  Category A, Protein Synaptic vesicular amine transporter, Actions inducer . Category A, Protein Alpha-2A adrenergic receptor, Actions agonist . Category A, Protein Alpha-1A adrenergic receptor, Ac...
# 2                                                                                                                                                                                            Not Available
# 3                                           Category A, Protein GABA(A) Receptor, Actions positive allosteric modulator . Category A, Protein GABA(A) Receptor Benzodiazepine Binding Site, Actions ligand
# 4             Category A, Protein 30S ribosomal protein S4, Actions inhibitor . Category U, Protein 30S ribosomal protein S9, Actions inhibitor . Category N, Protein 16S ribosomal RNA, Actions inhibitor
#
#                                                                                                                                                                                                  d1_action  \
# 0  Codeine is a selective agonist for the mu opioid receptor, but with a much weaker affinity to this receptor than morphine, a more potent opioid drug. Codeine binds to mu-opioid receptors, which ar...
# 1  The mechanism of action of these drugs is not fully understood, however it may be similar to that of amphetamines. Amphetamines stimulate noepinephrine and dopamine release in nerve endings in the...
# 2                                                                                                                                                                                            Not Available
# 3  Adinazolam binds to peripheral-type benzodiazepine receptors which interact allosterically with GABA receptors. This potentiates the effects of the inhibitory neurotransmitter GABA, increasing the...
# 4  Clomocycline inhibits cell growth by inhibiting translation. It binds to the 30S ribosomal subunit and prevents the amino-acyl tRNA from binding to the A site of the ribosome. The binding is rever...
#
#                                                                                                                                                                                                  d2_target  \
# 0                                                                                                                                                                                            Not Available
# 1                                                                                                                                                                                            Not Available
# 2  Category A, Protein Sodium-dependent serotonin transporter, Actions inhibitor . Category A, Protein Sodium-dependent noradrenaline transporter, Actions inhibitor . Category U, Protein NMDA recepto...
# 3                                                                                   Category A, Protein DNA polymerase beta, Actions inhibitor . Category A, Protein DNA, Actions cross-linking/alkylation
# 4                                                                                                                                         Category A, Protein Somatostatin receptor type 2, Actions binder
#
#                                                                                                                                                                                                  d2_action  \
# 0                                                                                                                                                                                            Not Available
# 1                                                                                                                                                                                            Not Available
# 2  The dual ability for milnacipran to inhibit the reuptake of both serotonin (5HT) and norepinephrine (NE) facilitates its treatment of both fibromyalgia and major depressive disorder (MDD). | In pa...
# 3  Cytarabine acts through direct DNA damage and incorporation into DNA. Cytarabine is cytotoxic to a wide variety of proliferating mammalian cells in culture. It exhibits cell phase specificity, pri...
# 4  The somatostatin receptor-based imaging is the preferred choice in the diagnostic and management of neuroendocrine tumors. The basis for the mechanism of dotatate gallium 68 is the binding of a li...
#
#                                                                                                                                                                                            target_features
# 0  Drug1: Category A, Protein Mu-type opioid receptor, Actions agonist . Category A, Protein Kappa-type opioid receptor, Actions regulator . Category A, Protein Delta-type opioid receptor, Actions ag...
# 1  Drug1: Category A, Protein Synaptic vesicular amine transporter, Actions inducer . Category A, Protein Alpha-2A adrenergic receptor, Actions agonist . Category A, Protein Alpha-1A adrenergic recep...
# 2  Drug1: Not Available [SEP] Drug2: Category A, Protein Sodium-dependent serotonin transporter, Actions inhibitor . Category A, Protein Sodium-dependent noradrenaline transporter, Actions inhibitor ...
# 3  Drug1: Category A, Protein GABA(A) Receptor, Actions positive allosteric modulator . Category A, Protein GABA(A) Receptor Benzodiazepine Binding Site, Actions ligand [SEP] Drug2: Category A, Prote...
# 4  Drug1: Category A, Protein 30S ribosomal protein S4, Actions inhibitor . Category U, Protein 30S ribosomal protein S9, Actions inhibitor . Category N, Protein 16S ribosomal RNA, Actions inhibitor ...
